# %%
import pandas as pd

# Load the Excel files
file1 = "DatasetTruth.xlsx"
file2 = "patient_data_cleaned.xlsx"
df1 = pd.read_excel(file1)
df2 = pd.read_excel(file2)

# Combine the DataFrames vertically
combined_df = pd.concat([df1, df2], ignore_index=True)

# combined_df

# %%
# issue with ground truth label row 27 was shifted 1 element to the left need to shift to right
row_index = 27

# Extract the row values as a NumPy array
row_vals = combined_df.iloc[row_index].values.copy()
n_cols = len(row_vals)

# Create a new array for the modified row
new_row = row_vals.copy()

# Place the value from the last column into column 3 (Python index 2)
new_row[3] = row_vals[-1]

# Shift the original values from column 3 (index 2) through the second-to-last column one position to the right.
# They will now occupy indices 3 through n_cols-1.
new_row[4:] = row_vals[3:-1]

# Replace the row in the DataFrame with the modified row
combined_df.iloc[row_index] = new_row

# Verify the change by printing the modified row
combined_df.iloc[27]
# Out:
# Patient Note                                                                              BC27
# Entire Patient Note                            Chief complaint: Patient with breast cancer ...
# Current Medications                          acetaminophen (TYLENOL) 325 mg tablet Take 2 t...
# Past Medications                                                                           NaN
# Patient Current Age                                                         70-year-old female
# Current Symptoms                             Feeling well since surgery, healing well, slig...
# Past symptoms                                Left breast mass, numbness of L axilla and L e...
# Chronic Conditions                           Arthritis, Breast cancer (left side), Cataract...
# family history                               Paternal grandmother passed away from breast c...
# Reason for visit                             Patient with a recent diagnosis of stage IIA p...
# Primary diagnosis (should be only one)       Stage IIA pT2(m)N1a left breast invasive ducta...
# Procedure names                              Screening mammogram, Diagnostic mammogram, Ult...
# Information relevant to primary diagnosis    Stage IIA IDC with known lymph node involvemen...
# Name: 27, dtype: object

# %%
import re

# Function to extract the numeric age from the string
def extract_age(age_str):
    if pd.isnull(age_str):
        return None
    # Extract the first group of digits from the age string
    match = re.search(r'(\d+)', str(age_str))
    return int(match.group(1)) if match else None

# Function to determine gender based on the 'age' and 'Reason for visit' columns
def determine_gender(age_str, reason_str):
    # Default to 'male'
    gender = "male"

    # Check the 'age' column first for keywords indicating female
    if pd.notnull(age_str):
        age_lower = str(age_str).lower()
        if "female" in age_lower or "woman" in age_lower:
            return "female"

    # Next, check the 'Reason for visit' column for gender-indicating words
    if pd.notnull(reason_str):
        reason_lower = str(reason_str).lower()
        # Look for tokens that might indicate a female
        if any(token in reason_lower for token in ["her", "woman", "she", "ms"]):
            return "female"
        # Optionally, you could check for "mr" to force male, but since default is male, it's not needed

    return gender

# Apply the functions to create new columns
combined_df['Age'] = combined_df['Patient Current Age'].apply(extract_age)
combined_df['Gender'] = combined_df.apply(lambda row: determine_gender(row['Patient Current Age'], row['Reason for visit']), axis=1)

# Display the first few rows to verify the changes
combined_df
# Out:
#    Patient Note                                Entire Patient Note  \
# 0         pdac0  SUBJECTIVE:    This is a very pleasant 47-year...
# 1         pdac1  This is an independent visit    ATTENDING: ***...
# 2         pdac2  Mr. ***** is a 74 y.o. male who returns to our...
# 3         pdac3  SUBJECTIVE:    This is a very pleasant 64-year...
# 4         pdac4  This is an independent service.  The available...
# 5         pdac5  Subjective:    This is a very pleasant 63-year...
# 6         pdac6  SUBJECTIVE:    This is a very pleasant 68-year...
# 7         pdac7  Ms. ***** is a 69 y.o. female who comes to our...
# 8         pdac8  REASON FOR VISIT/CC:   Chief Complaint   Patie...
# 9         pdac9  FOLLOW UP VISIT    Ms. ***** is a 73 y.o. fema...
# 10       pdac10  INITIAL GI MEDICAL ONCOLOGY VISIT     Patient ...
# 11       pdac11  I had the pleasure of seeing ***** ***** for f...
# 12       pdac12    FOLLOW UP GASTROINTESTINAL MEDICAL ONCOLOGY ...
# 13       pdac13  VIDEO VISIT  I performed this consultation usi...
# 14       pdac14  REASON FOR VISIT/CC:   Chief Complaint   Patie...
# 15       pdac15   UCSF Cancer Center GI Medical Oncology Progra...
# 16       pdac16  This is an independent visit     Patient ID:  ...
# 17       pdac17    SUBJECTIVE:  This is a very pleasant 65-year...
# 18       pdac18    This is an independent visit    SUBJECTIVE  ...
# 19       pdac19  Mr. ***** is a 51 y.o. male who comes to our G...
# 20         BC20  ID: ***** ***** is a 81 y.o. postmenopausal pa...
# 21         BC21                           UCSF ***** ***** FAMI...
# 22         BC22  *****  60 yo F    Chief complaint: Patient wit...
# 23         BC23  ID: 71 year old female    CC:  HR low, HER2 ne...
# 24         BC24  ID: ***** ***** is a 55 y.o. ***** with a rece...
# 25         BC25  ***** ***** is a 53 y.o. female with newly dia...
# 26         BC26  This is a shared visit for services provided b...
# 27         BC27    Chief complaint: Patient with breast cancer ...
# 28         BC28  ID: ***** ***** is a 31 y.o. premenopausal fem...
# 29         BC29  HPI:  ***** ***** is a 32 y.o. female here in ...
# 30         BC30  Subjective:       Patient ID: ***** ***** ****...
# 31         BC31  ID: ***** ***** ***** is a 67 y.o. postmenopau...
# 32         BC32  HPI:  ***** ***** is a 36 y.o. female with a r...
# 33         BC33  HPI:  ***** ***** is a 34 y.o. female here in ...
# 34         BC34  ID: ***** ***** is a 33 y.o. premenopausal pat...
# 35         BC35                              UCSF ***** ***** F...
# 36         BC36  HPI:  ***** ***** ***** is a 58 y.o. female he...
# 37         BC37  HPI:  ***** ***** is a 32 y.o. female here for...
# 38         BC38  SUBJECTIVE    ***** ***** is a 49 y.o. female ...
# 39         BC39  New patient Visit  Breast Cancer *****    ****...
#
#                                   Current Medications  \
# 0                                                none
# 1   ALPRAZolam (XANAX) 0.25 mg tablet Take 1 table...
# 2   acetaminophen (TYLENOL ORAL) Take 200 mg by mo...
# 3   buPROPion (WELLBUTRIN SR) 100 mg 12 hr tablet ...
# 4   butenafine (LOTRIMIN ULTRA) 1 % cream\ncholeca...
# 5                                                none
# 6   bisacodyL (DULCOLAX) 5 mg EC tablet\ncholecalc...
# 7   acetaminophen (TYLENOL PO) take by mouth every...
# 8   albuterol 90 mcg/actuation metered dose inhale...
# 9   diphenoxylate-atropine (LOMOTIL) 2.5-0.025 mg ...
# 10  acetaminophen (TYLENOL) 500 mg tablet Take 1,0...
# 11  0.9 % sodium chloride flush injection syringe,...
# 12  acetaminophen (TYLENOL) 325 mg, Oral, Once PRN...
# 13  amLODIPine (NORVASC) 5 mg, Oral, Daily Schedul...
# 14  acetaminophen (TYLENOL) 500 mg tablet Take 1,0...
# 15  acetaminophen (TYLENOL EXTRA STRENGTH) 500 mg ...
# 16                                               none
# 17  albuterol 90 mcg/actuation metered dose inhale...
# 18  aspirin 81 mg EC tablet\natorvastatin (LIPITOR...
# 19  oxyCODONE-acetaminophen (Percocet) 5-325 mg ta...
# 20  acetaminophen (TYLENOL) 500 mg tablet, amLODIP...
# 21                                    zoledronic acid
# 22  clotrimazole-betamethasone (LOTRISONE) 1-0.05 ...
# 23  acetaminophen (TYLENOL) 325 mg tablet Take 1 t...
# 24                                     No Medications
# 25  ergocalciferol, vitamin D2, (ERGOCALCIFEROL) 5...
# 26  albuterol 90 mcg/actuation metered dose inhale...
# 27  acetaminophen (TYLENOL) 325 mg tablet Take 2 t...
# 28  gabapentin (NEURONTIN) 300 mg capsule, hydroCH...
# 29  CETRORELIX ACETATE (CETROTIDE SUBCUT), Inject ...
# 30  amLODIPine (NORVASC) 5 mg tablet Take 1 tablet...
# 31                   simvastatin (ZOCOR) 20 mg tablet
# 32  cholecalciferol, vitamin D3, (VITAMIN D3 ORAL)...
# 33  ascorbic acid, vitamin C, 500 mg TABSR, Take b...
# 34  buPROPion (WELLBUTRIN SR) 150 mg 12 hr tablet,...
# 35            Hydrochlorothiazide, Potassium, Exforge
# 36  cholecalciferol, vitamin D3, (VITAMIN D3) 2,00...
# 37  ALPRAZolam (XANAX) 0.25 mg tablet, ibuprofen (...
# 38  amoxicillin (AMOXIL) 875 mg tablet, amoxicilli...
# 39                                                NaN
#
#                                      Past Medications Patient Current Age  \
# 0                               Gemcitabine\nAbraxane         47-year-old
# 1                  FOLFIRINOX\nGemcitabine + Abraxane             71 y.o.
# 2   FOLFIRINOX\nFOLFOX\nGemcitabine plus nab-pacli...             74 y.o.
# 3                FOLFIRINOX\ngemcitabine and Abraxane         64-year-old
# 4                                  FOLFIRINOX\nFOLFOX             53 y.o.
# 5                                 modified FOLFIRINOX         63-year-old
# 6                           gemcitabine and Abraxane          68-year-old
# 7   FOLFOX chemotherapy (1 cycle, 06/15/19)\nFOLFI...      69 y.o. female
# 8   FOLFIRINOX x 12 cycles\n5FU & liposomal irinot...      71 y.o. female
# 9   FOLFIRINOX\n5FU & liposomal irinotecan\nnab-pa...      73 y.o. female
# 10  omeprazole (for H. pylori treatment in January...        52 y.o. male
# 11  mFOLFIRINOX (12 cycles)\ngemcitabine and nab-p...        74 y.o. male
# 12  vori\nFOLFIRINOX\nGemcitabine + Capecitabine\n...        78 y.o. male
# 13                                 oxycodone\nTylenol      69 y.o. female
# 14                                                NaN        64 y.o. male
# 15                                               none      86 y.o. female
# 16                                               none        58 y.o. male
# 17                           gemcitabine and Abraxane   65-year-old woman
# 18                           gemcitabine and Abraxane         69-year-old
# 19  metronidazole\nrifaximin\nprobiotics\ndietary ...             51 y.o.
# 20  doxycycline (MONODOX) 100 mg capsule, furosemi...             81 y.o.
# 21                        tamoxifen from 1994 to 1996   73-year-old woman
# 22                                                NaN  60-year-old female
# 23                                                NaN  71-year-old female
# 24                                                NaN  55-year-old female
# 25                                                NaN  53-year-old female
# 26                                                NaN  44-year-old female
# 27                                                NaN  70-year-old female
# 28  polymyxin b-trimethoprim (POLYTRIM) ophthalmic...  31-year-old female
# 29                                                NaN  32-year-old female
# 30                                                NaN  51-year-old female
# 31  LORazepam (ATIVAN) 1 mg tablet Take 1 tab po/s...  67-year-old female
# 32  acetaminophen (TYLENOL) 500 mg tablet, Take 2 ...  36-year-old female
# 33                                                NaN  34-year-old female
# 34                                                NaN  33-year-old female
# 35                                                NaN   59-year-old woman
# 36                                                NaN  58-year-old female
# 37                                                NaN  32-year-old female
# 38                               tamoxifen, letrozole  49-year-old female
# 39                                                NaN  44-year-old female
#
#                                     Current Symptoms   \
# 0   Intermittent abdominal discomfort, usually at ...
# 1   Intermittent fevers for 4-5 days following tre...
# 2   Tolerating POs adequately since stent placemen...
# 3   She does complain of brain fog which she attri...
# 4                  Continues to have some oral thrush
# 5   continued abdominal discomfort particularly on...
# 6   She has no cancer pain but takes oxycodone for...
# 7   She denies any pain at present (currently on o...
# 8   Worsening neuropathy.\nImproved abd pain.\nTro...
# 9   Feels ‘almost normal\nNotes constant saltiness...
# 10  early satiety\nnausea post prandial\nloss of a...
# 11  (+) weight loss\n(+) bloating\n(+) bilirubinur...
# 12  Fevers episodically around 12/20/21 for a few ...
# 13  Appetite has been sluggish in the past few wee...
# 14      HgBA1C running >12\nNo pain. Wounds improved.
# 15  Her energy level is low and her appetite is lo...
# 16  Patient has felt very well.\nHe is exercising ...
# 17  She is very fatigued and sleeps about 12 hours...
# 18  Patient reports increased fatigue over the pas...
# 19  Appetite fair\nsome early satiety and postpran...
# 20  dyspnea, no pain at the site of her breast sur...
# 21  lack of energy and pain in her right hand, dis...
# 22  Patient with early stage breast cancer here to...
# 23        tenderness at biopsy site and around axilla
# 24   mild joint stiffness, in particular in her knees
# 25  No bone pain or any other systemic concerns, N...
# 26  Worsening GERD, nausea, fatigue for 3 days aft...
# 27  Feeling well since surgery, healing well, slig...
# 28  Left breast mass growing rapidly, some discolo...
# 29  Found mass in her right breast while on vacati...
# 30  Left breast still somewhat sore post-surgery, ...
# 31                Feeling well, no new symptoms noted
# 32  No new symptoms noted, patient here for treatm...
# 33           2 cm R breast mass 8 cm from the nipple.
# 34  Right lateral neck lump increasing in size, so...
# 35  Right breast aching that is gradually increasi...
# 36  Mild left breast pain status post lumpectomy r...
# 37         Left breast lump palpated in December 2017
# 38  Minimal joint aches, mild hot flashes and inso...
# 39  Felt a lump in the right breast, two episodes ...
#
#                                         Past symptoms  \
# 0   Several months of vague abdominal discomfort, ...
# 1   Abdominal discomfort and biliary ductal obstru...
# 2   Progressive anorexia and fatigue\nMild thrombo...
# 3   She does complain of brain fog which she attri...
# 4       Presented with abdominal pain and weight loss
# 5   abdominal discomfort, bloating and eventually ...
# 6   symptoms of small bowel obstruction in early J...
# 7   Painless jaundice (May 2019)\nPersistent mid-b...
# 8   Peripheral neuropathy - improved off of treatm...
# 9   Peripheral neuropathy\nDiarrhea with every PO ...
# 10  abdominal pain x1mo\n35lb weight loss\nemesis ...
# 11  weight loss (8 lbs over past month)\ndecline i...
# 12  acute symptomatic anemia\nfever with leukocyto...
# 13  2 months of intermittent epigastric and left s...
# 14  03/19/17 he presented to ***** with 3 weeks of...
# 15  November 2018: Presented to her primary care d...
# 16  October 2017: abd pain. Seen in ED sent home.\...
# 17  Severe adverse events including metabolic abno...
# 18  Presented with abdominal pain and weight loss ...
# 19  intermittent mid/LUQ abdominal discomfort\nblo...
# 20  painful mass in her right breast, firm mobile ...
# 21  neuropathy of the right hand associated with a...
# 22                    felt a mass in her right breast
# 23  chronic back and shoulder pain x 2 years, chro...
# 24      Felt lump in her left breast in February 2017
# 25                             None explicitly stated
# 26                             None explicitly stated
# 27  Left breast mass, numbness of L axilla and L e...
# 28  Palpated a mass in her left breast while breas...
# 29                             None explicitly stated
# 30                             None explicitly stated
# 31    Felt a mass in her right breast in late January
# 32  Felt a mass in her right breast while on vacat...
# 33  Self-palpated right breast mass in December 2018.
# 34                             None explicitly stated
# 35  Left breast had an area of increased density, ...
# 36  Left breast mass measuring 2cm after feeling a...
# 37                             None explicitly stated
# 38  Left breast mass, history of postoperative nau...
# 39                             None explicitly stated
#
#                                    Chronic Conditions  \
# 0   Hypertension, voluntarily stopped his antihype...
# 1   COPD (chronic obstructive pulmonary disease) (...
# 2                        Metastatic pancreatic cancer
# 3           Metastatic adenocarcinoma of the pancreas
# 4   Stage IV pancreatic adenocarcinoma\nBiopsy-pro...
# 5   Borderline resectable/locally advanced adenoca...
# 6   Chronic opioid use\narthritis\nchronic back pa...
# 7   Hypertension\nHyperlipidemia\nAdenomatous poly...
# 8   Asthma\nBreast cancer (HCC)\nDifficult intubat...
# 9   Diabetes with A1C 10\nLocally advanced pancrea...
# 10  Borderline hypertension\nDiabetes (CMS code) M...
# 11  Pancreatic adenocarcinoma\nDiabetes\nHypertension
# 12  Pancreatic adenocarcinoma\nProstate cancer\nCa...
# 13  HTN\nDyslipidemia\nPre-diabetes\nLumbar stenos...
# 14  Arthritis\nHistory of continuous positive airw...
# 15  Pancreatic adenocarcinoma\nOrthostatic hypoten...
# 16            Locally advanced pMMR pancreatic cancer
# 17  Hypertension\nHistory of hypothyroidism\nAsthm...
# 18  Locally advanced and unresectable adenocarcino...
# 19  Anxiety\nEnvironmental allergies\nmetastatic p...
# 20  Cardiac pacemaker in situ, Cataract, CHF (cong...
# 21  osteoarthritis in the left hand, trace emphyse...
# 22  Abnormal liver enzymes 2012, Hyperbilirubinemi...
# 23  Cataract, Elevated CA-125, GERD (gastroesophag...
# 24        Breast cancer, Diabetes 08/09/2017, Obesity
# 25                   Breast cancer, Diabetes mellitus
# 26  Lynch syndrome, Colon cancer (HCC), Metastatic...
# 27  Arthritis, Breast cancer (left side), Cataract...
# 28  Stage III HR+/HER2- IDC of the left breast, Hy...
# 29  Breast cancer, right breast, Closed left ankle...
# 30  Migraine, Chronic low back pain, Right-sided l...
# 31  Breast cancer, Fibrocystic breast disease, Lip...
# 32                      Breast cancer, Hypothyroidism
# 33  Bipolar 2 disorder, Insomnia, Breast Cancer Right
# 34  Back pain, Breast cancer, Depression, Hyperten...
# 35  Hypertension (for 30 years), Hysterectomy and ...
# 36                         Breast cancer, left breast
# 37                                       ATM mutation
# 38  ER+/PR-/HER2- left breast cancer, Endometriosi...
# 39                                Breast cancer (HCC)
#
#                                        family history  \
# 0   There is no cancer among his first-degree rela...
# 1   Father Pancreatic cancer\nMaternal Uncle Pancr...
# 2   Comprehensive past medical, family, and social...
# 3                                                none
# 4   Past medical, social, and family history were ...
# 5                                                none
# 6   The only cancer in her family is in maternal a...
# 7   Paternal grandmother with esophageal cancer\nM...
# 8   Stomach cancer Mother  71\nColon cancer Sister...
# 9   No new updates, reviewed and unchanged from pr...
# 10  Breast cancer (Mother)\nProstate cancer (Fathe...
# 11             No updates from prior visits, per note
# 12  Hearing loss (Mother)\nHeart disease (Mother)\...
# 13  Reviewed; no hereditary pattern of cancer note...
# 14                                               none
# 15  Past medical, social, and family history: Unch...
# 16                                               none
# 17  Her father had prostate cancer.\nShe has 3 pat...
# 18  She has 4 siblings. One sister was diagnosed w...
# 19  Ovarian cancer – Mother\nLung cancer – Materna...
# 20  Stroke (Mother), Uterine cancer (Mother) age 4...
# 21  one maternal aunt with breast cancer at the ag...
# 22  Breast cancer in her sister, Cancer (age of on...
# 23  Cancer Mother 35 - breast cancer, Hypertension...
# 24              Breast cancer Maternal Grandmother 58
# 25  Family history unknown: Yes, no h/o malignancy...
# 26  Leukemia Mother - as a child, in remission, Ot...
# 27  Paternal grandmother passed away from breast c...
# 28  Lymphoma Father, No family history of breast c...
# 29  Lung cancer - Father (Age 68), Melanoma - Mate...
# 30  Hypertension - Mother, Arthritis - Mother, Dep...
# 31  Breast cancer - Mother (early 50s, had unilate...
# 32                             Breast cancer - Cousin
# 33  Alzheimer's disease - Paternal Grandfather, Al...
# 34  Cerebral aneurysm - Father, Melanoma - Negativ...
# 35  Mother had Parkinson's disease, does not know ...
# 36  Breast cancer - Paternal Grandmother (Age 35),...
# 37  Breast cancer - Mother, Breast cancer - Other ...
# 38  Mother had Parkinson's disease, does not know ...
# 39  Colon cancer - Father (diagnosed in late 40s, ...
#
#                                      Reason for visit  \
# 0   He would like to meet with psycho oncology as ...
# 1   Mr. ***** is a 71 y.o. male who returns to our...
# 2   Mr. ***** is a 74 y.o. male who returns to our...
# 3   She’ll continue on surveillance and we will se...
# 4   Mr. ***** is a 53 y.o. male who returns to our...
# 5   I’m very concerned about her imaging studies. ...
# 6   She is now had 4 full cycles and returns for C...
# 7   Ms. ***** is a 69 y.o. female who comes to our...
# 8   Patient presents with Pancreatic Cancer Follow-up
# 9   Follow-up of her locally advanced pancreatic c...
# 10  Newly diagnosed metastatic pancreatic cancer\n...
# 11  Follow up visit of pancreatic adenocarcinoma w...
# 12                 Patient presents for consideration
# 13  Ms. ***** is a 69 y.o. female whom I am seeing...
# 14  Patient presents with Follow-up\n presents tod...
# 15  86 y.o. female who presents to our GI Oncology...
# 16  Patient prefers to hold off on any additional ...
# 17            Surveillance scan h/o pancreatic cancer
# 18  Patient is now s/p 2 cycles of FOLFIRINOX. She...
# 19  Mr. ***** is a 51 y.o. male who comes to our G...
# 20  presents in consultation to discuss treatment ...
# 21  she comes here today for a discussion of poten...
# 22  The patient has been referred to discuss neoad...
# 23  Patient with R breast cancer here for discussi...
# 24  Patient with a recent diagnosis of early stage...
# 25  Newly diagnosed HR-negative HER2+ breast cance...
# 26  Newly diagnosed metastatic breast cancer to li...
# 27  Patient with a recent diagnosis of stage IIA p...
# 28  31-year-old female with a history of Stage III...
# 29  Consultation to discuss treatment options for ...
# 30  51-year-old female with biopsy-proven left bre...
# 31  67-year-old postmenopausal patient with a clin...
# 32  36-year-old female with a newly diagnosed horm...
# 33  34-year-old premenopausal woman with HR+ right...
# 34  33-year-old premenopausal patient with a recen...
# 35  Consultation regarding treatment of her newly ...
# 36  58-year-old postmenopausal woman with a T2N1 g...
# 37  32-year-old female ATM mutation carrier with n...
# 38  49-year-old woman with a history of HR+ low-ri...
# 39  44-year-old premenopausal female with a recent...
#
#                Primary diagnosis (should be only one)  \
# 0     Locally advanced adenocarcinoma of the pancreas
# 1                      Adenocarcinoma of the pancreas
# 2                        Metastatic pancreatic cancer
# 3           Metastatic adenocarcinoma of the pancreas
# 4                  Stage IV pancreatic adenocarcinoma
# 5   Borderline resectable/locally advanced adenoca...
# 6   Adenocarcinoma the tail of the pancreas with l...
# 7      Recurrent metastatic pancreatic adenocarcinoma
# 8                        Metastatic pancreatic cancer
# 9                  Locally advanced pancreatic cancer
# 10                       Metastatic pancreatic cancer
# 11                          Pancreatic adenocarcinoma
# 12                          Pancreatic adenocarcinoma
# 13               Metastatic pancreatic adenocarcinoma
# 14                         Resected pancreatic cancer
# 15                          Pancreatic adenocarcinoma
# 16            Locally advanced pMMR pancreatic cancer
# 17  Adenocarcinoma of the tail of the pancreas, st...
# 18  Localized adenocarcinoma of the pancreas, on t...
# 19               metastatic pancreatic adenocarcinoma
# 20      Stage II (T2N1) triple negative breast cancer
# 21  locally recurrent, unresectable, hormone-recep...
# 22  ER Negative, PR Negative, HER2 Negative right ...
# 23   HR low, HER2 negative cancer of the right breast
# 24  Stage III (T3N1) HR+/HER2- grade 3 IDC of the ...
# 25                    HR-negative HER2+ breast cancer
# 26  Metastatic ER-negative, HER2-negative breast c...
# 27  Stage IIA pT2(m)N1a left breast invasive ducta...
# 28  Locally advanced, unresectable HR+/HER2- breas...
# 29  Grade 2 ER+ breast cancer, T2N1, clinical stag...
# 30                    Ductal carcinoma in situ (DCIS)
# 31  Clinical stage II HR+/HER2- invasive ductal ca...
# 32        HR+/HER2- node positive right breast cancer
# 33               HR+ right breast cancer, grade 1 IDC
# 34  HR+ metastatic breast cancer involving lymph n...
# 35  Clinical stage III lobular carcinoma of the le...
# 36  Stage IIb (T2N1M0) Grade 2 IDC (ER pos/PR pos/...
# 37     Clinical T2NX ER+/PR-/HER2- left breast cancer
# 38                HR+ low-risk IDC of the left breast
# 39  Bilateral breast cancer, ER+ on both sides, HE...
#
#                                       Procedure names  \
# 0   CT scan ERCP with an EUS at ***** on October 2...
# 1   ERCP and stent was placed\nWhipple for pancrea...
# 2   EGD (03/16/2019) notable for partial gastric o...
# 3   EGD and ERCP\nCT Abdomen /Pelvis with Contrast...
# 4   CT of the abdomen\nCT PET”\nEUS directed FNA o...
# 5   metal stent was placed on May 29\nEUS done on ...
# 6   EUS was done but biopsy was not attempted\nCT ...
# 7   EUS-guided FNA (05/18/19)\nERCPs for biliary s...
# 8   EUS: Celiac block October 2016 with relief\nIR...
# 9   EUS with biopsy\nCT AP with contrast\nCT chest...
# 10  CT AP\nEGD/EUS\nFNA/FNB Path\nCT Chest\nCA 19-...
# 11  CT abdomen\nEUS\nFNA of pancreatic mass\nDiagn...
# 12  CT Abdomen /Pelvis with and without Contrast\n...
# 13  Liver biopsy by I.R., performed on 07/06/2021\...
# 14  endoscopic US, stent placement in the strictur...
# 15  ERCP 12/13/18: (Tbili at that time 14.7) high ...
# 16  A first endoscopy showed no abnormalities in t...
# 17  Fine needle aspiration of the mass by EUS\nCT ...
# 18  CT scan of the abdomen done on 03/08/2017.\nEU...
# 19  EGD\ncolonoscopy with 2 tubular adenomas in th...
# 20  Fine Needle Aspiration, BIOPSY / EXCISION BREA...
# 21  right breast mass removed, axillary lymph node...
# 22  US guided CNB, Bilateral diagnostic mammo, US ...
# 23  Bilateral Breast MRI, R Breast Ultrasound, Cor...
# 24  Diagnostic mammogram, Targeted left breast ult...
# 25  Right diagnostic mammogram with 3D Tomo, Right...
# 26  Right diagnostic mammogram with 3D Tomo, Right...
# 27  Screening mammogram, Diagnostic mammogram, Ult...
# 28  Bilateral breast ultrasound, US-guided core bi...
# 29  Diagnostic mammogram and ultrasound, Core biop...
# 30  Screening mammography, Diagnostic mammography,...
# 31  Right breast partial mastectomy, Fine needle a...
# 32  Mammogram, Ultrasound-guided core biopsy, MRI ...
# 33  Bilateral breast ultrasound, Right breast FNA,...
# 34  Neck ultrasound, US-guided right supraclavicul...
# 35  Fine needle aspiration of left axillary lymph ...
# 36  Bilateral diagnostic mammogram, Left breast ul...
# 37  Left breast ultrasound, Left diagnostic mammog...
# 38  Screening mammogram, Bilateral ultrasound, Cor...
# 39  Bilateral ultrasound, CT scan, PET/CT (planned...
#
#             Information relevant to primary diagnosis  Age  Gender
# 0   CT scan was done which revealed a pancreatic m...   47    male
# 1   He presented with abdominal discomfort and bil...   71    male
# 2   He initially received 4 cycles of FOLFIRINOX, ...   74    male
# 3   She presented in June 2020 and was thought to ...   64  female
# 4   On 01/10/2019, he had a CT of the abdomen whic...   53    male
# 5   She presented in February with abdominal disco...   63  female
# 6   She was hospitalized and treated conservativel...   68  female
# 7   Known germline ATM mutation\nInitially diagnos...   69  female
# 8   BRCA variant of unknown significance in the se...   71  female
# 9   4.4 x 3.5 cm mass in pancreatic body with upst...   73  female
# 10  03/16/21: CT AP: Pancreatic cystic lesion >/= ...   52    male
# 11  CT abdomen was obtained which revealed a 7.5x3...   74    male
# 12  Pancreatic adenocarcinoma located in pancreati...   78    male
# 13  Metastatic pancreatic adenocarcinoma causing m...   69  female
# 14  03/19/17 he presented to ***** with 3 weeks of...   64    male
# 15  Given her age, comorbidities and preference, s...   86  female
# 16  October 2017: abd pain. Seen in ED sent home.\...   58    male
# 17  An abdominal CT scan was done during her admis...   65  female
# 18  CT scan of the abdomen done on 03/08/2017 show...   69  female
# 19  began developing intermittent mid/LUQ abdomina...   51    male
# 20  81 y.o. postmenopausal patient with multiple m...   81    male
# 21  Based on all of this information, it appears t...   73  female
# 22  60 year old female with ER Negative, PR Negati...   60  female
# 23  Hypermetabolic (FDG avid) right lateral breast...   71  female
# 24  High clinical risk features, including tumor s...   55  female
# 25  Her PET CT is suspicious for bone metastasis. ...   53  female
# 26  Metastatic breast cancer with axillary pain im...   44  female
# 27  Stage IIA IDC with known lymph node involvemen...   70  female
# 28  Recurrent, unresectable HR+/HER2- breast cance...   31  female
# 29  Patient diagnosed with Grade 2 ER+ right breas...   32  female
# 30  Left breast DCIS, intermediate nuclear grade, ...   51  female
# 31  Clinical stage II HR+/HER2- IDC of the right b...   67  female
# 32  HR+/HER2- node positive right breast cancer wi...   36  female
# 33  HR+ right breast cancer, grade 1 IDC, 1-2.2 cm...   34  female
# 34  HR+ metastatic breast cancer with axillary, su...   33  female
# 35  Clinical stage III lobular carcinoma of the le...   59  female
# 36  Stage IIb IDC with multifocal disease and pote...   58  female
# 37  Left breast cancer with high-risk Mammaprint s...   32  female
# 38  HR+ low-risk IDC of the left breast, no eviden...   49  female
# 39  44-year-old premenopausal female with newly di...   44  female

# %%
# A set to keep track of unique methods encountered.
unique_methods = set()

# List of known method options (all lower case). Add new options as encountered.
METHOD_OPTIONS = {
    "tablet", "patch", "capsule", "gel", "ointment", "suspension", "solution",
    "cream", "drops", "injection", "ec tablet", "topical ointment"
}

def process_medication_entry(entry):
    """
    Process a single medication string.
    Returns a dictionary with:
      - "drug": a list of names (the main name and alternative names if in parentheses)
      - "dosage": dosage string (if any)
      - "method": method string (if any)
    """
    # Clean the entry by removing parenthetical notes with dates or patient notes.
    # Remove any parenthetical parts that mention "reported" or "patient"
    entry = re.sub(r'\(.*?(reported|patient).*?\)', '', entry, flags=re.IGNORECASE).strip()

    # Remove any prefix like "UNABLE TO FIND Med Name:"
    entry = entry.replace("UNABLE TO FIND Med Name:", "").strip()

    # If the cleaned entry is just "none" (case insensitive), return that.
    if entry.lower() == "none":
        return {"drug": ["none"], "dosage": None, "method": None}

    # Split the entry by whitespace
    tokens = entry.split()

    # Find first token that starts with a digit (assume that's where dosage info begins)
    dosage_index = None
    for i, token in enumerate(tokens):
        if re.match(r'^\d', token):
            dosage_index = i
            break

    if dosage_index is None:
        # No dosage found: assume the whole entry is the drug name.
        # Try to extract alternative names from any parentheses.
        drug_names = extract_drug_names(" ".join(tokens))
        return {"drug": drug_names, "dosage": None, "method": None}

    # The drug part is the tokens before the dosage starts.
    drug_part = " ".join(tokens[:dosage_index])
    drug_names = extract_drug_names(drug_part)

    # Now, consider tokens from dosage_index onward.
    dosage_and_rest = tokens[dosage_index:]

    # We try to identify the method from the end.
    # Check first if the last two tokens form a known method option:
    method = None
    if len(dosage_and_rest) >= 2:
        possible_method = " ".join(dosage_and_rest[-2:]).lower()
        if possible_method in METHOD_OPTIONS:
            method = possible_method
            dosage_tokens = dosage_and_rest[:-2]
        else:
            # Otherwise, check if the last token is in our options.
            possible_method = dosage_and_rest[-1].lower()
            if possible_method in METHOD_OPTIONS:
                method = possible_method
                dosage_tokens = dosage_and_rest[:-1]
            else:
                # If not recognized, assume the last token is still the method.
                method = possible_method
                dosage_tokens = dosage_and_rest[:-1]
    else:
        # Only one token remains: treat it as method.
        method = dosage_and_rest[-1].lower()
        dosage_tokens = dosage_and_rest[:-1]

    # Save the encountered method in our unique_methods set.
    unique_methods.add(method)

    dosage = " ".join(dosage_tokens).strip() if dosage_tokens else None

    return {"drug": drug_names, "dosage": dosage, "method": method}

def extract_drug_names(text):
    """
    Given a string representing the drug part, extract the main drug name and any alternative names
    contained in parentheses.
    Returns a list of drug names.
    """
    # Find all text inside parentheses.
    alt_names = re.findall(r'\((.*?)\)', text)
    # Remove the parentheses parts from the main text.
    main_name = re.sub(r'\(.*?\)', '', text).strip()
    # Clean up main name: remove trailing commas etc.
    main_name = main_name.rstrip(",")

    names = []
    if main_name:
        names.append(main_name)
    for name in alt_names:
        cleaned = name.strip()
        if cleaned:
            names.append(cleaned)
    return names

def process_medications_cell(cell_value):
    """
    Process a cell from a medications column.
    Each cell may contain multiple medication entries separated by newlines.
    Returns three lists: list of drug entries (each a list of names), list of dosages, list of methods.
    """
    if pd.isnull(cell_value):
        return {"drug": [], "dosage": [], "method": []}

    # Split by newline (assumes each line is one medication entry)
    entries = [entry.strip() for entry in str(cell_value).split('\n') if entry.strip()]
    drugs = []
    dosages = []
    methods = []

    for entry in entries:
        result = process_medication_entry(entry)
        drugs.append(result["drug"])
        dosages.append(result["dosage"])
        methods.append(result["method"])

    return {"drug": drugs, "dosage": dosages, "method": methods}

# Example usage on a list of medication entries (for testing):
test_entries = [
    "bisacodyL (DULCOLAX) 5 mg EC tablet",
    "cholecalciferol, vitamin D3, 1000 UNITS tablet",
    "cloNIDine (CATAPRES) 0.1 mg/24 hr patch",
    "cyanocobalamin, Vitamin B12, (VITAMIN B-12) 500 mcg tablet",
    "diclofenac (VOLTAREN) 1 % gel",
    "docusate sodium (COLACE) 100 mg capsule",
    "fexofenadine (ALLEGRA) 60 mg tablet",
    "fluocinonide (LIDEX) 0.05 % ointment",
    "LORazepam (ATIVAN) 1 mg tablet",
    "ondansetron (ZOFRAN) 8 mg tablet (Patient not taking: Reported on 12/07/2020)",
    "oxybutynin (DITROPAN XL) 5 mg 24 hr tablet",
    "oxyCODONE (OXY-IR) 5 mg capsule",
    "pantoprazole (PROTONIX) 40 mg EC tablet",
    "prochlorperazine (COMPAZINE) 10 mg tablet (Patient not taking: Reported on 12/07/2020)",
    "senna (SENOKOT) 8.6 mg tablet",
    "UNABLE TO FIND Med Name: Equi-Block topical ointment"
]

print("Testing individual entries:")
for entry in test_entries:
    result = process_medication_entry(entry)
    print(f"Entry: {entry}")
    print(f"Processed -> Drug: {result['drug']}, Dosage: {result['dosage']}, Method: {result['method']}\n")

print("Unique method options encountered:", unique_methods)


# Process the medications columns.
combined_df['current_meds_processed'] = combined_df['Current Medications'].apply(process_medications_cell)
combined_df['past_meds_processed'] = combined_df['Past Medications'].apply(process_medications_cell)

# If you want to expand these into separate columns, you might do something like:
# (This creates new columns: current_drug, current_dosage, current_method, etc.)
combined_df['current_drug'] = combined_df['current_meds_processed'].apply(lambda x: x['drug'])
combined_df['current_dosage'] = combined_df['current_meds_processed'].apply(lambda x: x['dosage'])
combined_df['current_method'] = combined_df['current_meds_processed'].apply(lambda x: x['method'])

combined_df['past_drug'] = combined_df['past_meds_processed'].apply(lambda x: x['drug'])
combined_df['past_dosage'] = combined_df['past_meds_processed'].apply(lambda x: x['dosage'])
combined_df['past_method'] = combined_df['past_meds_processed'].apply(lambda x: x['method'])

combined_df
# Out:
# Testing individual entries:
# Entry: bisacodyL (DULCOLAX) 5 mg EC tablet
# Processed -> Drug: ['bisacodyL', 'DULCOLAX'], Dosage: 5 mg, Method: ec tablet
#
# Entry: cholecalciferol, vitamin D3, 1000 UNITS tablet
# Processed -> Drug: ['cholecalciferol, vitamin D3'], Dosage: 1000 UNITS, Method: tablet
#
# Entry: cloNIDine (CATAPRES) 0.1 mg/24 hr patch
# Processed -> Drug: ['cloNIDine', 'CATAPRES'], Dosage: 0.1 mg/24 hr, Method: patch
#
# Entry: cyanocobalamin, Vitamin B12, (VITAMIN B-12) 500 mcg tablet
# Processed -> Drug: ['cyanocobalamin, Vitamin B12', 'VITAMIN B-12'], Dosage: 500 mcg, Method: tablet
#
# Entry: diclofenac (VOLTAREN) 1 % gel
# Processed -> Drug: ['diclofenac', 'VOLTAREN'], Dosage: 1 %, Method: gel
#
# Entry: docusate sodium (COLACE) 100 mg capsule
# Processed -> Drug: ['docusate sodium', 'COLACE'], Dosage: 100 mg, Method: capsule
#
# Entry: fexofenadine (ALLEGRA) 60 mg tablet
# Processed -> Drug: ['fexofenadine', 'ALLEGRA'], Dosage: 60 mg, Method: tablet
#
# Entry: fluocinonide (LIDEX) 0.05 % ointment
# Processed -> Drug: ['fluocinonide', 'LIDEX'], Dosage: 0.05 %, Method: ointment
#
# Entry: LORazepam (ATIVAN) 1 mg tablet
# Processed -> Drug: ['LORazepam', 'ATIVAN'], Dosage: 1 mg, Method: tablet
#
# Entry: ondansetron (ZOFRAN) 8 mg tablet (Patient not taking: Reported on 12/07/2020)
# Processed -> Drug: ['ondansetron'], Dosage: None, Method: None
#
# Entry: oxybutynin (DITROPAN XL) 5 mg 24 hr tablet
# Processed -> Drug: ['oxybutynin', 'DITROPAN XL'], Dosage: 5 mg 24 hr, Method: tablet
#
# Entry: oxyCODONE (OXY-IR) 5 mg capsule
# Processed -> Drug: ['oxyCODONE', 'OXY-IR'], Dosage: 5 mg, Method: capsule
#
# Entry: pantoprazole (PROTONIX) 40 mg EC tablet
# Processed -> Drug: ['pantoprazole', 'PROTONIX'], Dosage: 40 mg, Method: ec tablet
#
# Entry: prochlorperazine (COMPAZINE) 10 mg tablet (Patient not taking: Reported on 12/07/2020)
# Processed -> Drug: ['prochlorperazine'], Dosage: None, Method: None
#
# Entry: senna (SENOKOT) 8.6 mg tablet
# Processed -> Drug: ['senna', 'SENOKOT'], Dosage: 8.6 mg, Method: tablet
#
# Entry: UNABLE TO FIND Med Name: Equi-Block topical ointment
# Processed -> Drug: ['Equi-Block topical ointment'], Dosage: None, Method: None
#
# Unique method options encountered: {'tablet', 'ec tablet', 'patch', 'capsule', 'ointment', 'gel'}
#    Patient Note                                Entire Patient Note  \
# 0         pdac0  SUBJECTIVE:    This is a very pleasant 47-year...
# 1         pdac1  This is an independent visit    ATTENDING: ***...
# 2         pdac2  Mr. ***** is a 74 y.o. male who returns to our...
# 3         pdac3  SUBJECTIVE:    This is a very pleasant 64-year...
# 4         pdac4  This is an independent service.  The available...
# 5         pdac5  Subjective:    This is a very pleasant 63-year...
# 6         pdac6  SUBJECTIVE:    This is a very pleasant 68-year...
# 7         pdac7  Ms. ***** is a 69 y.o. female who comes to our...
# 8         pdac8  REASON FOR VISIT/CC:   Chief Complaint   Patie...
# 9         pdac9  FOLLOW UP VISIT    Ms. ***** is a 73 y.o. fema...
# 10       pdac10  INITIAL GI MEDICAL ONCOLOGY VISIT     Patient ...
# 11       pdac11  I had the pleasure of seeing ***** ***** for f...
# 12       pdac12    FOLLOW UP GASTROINTESTINAL MEDICAL ONCOLOGY ...
# 13       pdac13  VIDEO VISIT  I performed this consultation usi...
# 14       pdac14  REASON FOR VISIT/CC:   Chief Complaint   Patie...
# 15       pdac15   UCSF Cancer Center GI Medical Oncology Progra...
# 16       pdac16  This is an independent visit     Patient ID:  ...
# 17       pdac17    SUBJECTIVE:  This is a very pleasant 65-year...
# 18       pdac18    This is an independent visit    SUBJECTIVE  ...
# 19       pdac19  Mr. ***** is a 51 y.o. male who comes to our G...
# 20         BC20  ID: ***** ***** is a 81 y.o. postmenopausal pa...
# 21         BC21                           UCSF ***** ***** FAMI...
# 22         BC22  *****  60 yo F    Chief complaint: Patient wit...
# 23         BC23  ID: 71 year old female    CC:  HR low, HER2 ne...
# 24         BC24  ID: ***** ***** is a 55 y.o. ***** with a rece...
# 25         BC25  ***** ***** is a 53 y.o. female with newly dia...
# 26         BC26  This is a shared visit for services provided b...
# 27         BC27    Chief complaint: Patient with breast cancer ...
# 28         BC28  ID: ***** ***** is a 31 y.o. premenopausal fem...
# 29         BC29  HPI:  ***** ***** is a 32 y.o. female here in ...
# 30         BC30  Subjective:       Patient ID: ***** ***** ****...
# 31         BC31  ID: ***** ***** ***** is a 67 y.o. postmenopau...
# 32         BC32  HPI:  ***** ***** is a 36 y.o. female with a r...
# 33         BC33  HPI:  ***** ***** is a 34 y.o. female here in ...
# 34         BC34  ID: ***** ***** is a 33 y.o. premenopausal pat...
# 35         BC35                              UCSF ***** ***** F...
# 36         BC36  HPI:  ***** ***** ***** is a 58 y.o. female he...
# 37         BC37  HPI:  ***** ***** is a 32 y.o. female here for...
# 38         BC38  SUBJECTIVE    ***** ***** is a 49 y.o. female ...
# 39         BC39  New patient Visit  Breast Cancer *****    ****...
#
#                                   Current Medications  \
# 0                                                none
# 1   ALPRAZolam (XANAX) 0.25 mg tablet Take 1 table...
# 2   acetaminophen (TYLENOL ORAL) Take 200 mg by mo...
# 3   buPROPion (WELLBUTRIN SR) 100 mg 12 hr tablet ...
# 4   butenafine (LOTRIMIN ULTRA) 1 % cream\ncholeca...
# 5                                                none
# 6   bisacodyL (DULCOLAX) 5 mg EC tablet\ncholecalc...
# 7   acetaminophen (TYLENOL PO) take by mouth every...
# 8   albuterol 90 mcg/actuation metered dose inhale...
# 9   diphenoxylate-atropine (LOMOTIL) 2.5-0.025 mg ...
# 10  acetaminophen (TYLENOL) 500 mg tablet Take 1,0...
# 11  0.9 % sodium chloride flush injection syringe,...
# 12  acetaminophen (TYLENOL) 325 mg, Oral, Once PRN...
# 13  amLODIPine (NORVASC) 5 mg, Oral, Daily Schedul...
# 14  acetaminophen (TYLENOL) 500 mg tablet Take 1,0...
# 15  acetaminophen (TYLENOL EXTRA STRENGTH) 500 mg ...
# 16                                               none
# 17  albuterol 90 mcg/actuation metered dose inhale...
# 18  aspirin 81 mg EC tablet\natorvastatin (LIPITOR...
# 19  oxyCODONE-acetaminophen (Percocet) 5-325 mg ta...
# 20  acetaminophen (TYLENOL) 500 mg tablet, amLODIP...
# 21                                    zoledronic acid
# 22  clotrimazole-betamethasone (LOTRISONE) 1-0.05 ...
# 23  acetaminophen (TYLENOL) 325 mg tablet Take 1 t...
# 24                                     No Medications
# 25  ergocalciferol, vitamin D2, (ERGOCALCIFEROL) 5...
# 26  albuterol 90 mcg/actuation metered dose inhale...
# 27  acetaminophen (TYLENOL) 325 mg tablet Take 2 t...
# 28  gabapentin (NEURONTIN) 300 mg capsule, hydroCH...
# 29  CETRORELIX ACETATE (CETROTIDE SUBCUT), Inject ...
# 30  amLODIPine (NORVASC) 5 mg tablet Take 1 tablet...
# 31                   simvastatin (ZOCOR) 20 mg tablet
# 32  cholecalciferol, vitamin D3, (VITAMIN D3 ORAL)...
# 33  ascorbic acid, vitamin C, 500 mg TABSR, Take b...
# 34  buPROPion (WELLBUTRIN SR) 150 mg 12 hr tablet,...
# 35            Hydrochlorothiazide, Potassium, Exforge
# 36  cholecalciferol, vitamin D3, (VITAMIN D3) 2,00...
# 37  ALPRAZolam (XANAX) 0.25 mg tablet, ibuprofen (...
# 38  amoxicillin (AMOXIL) 875 mg tablet, amoxicilli...
# 39                                                NaN
#
#                                      Past Medications Patient Current Age  \
# 0                               Gemcitabine\nAbraxane         47-year-old
# 1                  FOLFIRINOX\nGemcitabine + Abraxane             71 y.o.
# 2   FOLFIRINOX\nFOLFOX\nGemcitabine plus nab-pacli...             74 y.o.
# 3                FOLFIRINOX\ngemcitabine and Abraxane         64-year-old
# 4                                  FOLFIRINOX\nFOLFOX             53 y.o.
# 5                                 modified FOLFIRINOX         63-year-old
# 6                           gemcitabine and Abraxane          68-year-old
# 7   FOLFOX chemotherapy (1 cycle, 06/15/19)\nFOLFI...      69 y.o. female
# 8   FOLFIRINOX x 12 cycles\n5FU & liposomal irinot...      71 y.o. female
# 9   FOLFIRINOX\n5FU & liposomal irinotecan\nnab-pa...      73 y.o. female
# 10  omeprazole (for H. pylori treatment in January...        52 y.o. male
# 11  mFOLFIRINOX (12 cycles)\ngemcitabine and nab-p...        74 y.o. male
# 12  vori\nFOLFIRINOX\nGemcitabine + Capecitabine\n...        78 y.o. male
# 13                                 oxycodone\nTylenol      69 y.o. female
# 14                                                NaN        64 y.o. male
# 15                                               none      86 y.o. female
# 16                                               none        58 y.o. male
# 17                           gemcitabine and Abraxane   65-year-old woman
# 18                           gemcitabine and Abraxane         69-year-old
# 19  metronidazole\nrifaximin\nprobiotics\ndietary ...             51 y.o.
# 20  doxycycline (MONODOX) 100 mg capsule, furosemi...             81 y.o.
# 21                        tamoxifen from 1994 to 1996   73-year-old woman
# 22                                                NaN  60-year-old female
# 23                                                NaN  71-year-old female
# 24                                                NaN  55-year-old female
# 25                                                NaN  53-year-old female
# 26                                                NaN  44-year-old female
# 27                                                NaN  70-year-old female
# 28  polymyxin b-trimethoprim (POLYTRIM) ophthalmic...  31-year-old female
# 29                                                NaN  32-year-old female
# 30                                                NaN  51-year-old female
# 31  LORazepam (ATIVAN) 1 mg tablet Take 1 tab po/s...  67-year-old female
# 32  acetaminophen (TYLENOL) 500 mg tablet, Take 2 ...  36-year-old female
# 33                                                NaN  34-year-old female
# 34                                                NaN  33-year-old female
# 35                                                NaN   59-year-old woman
# 36                                                NaN  58-year-old female
# 37                                                NaN  32-year-old female
# 38                               tamoxifen, letrozole  49-year-old female
# 39                                                NaN  44-year-old female
#
#                                     Current Symptoms   \
# 0   Intermittent abdominal discomfort, usually at ...
# 1   Intermittent fevers for 4-5 days following tre...
# 2   Tolerating POs adequately since stent placemen...
# 3   She does complain of brain fog which she attri...
# 4                  Continues to have some oral thrush
# 5   continued abdominal discomfort particularly on...
# 6   She has no cancer pain but takes oxycodone for...
# 7   She denies any pain at present (currently on o...
# 8   Worsening neuropathy.\nImproved abd pain.\nTro...
# 9   Feels ‘almost normal\nNotes constant saltiness...
# 10  early satiety\nnausea post prandial\nloss of a...
# 11  (+) weight loss\n(+) bloating\n(+) bilirubinur...
# 12  Fevers episodically around 12/20/21 for a few ...
# 13  Appetite has been sluggish in the past few wee...
# 14      HgBA1C running >12\nNo pain. Wounds improved.
# 15  Her energy level is low and her appetite is lo...
# 16  Patient has felt very well.\nHe is exercising ...
# 17  She is very fatigued and sleeps about 12 hours...
# 18  Patient reports increased fatigue over the pas...
# 19  Appetite fair\nsome early satiety and postpran...
# 20  dyspnea, no pain at the site of her breast sur...
# 21  lack of energy and pain in her right hand, dis...
# 22  Patient with early stage breast cancer here to...
# 23        tenderness at biopsy site and around axilla
# 24   mild joint stiffness, in particular in her knees
# 25  No bone pain or any other systemic concerns, N...
# 26  Worsening GERD, nausea, fatigue for 3 days aft...
# 27  Feeling well since surgery, healing well, slig...
# 28  Left breast mass growing rapidly, some discolo...
# 29  Found mass in her right breast while on vacati...
# 30  Left breast still somewhat sore post-surgery, ...
# 31                Feeling well, no new symptoms noted
# 32  No new symptoms noted, patient here for treatm...
# 33           2 cm R breast mass 8 cm from the nipple.
# 34  Right lateral neck lump increasing in size, so...
# 35  Right breast aching that is gradually increasi...
# 36  Mild left breast pain status post lumpectomy r...
# 37         Left breast lump palpated in December 2017
# 38  Minimal joint aches, mild hot flashes and inso...
# 39  Felt a lump in the right breast, two episodes ...
#
#                                         Past symptoms  \
# 0   Several months of vague abdominal discomfort, ...
# 1   Abdominal discomfort and biliary ductal obstru...
# 2   Progressive anorexia and fatigue\nMild thrombo...
# 3   She does complain of brain fog which she attri...
# 4       Presented with abdominal pain and weight loss
# 5   abdominal discomfort, bloating and eventually ...
# 6   symptoms of small bowel obstruction in early J...
# 7   Painless jaundice (May 2019)\nPersistent mid-b...
# 8   Peripheral neuropathy - improved off of treatm...
# 9   Peripheral neuropathy\nDiarrhea with every PO ...
# 10  abdominal pain x1mo\n35lb weight loss\nemesis ...
# 11  weight loss (8 lbs over past month)\ndecline i...
# 12  acute symptomatic anemia\nfever with leukocyto...
# 13  2 months of intermittent epigastric and left s...
# 14  03/19/17 he presented to ***** with 3 weeks of...
# 15  November 2018: Presented to her primary care d...
# 16  October 2017: abd pain. Seen in ED sent home.\...
# 17  Severe adverse events including metabolic abno...
# 18  Presented with abdominal pain and weight loss ...
# 19  intermittent mid/LUQ abdominal discomfort\nblo...
# 20  painful mass in her right breast, firm mobile ...
# 21  neuropathy of the right hand associated with a...
# 22                    felt a mass in her right breast
# 23  chronic back and shoulder pain x 2 years, chro...
# 24      Felt lump in her left breast in February 2017
# 25                             None explicitly stated
# 26                             None explicitly stated
# 27  Left breast mass, numbness of L axilla and L e...
# 28  Palpated a mass in her left breast while breas...
# 29                             None explicitly stated
# 30                             None explicitly stated
# 31    Felt a mass in her right breast in late January
# 32  Felt a mass in her right breast while on vacat...
# 33  Self-palpated right breast mass in December 2018.
# 34                             None explicitly stated
# 35  Left breast had an area of increased density, ...
# 36  Left breast mass measuring 2cm after feeling a...
# 37                             None explicitly stated
# 38  Left breast mass, history of postoperative nau...
# 39                             None explicitly stated
#
#                                    Chronic Conditions  \
# 0   Hypertension, voluntarily stopped his antihype...
# 1   COPD (chronic obstructive pulmonary disease) (...
# 2                        Metastatic pancreatic cancer
# 3           Metastatic adenocarcinoma of the pancreas
# 4   Stage IV pancreatic adenocarcinoma\nBiopsy-pro...
# 5   Borderline resectable/locally advanced adenoca...
# 6   Chronic opioid use\narthritis\nchronic back pa...
# 7   Hypertension\nHyperlipidemia\nAdenomatous poly...
# 8   Asthma\nBreast cancer (HCC)\nDifficult intubat...
# 9   Diabetes with A1C 10\nLocally advanced pancrea...
# 10  Borderline hypertension\nDiabetes (CMS code) M...
# 11  Pancreatic adenocarcinoma\nDiabetes\nHypertension
# 12  Pancreatic adenocarcinoma\nProstate cancer\nCa...
# 13  HTN\nDyslipidemia\nPre-diabetes\nLumbar stenos...
# 14  Arthritis\nHistory of continuous positive airw...
# 15  Pancreatic adenocarcinoma\nOrthostatic hypoten...
# 16            Locally advanced pMMR pancreatic cancer
# 17  Hypertension\nHistory of hypothyroidism\nAsthm...
# 18  Locally advanced and unresectable adenocarcino...
# 19  Anxiety\nEnvironmental allergies\nmetastatic p...
# 20  Cardiac pacemaker in situ, Cataract, CHF (cong...
# 21  osteoarthritis in the left hand, trace emphyse...
# 22  Abnormal liver enzymes 2012, Hyperbilirubinemi...
# 23  Cataract, Elevated CA-125, GERD (gastroesophag...
# 24        Breast cancer, Diabetes 08/09/2017, Obesity
# 25                   Breast cancer, Diabetes mellitus
# 26  Lynch syndrome, Colon cancer (HCC), Metastatic...
# 27  Arthritis, Breast cancer (left side), Cataract...
# 28  Stage III HR+/HER2- IDC of the left breast, Hy...
# 29  Breast cancer, right breast, Closed left ankle...
# 30  Migraine, Chronic low back pain, Right-sided l...
# 31  Breast cancer, Fibrocystic breast disease, Lip...
# 32                      Breast cancer, Hypothyroidism
# 33  Bipolar 2 disorder, Insomnia, Breast Cancer Right
# 34  Back pain, Breast cancer, Depression, Hyperten...
# 35  Hypertension (for 30 years), Hysterectomy and ...
# 36                         Breast cancer, left breast
# 37                                       ATM mutation
# 38  ER+/PR-/HER2- left breast cancer, Endometriosi...
# 39                                Breast cancer (HCC)
#
#                                        family history  \
# 0   There is no cancer among his first-degree rela...
# 1   Father Pancreatic cancer\nMaternal Uncle Pancr...
# 2   Comprehensive past medical, family, and social...
# 3                                                none
# 4   Past medical, social, and family history were ...
# 5                                                none
# 6   The only cancer in her family is in maternal a...
# 7   Paternal grandmother with esophageal cancer\nM...
# 8   Stomach cancer Mother  71\nColon cancer Sister...
# 9   No new updates, reviewed and unchanged from pr...
# 10  Breast cancer (Mother)\nProstate cancer (Fathe...
# 11             No updates from prior visits, per note
# 12  Hearing loss (Mother)\nHeart disease (Mother)\...
# 13  Reviewed; no hereditary pattern of cancer note...
# 14                                               none
# 15  Past medical, social, and family history: Unch...
# 16                                               none
# 17  Her father had prostate cancer.\nShe has 3 pat...
# 18  She has 4 siblings. One sister was diagnosed w...
# 19  Ovarian cancer – Mother\nLung cancer – Materna...
# 20  Stroke (Mother), Uterine cancer (Mother) age 4...
# 21  one maternal aunt with breast cancer at the ag...
# 22  Breast cancer in her sister, Cancer (age of on...
# 23  Cancer Mother 35 - breast cancer, Hypertension...
# 24              Breast cancer Maternal Grandmother 58
# 25  Family history unknown: Yes, no h/o malignancy...
# 26  Leukemia Mother - as a child, in remission, Ot...
# 27  Paternal grandmother passed away from breast c...
# 28  Lymphoma Father, No family history of breast c...
# 29  Lung cancer - Father (Age 68), Melanoma - Mate...
# 30  Hypertension - Mother, Arthritis - Mother, Dep...
# 31  Breast cancer - Mother (early 50s, had unilate...
# 32                             Breast cancer - Cousin
# 33  Alzheimer's disease - Paternal Grandfather, Al...
# 34  Cerebral aneurysm - Father, Melanoma - Negativ...
# 35  Mother had Parkinson's disease, does not know ...
# 36  Breast cancer - Paternal Grandmother (Age 35),...
# 37  Breast cancer - Mother, Breast cancer - Other ...
# 38  Mother had Parkinson's disease, does not know ...
# 39  Colon cancer - Father (diagnosed in late 40s, ...
#
#                                      Reason for visit  ... Age  Gender  \
# 0   He would like to meet with psycho oncology as ...  ...  47    male
# 1   Mr. ***** is a 71 y.o. male who returns to our...  ...  71    male
# 2   Mr. ***** is a 74 y.o. male who returns to our...  ...  74    male
# 3   She’ll continue on surveillance and we will se...  ...  64  female
# 4   Mr. ***** is a 53 y.o. male who returns to our...  ...  53    male
# 5   I’m very concerned about her imaging studies. ...  ...  63  female
# 6   She is now had 4 full cycles and returns for C...  ...  68  female
# 7   Ms. ***** is a 69 y.o. female who comes to our...  ...  69  female
# 8   Patient presents with Pancreatic Cancer Follow-up  ...  71  female
# 9   Follow-up of her locally advanced pancreatic c...  ...  73  female
# 10  Newly diagnosed metastatic pancreatic cancer\n...  ...  52    male
# 11  Follow up visit of pancreatic adenocarcinoma w...  ...  74    male
# 12                 Patient presents for consideration  ...  78    male
# 13  Ms. ***** is a 69 y.o. female whom I am seeing...  ...  69  female
# 14  Patient presents with Follow-up\n presents tod...  ...  64    male
# 15  86 y.o. female who presents to our GI Oncology...  ...  86  female
# 16  Patient prefers to hold off on any additional ...  ...  58    male
# 17            Surveillance scan h/o pancreatic cancer  ...  65  female
# 18  Patient is now s/p 2 cycles of FOLFIRINOX. She...  ...  69  female
# 19  Mr. ***** is a 51 y.o. male who comes to our G...  ...  51    male
# 20  presents in consultation to discuss treatment ...  ...  81    male
# 21  she comes here today for a discussion of poten...  ...  73  female
# 22  The patient has been referred to discuss neoad...  ...  60  female
# 23  Patient with R breast cancer here for discussi...  ...  71  female
# 24  Patient with a recent diagnosis of early stage...  ...  55  female
# 25  Newly diagnosed HR-negative HER2+ breast cance...  ...  53  female
# 26  Newly diagnosed metastatic breast cancer to li...  ...  44  female
# 27  Patient with a recent diagnosis of stage IIA p...  ...  70  female
# 28  31-year-old female with a history of Stage III...  ...  31  female
# 29  Consultation to discuss treatment options for ...  ...  32  female
# 30  51-year-old female with biopsy-proven left bre...  ...  51  female
# 31  67-year-old postmenopausal patient with a clin...  ...  67  female
# 32  36-year-old female with a newly diagnosed horm...  ...  36  female
# 33  34-year-old premenopausal woman with HR+ right...  ...  34  female
# 34  33-year-old premenopausal patient with a recen...  ...  33  female
# 35  Consultation regarding treatment of her newly ...  ...  59  female
# 36  58-year-old postmenopausal woman with a T2N1 g...  ...  58  female
# 37  32-year-old female ATM mutation carrier with n...  ...  32  female
# 38  49-year-old woman with a history of HR+ low-ri...  ...  49  female
# 39  44-year-old premenopausal female with a recent...  ...  44  female
#
#                                current_meds_processed  \
# 0   {'drug': [['none']], 'dosage': [None], 'method...
# 1   {'drug': [['ALPRAZolam', 'XANAX'], ['atorvasta...
# 2   {'drug': [['acetaminophen  Take', 'TYLENOL ORA...
# 3   {'drug': [['buPROPion', 'WELLBUTRIN SR'], ['es...
# 4   {'drug': [['butenafine', 'LOTRIMIN ULTRA'], ['...
# 5   {'drug': [['none']], 'dosage': [None], 'method...
# 6   {'drug': [['bisacodyL', 'DULCOLAX'], ['choleca...
# 7   {'drug': [['acetaminophen  take by mouth every...
# 8   {'drug': [['albuterol'], ['cetirizine', 'ZYRTE...
# 9   {'drug': [['diphenoxylate-atropine', 'LOMOTIL'...
# 10  {'drug': [['acetaminophen', 'TYLENOL'], ['ibup...
# 11  {'drug': [[], [], [], ['baclofen  tablet', 'LI...
# 12  {'drug': [['acetaminophen', 'TYLENOL'], ['bisa...
# 13  {'drug': [['amLODIPine', 'NORVASC'], ['atorvas...
# 14  {'drug': [['acetaminophen', 'TYLENOL'], ['alph...
# 15  {'drug': [['acetaminophen', 'TYLENOL EXTRA STR...
# 16  {'drug': [['none']], 'dosage': [None], 'method...
# 17  {'drug': [['albuterol'], ['buPROPion'], ['cape...
# 18  {'drug': [['aspirin'], ['atorvastatin', 'LIPIT...
# 19  {'drug': [['oxyCODONE-acetaminophen', 'Percoce...
# 20  {'drug': [['acetaminophen', 'TYLENOL']], 'dosa...
# 21  {'drug': [['zoledronic acid']], 'dosage': [Non...
# 22  {'drug': [['clotrimazole-betamethasone', 'LOTR...
# 23  {'drug': [['acetaminophen , menthol', 'BENGAY ...
# 24  {'drug': [['No Medications']], 'dosage': [None...
# 25  {'drug': [['ergocalciferol, vitamin D2', 'ERGO...
# 26  {'drug': [['albuterol']], 'dosage': ['90 mcg/a...
# 27  {'drug': [['acetaminophen', 'TYLENOL']], 'dosa...
# 28  {'drug': [['gabapentin', 'NEURONTIN']], 'dosag...
# 29  {'drug': [['CETRORELIX ACETATE , Inject under ...
# 30  {'drug': [['amLODIPine', 'NORVASC']], 'dosage'...
# 31  {'drug': [['simvastatin', 'ZOCOR']], 'dosage':...
# 32  {'drug': [['cholecalciferol, vitamin D3, , Tak...
# 33  {'drug': [['ascorbic acid, vitamin C']], 'dosa...
# 34  {'drug': [['buPROPion', 'WELLBUTRIN SR']], 'do...
# 35  {'drug': [['Hydrochlorothiazide, Potassium, Ex...
# 36  {'drug': [['cholecalciferol, vitamin D3', 'VIT...
# 37  {'drug': [['ALPRAZolam', 'XANAX']], 'dosage': ...
# 38  {'drug': [['amoxicillin', 'AMOXIL']], 'dosage'...
# 39           {'drug': [], 'dosage': [], 'method': []}
#
#                                   past_meds_processed  \
# 0   {'drug': [['Gemcitabine'], ['Abraxane']], 'dos...
# 1   {'drug': [['FOLFIRINOX'], ['Gemcitabine + Abra...
# 2   {'drug': [['FOLFIRINOX'], ['FOLFOX'], ['Gemcit...
# 3   {'drug': [['FOLFIRINOX'], ['gemcitabine and Ab...
# 4   {'drug': [['FOLFIRINOX'], ['FOLFOX']], 'dosage...
# 5   {'drug': [['modified FOLFIRINOX']], 'dosage': ...
# 6   {'drug': [['gemcitabine and Abraxane']], 'dosa...
# 7   {'drug': [['FOLFOX chemotherapy (1 cycle'], ['...
# 8   {'drug': [['FOLFIRINOX x'], [], ['Single-agent...
# 9   {'drug': [['FOLFIRINOX'], [], ['nab-paclitaxel...
# 10  {'drug': [['omeprazole (for H. pylori treatmen...
# 11  {'drug': [['mFOLFIRINOX', '12 cycles'], ['gemc...
# 12  {'drug': [['vori'], ['FOLFIRINOX'], ['Gemcitab...
# 13  {'drug': [['oxycodone'], ['Tylenol']], 'dosage...
# 14           {'drug': [], 'dosage': [], 'method': []}
# 15  {'drug': [['none']], 'dosage': [None], 'method...
# 16  {'drug': [['none']], 'dosage': [None], 'method...
# 17  {'drug': [['gemcitabine and Abraxane']], 'dosa...
# 18  {'drug': [['gemcitabine and Abraxane']], 'dosa...
# 19  {'drug': [['metronidazole'], ['rifaximin'], ['...
# 20  {'drug': [['doxycycline', 'MONODOX']], 'dosage...
# 21  {'drug': [['tamoxifen from']], 'dosage': ['199...
# 22           {'drug': [], 'dosage': [], 'method': []}
# 23           {'drug': [], 'dosage': [], 'method': []}
# 24           {'drug': [], 'dosage': [], 'method': []}
# 25           {'drug': [], 'dosage': [], 'method': []}
# 26           {'drug': [], 'dosage': [], 'method': []}
# 27           {'drug': [], 'dosage': [], 'method': []}
# 28  {'drug': [['polymyxin b-trimethoprim , iohexol...
# 29           {'drug': [], 'dosage': [], 'method': []}
# 30           {'drug': [], 'dosage': [], 'method': []}
# 31  {'drug': [['LORazepam']], 'dosage': [None], 'm...
# 32  {'drug': [['acetaminophen , docusate sodium , ...
# 33           {'drug': [], 'dosage': [], 'method': []}
# 34           {'drug': [], 'dosage': [], 'method': []}
# 35           {'drug': [], 'dosage': [], 'method': []}
# 36           {'drug': [], 'dosage': [], 'method': []}
# 37           {'drug': [], 'dosage': [], 'method': []}
# 38  {'drug': [['tamoxifen, letrozole']], 'dosage':...
# 39           {'drug': [], 'dosage': [], 'method': []}
#
#                                          current_drug  \
# 0                                            [[none]]
# 1   [[ALPRAZolam, XANAX], [atorvastatin, LIPITOR],...
# 2   [[acetaminophen  Take, TYLENOL ORAL], [aspirin...
# 3   [[buPROPion, WELLBUTRIN SR], [estradiol twice ...
# 4   [[butenafine, LOTRIMIN ULTRA], [cholecalcifero...
# 5                                            [[none]]
# 6   [[bisacodyL, DULCOLAX], [cholecalciferol, vita...
# 7   [[acetaminophen  take by mouth every day, TYLE...
# 8   [[albuterol], [cetirizine, ZYRTEC], [diphenoxy...
# 9   [[diphenoxylate-atropine, LOMOTIL], [EYEBRIGHT...
# 10  [[acetaminophen, TYLENOL], [ibuprofen, ADVIL, ...
# 11  [[], [], [], [baclofen  tablet, LIORESAL], [ca...
# 12  [[acetaminophen, TYLENOL], [bisacodyL, DULCOLA...
# 13  [[amLODIPine, NORVASC], [atorvastatin, LIPITOR...
# 14  [[acetaminophen, TYLENOL], [alpha-D-galactosid...
# 15  [[acetaminophen, TYLENOL EXTRA STRENGTH], [bim...
# 16                                           [[none]]
# 17  [[albuterol], [buPROPion], [capecitabine], [cl...
# 18  [[aspirin], [atorvastatin, LIPITOR], [coenzyme...
# 19  [[oxyCODONE-acetaminophen, Percocet], [valACYc...
# 20                         [[acetaminophen, TYLENOL]]
# 21                                [[zoledronic acid]]
# 22          [[clotrimazole-betamethasone, LOTRISONE]]
# 23   [[acetaminophen , menthol, BENGAY COLD THERAPY]]
# 24                                 [[No Medications]]
# 25     [[ergocalciferol, vitamin D2, ERGOCALCIFEROL]]
# 26                                      [[albuterol]]
# 27                         [[acetaminophen, TYLENOL]]
# 28                          [[gabapentin, NEURONTIN]]
# 29  [[CETRORELIX ACETATE , Inject under the skin.,...
# 30                            [[amLODIPine, NORVASC]]
# 31                             [[simvastatin, ZOCOR]]
# 32  [[cholecalciferol, vitamin D3, , Take by mouth...
# 33                       [[ascorbic acid, vitamin C]]
# 34                       [[buPROPion, WELLBUTRIN SR]]
# 35        [[Hydrochlorothiazide, Potassium, Exforge]]
# 36        [[cholecalciferol, vitamin D3, VITAMIN D3]]
# 37                              [[ALPRAZolam, XANAX]]
# 38                            [[amoxicillin, AMOXIL]]
# 39                                                 []
#
#                                        current_dosage  \
# 0                                              [None]
# 1   [0.25 mg tablet Take 1 tablet (0.25 mg total) ...
# 2   [200 mg by mouth As, 81 mg EC tablet aspirin 8...
# 3   [100 mg 12 hr tablet Take 100 mg by mouth, 0.0...
# 4   [1 %, 1000 UNITS TAB tablet Take 4 tablets by ...
# 5                                              [None]
# 6   [5 mg, 1000 UNITS, 0.1 mg/24 hr, 500 mcg, 1 %,...
# 7   [None, None, 5,000 Int’l Units by mouth every,...
# 8   [90 mcg/actuation metered dose inhaler Inhale ...
# 9   [2.5-0.025 mg tablet Take 1 tablet by mouth 4 ...
# 10  [500 mg tablet Take 1,000 mg by mouth daily as...
# 11  [0.9 % sodium chloride flush injection syringe...
# 12  [325 mg, Oral, Once, 5 mg, Oral, Once, 160-9-4...
# 13  [5 mg, Oral, Daily, 20 mg, Oral, Daily, 20 mg,...
# 14  [500 mg tablet Take 1,000 mg by mouth 2 (two) ...
# 15  [500 mg tablet Take 500 mg by mouth every 6 (s...
# 16                                             [None]
# 17  [90 mcg/actuation metered dose, 450 mg, None, ...
# 18  [81 mg, 40 mg, 100 mg, 36,000-114,000-180,000 ...
# 19  [5-325 mg tablet Take 2 tablets by mouth every...
# 20  [500 mg tablet, amLODIPine (NORVASC) 5 mg tabl...
# 21                                             [None]
# 22  [1-0.05 % cream 2 (two) times a day., ibuprofe...
# 23  [5 % GEL Apply 1 Application topically 2 (two)...
# 24                                             [None]
# 25  [50,000 unit capsule, metFORMIN (GLUCOPHAGE) 5...
# 26  [90 mcg/actuation metered dose inhaler Inhale ...
# 27  [325 mg tablet Take 2 tablets (650 mg total) b...
# 28  [300 mg capsule, hydroCHLOROthiazide (HYDRODIU...
# 29                                            [20 mg]
# 30  [5 mg tablet Take 1 tablet (5 mg total) by mou...
# 31                                            [20 mg]
# 32  [1 tablet by mouth Daily., SYNTHROID 112 mcg t...
# 33  [500 mg TABSR, Take by mouth daily., B-complex...
# 34  [150 mg 12 hr tablet, Take 150 mg by mouth 2 (...
# 35                                             [None]
# 36                  [2,000 unit CAP capsule, Take by]
# 37  [0.25 mg tablet, ibuprofen (ADVIL) 200 mg tabl...
# 38  [875 mg tablet, amoxicillin-clavulanate (AUGME...
# 39                                                 []
#
#                                        current_method  \
# 0                                              [None]
# 1   [sleep., daily., pain, day., days, tpn/tf/npo,...
# 2   [needed., route., tablet, pain, needed., hours...
# 3   [daily, patch, vomiting), given., breakfast, d...
# 4   [cream, daily, treatment, stop., None, sola, N...
# 5                                              [None]
# 6   [ec tablet, tablet, patch, tablet, gel, capsul...
# 7                [None, None, day, daily, time, None]
# 8   [needed., needed., diarrhea., day., snack., (n...
# 9   [diarrhea, None, daily., None, None, hours., (...
# 10          [pain, pain, meals, daily, nausea, daily]
# 11  [sch, prn, continuous, tid, oral, (am), bedtim...
# 12  [prn, prn, daily, prn, scheduled, days., meals...
# 13  [scheduled, scheduled, prn, scheduled, schedul...
# 14  [pain., None, directed, None, needed., None, d...
# 15  [pain., daily., daily., daily., bedtime., mout...
# 16                                             [None]
# 17  [inhaler, tabsr24h, None, tablet, cream, table...
# 18  [ec tablet, tablet, capsule, capsule, tablet, ...
# 19                                [days, sores, None]
# 20                                         [solution]
# 21                                             [None]
# 22                                           [tablet]
# 23                                           [breath]
# 24                                             [None]
# 25                                         [solution]
# 26                                          [needed.]
# 27                                         [bedtime.]
# 28                                           [mouth.]
# 29                                          [tablet.]
# 30                                           [meals.]
# 31                                           [tablet]
# 32                                           [daily.]
# 33                                           [sleep.]
# 34                                           [sleep.]
# 35                                             [None]
# 36                                           [mouth.]
# 37                                           [mouth.]
# 38                                           [tablet]
# 39                                                 []
#
#                                             past_drug  \
# 0                         [[Gemcitabine], [Abraxane]]
# 1            [[FOLFIRINOX], [Gemcitabine + Abraxane]]
# 2   [[FOLFIRINOX], [FOLFOX], [Gemcitabine plus nab...
# 3          [[FOLFIRINOX], [gemcitabine and Abraxane]]
# 4                            [[FOLFIRINOX], [FOLFOX]]
# 5                             [[modified FOLFIRINOX]]
# 6                        [[gemcitabine and Abraxane]]
# 7   [[FOLFOX chemotherapy (1 cycle], [FOLFIRINOX (...
# 8   [[FOLFIRINOX x], [], [Single-agent liposomal i...
# 9   [[FOLFIRINOX], [], [nab-paclitaxel + CORT12513...
# 10  [[omeprazole (for H. pylori treatment in Janua...
# 11  [[mFOLFIRINOX, 12 cycles], [gemcitabine and na...
# 12  [[vori], [FOLFIRINOX], [Gemcitabine + Capecita...
# 13                           [[oxycodone], [Tylenol]]
# 14                                                 []
# 15                                           [[none]]
# 16                                           [[none]]
# 17                       [[gemcitabine and Abraxane]]
# 18                       [[gemcitabine and Abraxane]]
# 19  [[metronidazole], [rifaximin], [probiotics], [...
# 20                           [[doxycycline, MONODOX]]
# 21                                 [[tamoxifen from]]
# 22                                                 []
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27                                                 []
# 28  [[polymyxin b-trimethoprim , iohexol, OMNIPAQUE]]
# 29                                                 []
# 30                                                 []
# 31                                      [[LORazepam]]
# 32  [[acetaminophen , docusate sodium , HYDROcodon...
# 33                                                 []
# 34                                                 []
# 35                                                 []
# 36                                                 []
# 37                                                 []
# 38                           [[tamoxifen, letrozole]]
# 39                                                 []
#
#                                           past_dosage  \
# 0                                        [None, None]
# 1                                        [None, None]
# 2   [None, None, None, 5-FU/LV plus nanoliposomal ...
# 3                                        [None, None]
# 4                                        [None, None]
# 5                                              [None]
# 6                                              [None]
# 7             [None, 08/07/19 -, 09/19/20, currently]
# 8   [12, 5FU & liposomal irinotecan x 12, None, No...
# 9   [None, 5FU & liposomal, None, None, None, None...
# 10                                             [None]
# 11                                 [None, None, None]
# 12                           [None, None, None, None]
# 13                                       [None, None]
# 14                                                 []
# 15                                             [None]
# 16                                             [None]
# 17                                             [None]
# 18                                             [None]
# 19                           [None, None, None, None]
# 20  [100 mg capsule, furosemide (LASIX) 40 mg tabl...
# 21                                          [1994 to]
# 22                                                 []
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27                                                 []
# 28                    [350 mg iodine/mL solution 150]
# 29                                                 []
# 30                                                 []
# 31                                             [None]
# 32                                             [None]
# 33                                                 []
# 34                                                 []
# 35                                                 []
# 36                                                 []
# 37                                                 []
# 38                                             [None]
# 39                                                 []
#
#                                           past_method
# 0                                        [None, None]
# 1                                        [None, None]
# 2                        [None, None, None, onivyde)]
# 3                                        [None, None]
# 4                                        [None, None]
# 5                                              [None]
# 6                                              [None]
# 7                    [06/15/19), 01/09/20), ongoing)]
# 8                  [cycles, cycles, None, None, None]
# 9   [None, irinotecan, None, None, None, None, Non...
# 10                                            [2021)]
# 11                                 [None, None, None]
# 12                           [None, None, None, None]
# 13                                       [None, None]
# 14                                                 []
# 15                                             [None]
# 16                                             [None]
# 17                                             [None]
# 18                                             [None]
# 19                           [None, None, None, None]
# 20                                               [mg]
# 21                                             [1996]
# 22                                                 []
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27                                                 []
# 28                                               [ml]
# 29                                                 []
# 30                                                 []
# 31                                             [None]
# 32                                             [None]
# 33                                                 []
# 34                                                 []
# 35                                                 []
# 36                                                 []
# 37                                                 []
# 38                                             [None]
# 39                                                 []
#
# [40 rows x 23 columns]

# %%
combined_df.columns = combined_df.columns.str.strip()
print("Columns in DataFrame:", combined_df.columns.tolist())

def process_list_cell(cell_value):
    """
    Process a cell that contains list-like text and return a list of items.
    Splits by newline and comma.
    """
    if pd.isnull(cell_value):
        return []

    # First, split by newline
    items = [item.strip() for item in str(cell_value).split('\n') if item.strip()]

    # Then, for each item, further split by comma if needed.
    final_items = []
    for item in items:
        if ',' in item:
            final_items.extend([sub_item.strip() for sub_item in item.split(',') if sub_item.strip()])
        else:
            final_items.append(item)

    return final_items

# Update these names if the actual columns differ
current_symptoms_col = "Current Symptoms"
past_symptoms_col = "Past symptoms"
chronic_conditions_col = "Chronic Conditions"
family_histry_col = "family history"


# Process the columns to create new list columns.
combined_df['current_symptoms_list'] = combined_df[current_symptoms_col].apply(process_list_cell)
combined_df['past_symptoms_list'] = combined_df[past_symptoms_col].apply(process_list_cell)
combined_df['chronic_conditions_list'] = combined_df[chronic_conditions_col].apply(process_list_cell)
combined_df['family_history_list'] = combined_df[family_histry_col].apply(process_list_cell)

# Display a few rows for verification
combined_df
# Out:
# Columns in DataFrame: ['Patient Note', 'Entire Patient Note', 'Current Medications', 'Past Medications', 'Patient Current Age', 'Current Symptoms', 'Past symptoms', 'Chronic Conditions', 'family history', 'Reason for visit', 'Primary diagnosis (should be only one)', 'Procedure names', 'Information relevant to primary diagnosis', 'Age', 'Gender', 'current_meds_processed', 'past_meds_processed', 'current_drug', 'current_dosage', 'current_method', 'past_drug', 'past_dosage', 'past_method']
#    Patient Note                                Entire Patient Note  \
# 0         pdac0  SUBJECTIVE:    This is a very pleasant 47-year...
# 1         pdac1  This is an independent visit    ATTENDING: ***...
# 2         pdac2  Mr. ***** is a 74 y.o. male who returns to our...
# 3         pdac3  SUBJECTIVE:    This is a very pleasant 64-year...
# 4         pdac4  This is an independent service.  The available...
# 5         pdac5  Subjective:    This is a very pleasant 63-year...
# 6         pdac6  SUBJECTIVE:    This is a very pleasant 68-year...
# 7         pdac7  Ms. ***** is a 69 y.o. female who comes to our...
# 8         pdac8  REASON FOR VISIT/CC:   Chief Complaint   Patie...
# 9         pdac9  FOLLOW UP VISIT    Ms. ***** is a 73 y.o. fema...
# 10       pdac10  INITIAL GI MEDICAL ONCOLOGY VISIT     Patient ...
# 11       pdac11  I had the pleasure of seeing ***** ***** for f...
# 12       pdac12    FOLLOW UP GASTROINTESTINAL MEDICAL ONCOLOGY ...
# 13       pdac13  VIDEO VISIT  I performed this consultation usi...
# 14       pdac14  REASON FOR VISIT/CC:   Chief Complaint   Patie...
# 15       pdac15   UCSF Cancer Center GI Medical Oncology Progra...
# 16       pdac16  This is an independent visit     Patient ID:  ...
# 17       pdac17    SUBJECTIVE:  This is a very pleasant 65-year...
# 18       pdac18    This is an independent visit    SUBJECTIVE  ...
# 19       pdac19  Mr. ***** is a 51 y.o. male who comes to our G...
# 20         BC20  ID: ***** ***** is a 81 y.o. postmenopausal pa...
# 21         BC21                           UCSF ***** ***** FAMI...
# 22         BC22  *****  60 yo F    Chief complaint: Patient wit...
# 23         BC23  ID: 71 year old female    CC:  HR low, HER2 ne...
# 24         BC24  ID: ***** ***** is a 55 y.o. ***** with a rece...
# 25         BC25  ***** ***** is a 53 y.o. female with newly dia...
# 26         BC26  This is a shared visit for services provided b...
# 27         BC27    Chief complaint: Patient with breast cancer ...
# 28         BC28  ID: ***** ***** is a 31 y.o. premenopausal fem...
# 29         BC29  HPI:  ***** ***** is a 32 y.o. female here in ...
# 30         BC30  Subjective:       Patient ID: ***** ***** ****...
# 31         BC31  ID: ***** ***** ***** is a 67 y.o. postmenopau...
# 32         BC32  HPI:  ***** ***** is a 36 y.o. female with a r...
# 33         BC33  HPI:  ***** ***** is a 34 y.o. female here in ...
# 34         BC34  ID: ***** ***** is a 33 y.o. premenopausal pat...
# 35         BC35                              UCSF ***** ***** F...
# 36         BC36  HPI:  ***** ***** ***** is a 58 y.o. female he...
# 37         BC37  HPI:  ***** ***** is a 32 y.o. female here for...
# 38         BC38  SUBJECTIVE    ***** ***** is a 49 y.o. female ...
# 39         BC39  New patient Visit  Breast Cancer *****    ****...
#
#                                   Current Medications  \
# 0                                                none
# 1   ALPRAZolam (XANAX) 0.25 mg tablet Take 1 table...
# 2   acetaminophen (TYLENOL ORAL) Take 200 mg by mo...
# 3   buPROPion (WELLBUTRIN SR) 100 mg 12 hr tablet ...
# 4   butenafine (LOTRIMIN ULTRA) 1 % cream\ncholeca...
# 5                                                none
# 6   bisacodyL (DULCOLAX) 5 mg EC tablet\ncholecalc...
# 7   acetaminophen (TYLENOL PO) take by mouth every...
# 8   albuterol 90 mcg/actuation metered dose inhale...
# 9   diphenoxylate-atropine (LOMOTIL) 2.5-0.025 mg ...
# 10  acetaminophen (TYLENOL) 500 mg tablet Take 1,0...
# 11  0.9 % sodium chloride flush injection syringe,...
# 12  acetaminophen (TYLENOL) 325 mg, Oral, Once PRN...
# 13  amLODIPine (NORVASC) 5 mg, Oral, Daily Schedul...
# 14  acetaminophen (TYLENOL) 500 mg tablet Take 1,0...
# 15  acetaminophen (TYLENOL EXTRA STRENGTH) 500 mg ...
# 16                                               none
# 17  albuterol 90 mcg/actuation metered dose inhale...
# 18  aspirin 81 mg EC tablet\natorvastatin (LIPITOR...
# 19  oxyCODONE-acetaminophen (Percocet) 5-325 mg ta...
# 20  acetaminophen (TYLENOL) 500 mg tablet, amLODIP...
# 21                                    zoledronic acid
# 22  clotrimazole-betamethasone (LOTRISONE) 1-0.05 ...
# 23  acetaminophen (TYLENOL) 325 mg tablet Take 1 t...
# 24                                     No Medications
# 25  ergocalciferol, vitamin D2, (ERGOCALCIFEROL) 5...
# 26  albuterol 90 mcg/actuation metered dose inhale...
# 27  acetaminophen (TYLENOL) 325 mg tablet Take 2 t...
# 28  gabapentin (NEURONTIN) 300 mg capsule, hydroCH...
# 29  CETRORELIX ACETATE (CETROTIDE SUBCUT), Inject ...
# 30  amLODIPine (NORVASC) 5 mg tablet Take 1 tablet...
# 31                   simvastatin (ZOCOR) 20 mg tablet
# 32  cholecalciferol, vitamin D3, (VITAMIN D3 ORAL)...
# 33  ascorbic acid, vitamin C, 500 mg TABSR, Take b...
# 34  buPROPion (WELLBUTRIN SR) 150 mg 12 hr tablet,...
# 35            Hydrochlorothiazide, Potassium, Exforge
# 36  cholecalciferol, vitamin D3, (VITAMIN D3) 2,00...
# 37  ALPRAZolam (XANAX) 0.25 mg tablet, ibuprofen (...
# 38  amoxicillin (AMOXIL) 875 mg tablet, amoxicilli...
# 39                                                NaN
#
#                                      Past Medications Patient Current Age  \
# 0                               Gemcitabine\nAbraxane         47-year-old
# 1                  FOLFIRINOX\nGemcitabine + Abraxane             71 y.o.
# 2   FOLFIRINOX\nFOLFOX\nGemcitabine plus nab-pacli...             74 y.o.
# 3                FOLFIRINOX\ngemcitabine and Abraxane         64-year-old
# 4                                  FOLFIRINOX\nFOLFOX             53 y.o.
# 5                                 modified FOLFIRINOX         63-year-old
# 6                           gemcitabine and Abraxane          68-year-old
# 7   FOLFOX chemotherapy (1 cycle, 06/15/19)\nFOLFI...      69 y.o. female
# 8   FOLFIRINOX x 12 cycles\n5FU & liposomal irinot...      71 y.o. female
# 9   FOLFIRINOX\n5FU & liposomal irinotecan\nnab-pa...      73 y.o. female
# 10  omeprazole (for H. pylori treatment in January...        52 y.o. male
# 11  mFOLFIRINOX (12 cycles)\ngemcitabine and nab-p...        74 y.o. male
# 12  vori\nFOLFIRINOX\nGemcitabine + Capecitabine\n...        78 y.o. male
# 13                                 oxycodone\nTylenol      69 y.o. female
# 14                                                NaN        64 y.o. male
# 15                                               none      86 y.o. female
# 16                                               none        58 y.o. male
# 17                           gemcitabine and Abraxane   65-year-old woman
# 18                           gemcitabine and Abraxane         69-year-old
# 19  metronidazole\nrifaximin\nprobiotics\ndietary ...             51 y.o.
# 20  doxycycline (MONODOX) 100 mg capsule, furosemi...             81 y.o.
# 21                        tamoxifen from 1994 to 1996   73-year-old woman
# 22                                                NaN  60-year-old female
# 23                                                NaN  71-year-old female
# 24                                                NaN  55-year-old female
# 25                                                NaN  53-year-old female
# 26                                                NaN  44-year-old female
# 27                                                NaN  70-year-old female
# 28  polymyxin b-trimethoprim (POLYTRIM) ophthalmic...  31-year-old female
# 29                                                NaN  32-year-old female
# 30                                                NaN  51-year-old female
# 31  LORazepam (ATIVAN) 1 mg tablet Take 1 tab po/s...  67-year-old female
# 32  acetaminophen (TYLENOL) 500 mg tablet, Take 2 ...  36-year-old female
# 33                                                NaN  34-year-old female
# 34                                                NaN  33-year-old female
# 35                                                NaN   59-year-old woman
# 36                                                NaN  58-year-old female
# 37                                                NaN  32-year-old female
# 38                               tamoxifen, letrozole  49-year-old female
# 39                                                NaN  44-year-old female
#
#                                      Current Symptoms  \
# 0   Intermittent abdominal discomfort, usually at ...
# 1   Intermittent fevers for 4-5 days following tre...
# 2   Tolerating POs adequately since stent placemen...
# 3   She does complain of brain fog which she attri...
# 4                  Continues to have some oral thrush
# 5   continued abdominal discomfort particularly on...
# 6   She has no cancer pain but takes oxycodone for...
# 7   She denies any pain at present (currently on o...
# 8   Worsening neuropathy.\nImproved abd pain.\nTro...
# 9   Feels ‘almost normal\nNotes constant saltiness...
# 10  early satiety\nnausea post prandial\nloss of a...
# 11  (+) weight loss\n(+) bloating\n(+) bilirubinur...
# 12  Fevers episodically around 12/20/21 for a few ...
# 13  Appetite has been sluggish in the past few wee...
# 14      HgBA1C running >12\nNo pain. Wounds improved.
# 15  Her energy level is low and her appetite is lo...
# 16  Patient has felt very well.\nHe is exercising ...
# 17  She is very fatigued and sleeps about 12 hours...
# 18  Patient reports increased fatigue over the pas...
# 19  Appetite fair\nsome early satiety and postpran...
# 20  dyspnea, no pain at the site of her breast sur...
# 21  lack of energy and pain in her right hand, dis...
# 22  Patient with early stage breast cancer here to...
# 23        tenderness at biopsy site and around axilla
# 24   mild joint stiffness, in particular in her knees
# 25  No bone pain or any other systemic concerns, N...
# 26  Worsening GERD, nausea, fatigue for 3 days aft...
# 27  Feeling well since surgery, healing well, slig...
# 28  Left breast mass growing rapidly, some discolo...
# 29  Found mass in her right breast while on vacati...
# 30  Left breast still somewhat sore post-surgery, ...
# 31                Feeling well, no new symptoms noted
# 32  No new symptoms noted, patient here for treatm...
# 33           2 cm R breast mass 8 cm from the nipple.
# 34  Right lateral neck lump increasing in size, so...
# 35  Right breast aching that is gradually increasi...
# 36  Mild left breast pain status post lumpectomy r...
# 37         Left breast lump palpated in December 2017
# 38  Minimal joint aches, mild hot flashes and inso...
# 39  Felt a lump in the right breast, two episodes ...
#
#                                         Past symptoms  \
# 0   Several months of vague abdominal discomfort, ...
# 1   Abdominal discomfort and biliary ductal obstru...
# 2   Progressive anorexia and fatigue\nMild thrombo...
# 3   She does complain of brain fog which she attri...
# 4       Presented with abdominal pain and weight loss
# 5   abdominal discomfort, bloating and eventually ...
# 6   symptoms of small bowel obstruction in early J...
# 7   Painless jaundice (May 2019)\nPersistent mid-b...
# 8   Peripheral neuropathy - improved off of treatm...
# 9   Peripheral neuropathy\nDiarrhea with every PO ...
# 10  abdominal pain x1mo\n35lb weight loss\nemesis ...
# 11  weight loss (8 lbs over past month)\ndecline i...
# 12  acute symptomatic anemia\nfever with leukocyto...
# 13  2 months of intermittent epigastric and left s...
# 14  03/19/17 he presented to ***** with 3 weeks of...
# 15  November 2018: Presented to her primary care d...
# 16  October 2017: abd pain. Seen in ED sent home.\...
# 17  Severe adverse events including metabolic abno...
# 18  Presented with abdominal pain and weight loss ...
# 19  intermittent mid/LUQ abdominal discomfort\nblo...
# 20  painful mass in her right breast, firm mobile ...
# 21  neuropathy of the right hand associated with a...
# 22                    felt a mass in her right breast
# 23  chronic back and shoulder pain x 2 years, chro...
# 24      Felt lump in her left breast in February 2017
# 25                             None explicitly stated
# 26                             None explicitly stated
# 27  Left breast mass, numbness of L axilla and L e...
# 28  Palpated a mass in her left breast while breas...
# 29                             None explicitly stated
# 30                             None explicitly stated
# 31    Felt a mass in her right breast in late January
# 32  Felt a mass in her right breast while on vacat...
# 33  Self-palpated right breast mass in December 2018.
# 34                             None explicitly stated
# 35  Left breast had an area of increased density, ...
# 36  Left breast mass measuring 2cm after feeling a...
# 37                             None explicitly stated
# 38  Left breast mass, history of postoperative nau...
# 39                             None explicitly stated
#
#                                    Chronic Conditions  \
# 0   Hypertension, voluntarily stopped his antihype...
# 1   COPD (chronic obstructive pulmonary disease) (...
# 2                        Metastatic pancreatic cancer
# 3           Metastatic adenocarcinoma of the pancreas
# 4   Stage IV pancreatic adenocarcinoma\nBiopsy-pro...
# 5   Borderline resectable/locally advanced adenoca...
# 6   Chronic opioid use\narthritis\nchronic back pa...
# 7   Hypertension\nHyperlipidemia\nAdenomatous poly...
# 8   Asthma\nBreast cancer (HCC)\nDifficult intubat...
# 9   Diabetes with A1C 10\nLocally advanced pancrea...
# 10  Borderline hypertension\nDiabetes (CMS code) M...
# 11  Pancreatic adenocarcinoma\nDiabetes\nHypertension
# 12  Pancreatic adenocarcinoma\nProstate cancer\nCa...
# 13  HTN\nDyslipidemia\nPre-diabetes\nLumbar stenos...
# 14  Arthritis\nHistory of continuous positive airw...
# 15  Pancreatic adenocarcinoma\nOrthostatic hypoten...
# 16            Locally advanced pMMR pancreatic cancer
# 17  Hypertension\nHistory of hypothyroidism\nAsthm...
# 18  Locally advanced and unresectable adenocarcino...
# 19  Anxiety\nEnvironmental allergies\nmetastatic p...
# 20  Cardiac pacemaker in situ, Cataract, CHF (cong...
# 21  osteoarthritis in the left hand, trace emphyse...
# 22  Abnormal liver enzymes 2012, Hyperbilirubinemi...
# 23  Cataract, Elevated CA-125, GERD (gastroesophag...
# 24        Breast cancer, Diabetes 08/09/2017, Obesity
# 25                   Breast cancer, Diabetes mellitus
# 26  Lynch syndrome, Colon cancer (HCC), Metastatic...
# 27  Arthritis, Breast cancer (left side), Cataract...
# 28  Stage III HR+/HER2- IDC of the left breast, Hy...
# 29  Breast cancer, right breast, Closed left ankle...
# 30  Migraine, Chronic low back pain, Right-sided l...
# 31  Breast cancer, Fibrocystic breast disease, Lip...
# 32                      Breast cancer, Hypothyroidism
# 33  Bipolar 2 disorder, Insomnia, Breast Cancer Right
# 34  Back pain, Breast cancer, Depression, Hyperten...
# 35  Hypertension (for 30 years), Hysterectomy and ...
# 36                         Breast cancer, left breast
# 37                                       ATM mutation
# 38  ER+/PR-/HER2- left breast cancer, Endometriosi...
# 39                                Breast cancer (HCC)
#
#                                        family history  \
# 0   There is no cancer among his first-degree rela...
# 1   Father Pancreatic cancer\nMaternal Uncle Pancr...
# 2   Comprehensive past medical, family, and social...
# 3                                                none
# 4   Past medical, social, and family history were ...
# 5                                                none
# 6   The only cancer in her family is in maternal a...
# 7   Paternal grandmother with esophageal cancer\nM...
# 8   Stomach cancer Mother  71\nColon cancer Sister...
# 9   No new updates, reviewed and unchanged from pr...
# 10  Breast cancer (Mother)\nProstate cancer (Fathe...
# 11             No updates from prior visits, per note
# 12  Hearing loss (Mother)\nHeart disease (Mother)\...
# 13  Reviewed; no hereditary pattern of cancer note...
# 14                                               none
# 15  Past medical, social, and family history: Unch...
# 16                                               none
# 17  Her father had prostate cancer.\nShe has 3 pat...
# 18  She has 4 siblings. One sister was diagnosed w...
# 19  Ovarian cancer – Mother\nLung cancer – Materna...
# 20  Stroke (Mother), Uterine cancer (Mother) age 4...
# 21  one maternal aunt with breast cancer at the ag...
# 22  Breast cancer in her sister, Cancer (age of on...
# 23  Cancer Mother 35 - breast cancer, Hypertension...
# 24              Breast cancer Maternal Grandmother 58
# 25  Family history unknown: Yes, no h/o malignancy...
# 26  Leukemia Mother - as a child, in remission, Ot...
# 27  Paternal grandmother passed away from breast c...
# 28  Lymphoma Father, No family history of breast c...
# 29  Lung cancer - Father (Age 68), Melanoma - Mate...
# 30  Hypertension - Mother, Arthritis - Mother, Dep...
# 31  Breast cancer - Mother (early 50s, had unilate...
# 32                             Breast cancer - Cousin
# 33  Alzheimer's disease - Paternal Grandfather, Al...
# 34  Cerebral aneurysm - Father, Melanoma - Negativ...
# 35  Mother had Parkinson's disease, does not know ...
# 36  Breast cancer - Paternal Grandmother (Age 35),...
# 37  Breast cancer - Mother, Breast cancer - Other ...
# 38  Mother had Parkinson's disease, does not know ...
# 39  Colon cancer - Father (diagnosed in late 40s, ...
#
#                                      Reason for visit  ...  \
# 0   He would like to meet with psycho oncology as ...  ...
# 1   Mr. ***** is a 71 y.o. male who returns to our...  ...
# 2   Mr. ***** is a 74 y.o. male who returns to our...  ...
# 3   She’ll continue on surveillance and we will se...  ...
# 4   Mr. ***** is a 53 y.o. male who returns to our...  ...
# 5   I’m very concerned about her imaging studies. ...  ...
# 6   She is now had 4 full cycles and returns for C...  ...
# 7   Ms. ***** is a 69 y.o. female who comes to our...  ...
# 8   Patient presents with Pancreatic Cancer Follow-up  ...
# 9   Follow-up of her locally advanced pancreatic c...  ...
# 10  Newly diagnosed metastatic pancreatic cancer\n...  ...
# 11  Follow up visit of pancreatic adenocarcinoma w...  ...
# 12                 Patient presents for consideration  ...
# 13  Ms. ***** is a 69 y.o. female whom I am seeing...  ...
# 14  Patient presents with Follow-up\n presents tod...  ...
# 15  86 y.o. female who presents to our GI Oncology...  ...
# 16  Patient prefers to hold off on any additional ...  ...
# 17            Surveillance scan h/o pancreatic cancer  ...
# 18  Patient is now s/p 2 cycles of FOLFIRINOX. She...  ...
# 19  Mr. ***** is a 51 y.o. male who comes to our G...  ...
# 20  presents in consultation to discuss treatment ...  ...
# 21  she comes here today for a discussion of poten...  ...
# 22  The patient has been referred to discuss neoad...  ...
# 23  Patient with R breast cancer here for discussi...  ...
# 24  Patient with a recent diagnosis of early stage...  ...
# 25  Newly diagnosed HR-negative HER2+ breast cance...  ...
# 26  Newly diagnosed metastatic breast cancer to li...  ...
# 27  Patient with a recent diagnosis of stage IIA p...  ...
# 28  31-year-old female with a history of Stage III...  ...
# 29  Consultation to discuss treatment options for ...  ...
# 30  51-year-old female with biopsy-proven left bre...  ...
# 31  67-year-old postmenopausal patient with a clin...  ...
# 32  36-year-old female with a newly diagnosed horm...  ...
# 33  34-year-old premenopausal woman with HR+ right...  ...
# 34  33-year-old premenopausal patient with a recen...  ...
# 35  Consultation regarding treatment of her newly ...  ...
# 36  58-year-old postmenopausal woman with a T2N1 g...  ...
# 37  32-year-old female ATM mutation carrier with n...  ...
# 38  49-year-old woman with a history of HR+ low-ri...  ...
# 39  44-year-old premenopausal female with a recent...  ...
#
#                                          current_drug  \
# 0                                            [[none]]
# 1   [[ALPRAZolam, XANAX], [atorvastatin, LIPITOR],...
# 2   [[acetaminophen  Take, TYLENOL ORAL], [aspirin...
# 3   [[buPROPion, WELLBUTRIN SR], [estradiol twice ...
# 4   [[butenafine, LOTRIMIN ULTRA], [cholecalcifero...
# 5                                            [[none]]
# 6   [[bisacodyL, DULCOLAX], [cholecalciferol, vita...
# 7   [[acetaminophen  take by mouth every day, TYLE...
# 8   [[albuterol], [cetirizine, ZYRTEC], [diphenoxy...
# 9   [[diphenoxylate-atropine, LOMOTIL], [EYEBRIGHT...
# 10  [[acetaminophen, TYLENOL], [ibuprofen, ADVIL, ...
# 11  [[], [], [], [baclofen  tablet, LIORESAL], [ca...
# 12  [[acetaminophen, TYLENOL], [bisacodyL, DULCOLA...
# 13  [[amLODIPine, NORVASC], [atorvastatin, LIPITOR...
# 14  [[acetaminophen, TYLENOL], [alpha-D-galactosid...
# 15  [[acetaminophen, TYLENOL EXTRA STRENGTH], [bim...
# 16                                           [[none]]
# 17  [[albuterol], [buPROPion], [capecitabine], [cl...
# 18  [[aspirin], [atorvastatin, LIPITOR], [coenzyme...
# 19  [[oxyCODONE-acetaminophen, Percocet], [valACYc...
# 20                         [[acetaminophen, TYLENOL]]
# 21                                [[zoledronic acid]]
# 22          [[clotrimazole-betamethasone, LOTRISONE]]
# 23   [[acetaminophen , menthol, BENGAY COLD THERAPY]]
# 24                                 [[No Medications]]
# 25     [[ergocalciferol, vitamin D2, ERGOCALCIFEROL]]
# 26                                      [[albuterol]]
# 27                         [[acetaminophen, TYLENOL]]
# 28                          [[gabapentin, NEURONTIN]]
# 29  [[CETRORELIX ACETATE , Inject under the skin.,...
# 30                            [[amLODIPine, NORVASC]]
# 31                             [[simvastatin, ZOCOR]]
# 32  [[cholecalciferol, vitamin D3, , Take by mouth...
# 33                       [[ascorbic acid, vitamin C]]
# 34                       [[buPROPion, WELLBUTRIN SR]]
# 35        [[Hydrochlorothiazide, Potassium, Exforge]]
# 36        [[cholecalciferol, vitamin D3, VITAMIN D3]]
# 37                              [[ALPRAZolam, XANAX]]
# 38                            [[amoxicillin, AMOXIL]]
# 39                                                 []
#
#                                        current_dosage  \
# 0                                              [None]
# 1   [0.25 mg tablet Take 1 tablet (0.25 mg total) ...
# 2   [200 mg by mouth As, 81 mg EC tablet aspirin 8...
# 3   [100 mg 12 hr tablet Take 100 mg by mouth, 0.0...
# 4   [1 %, 1000 UNITS TAB tablet Take 4 tablets by ...
# 5                                              [None]
# 6   [5 mg, 1000 UNITS, 0.1 mg/24 hr, 500 mcg, 1 %,...
# 7   [None, None, 5,000 Int’l Units by mouth every,...
# 8   [90 mcg/actuation metered dose inhaler Inhale ...
# 9   [2.5-0.025 mg tablet Take 1 tablet by mouth 4 ...
# 10  [500 mg tablet Take 1,000 mg by mouth daily as...
# 11  [0.9 % sodium chloride flush injection syringe...
# 12  [325 mg, Oral, Once, 5 mg, Oral, Once, 160-9-4...
# 13  [5 mg, Oral, Daily, 20 mg, Oral, Daily, 20 mg,...
# 14  [500 mg tablet Take 1,000 mg by mouth 2 (two) ...
# 15  [500 mg tablet Take 500 mg by mouth every 6 (s...
# 16                                             [None]
# 17  [90 mcg/actuation metered dose, 450 mg, None, ...
# 18  [81 mg, 40 mg, 100 mg, 36,000-114,000-180,000 ...
# 19  [5-325 mg tablet Take 2 tablets by mouth every...
# 20  [500 mg tablet, amLODIPine (NORVASC) 5 mg tabl...
# 21                                             [None]
# 22  [1-0.05 % cream 2 (two) times a day., ibuprofe...
# 23  [5 % GEL Apply 1 Application topically 2 (two)...
# 24                                             [None]
# 25  [50,000 unit capsule, metFORMIN (GLUCOPHAGE) 5...
# 26  [90 mcg/actuation metered dose inhaler Inhale ...
# 27  [325 mg tablet Take 2 tablets (650 mg total) b...
# 28  [300 mg capsule, hydroCHLOROthiazide (HYDRODIU...
# 29                                            [20 mg]
# 30  [5 mg tablet Take 1 tablet (5 mg total) by mou...
# 31                                            [20 mg]
# 32  [1 tablet by mouth Daily., SYNTHROID 112 mcg t...
# 33  [500 mg TABSR, Take by mouth daily., B-complex...
# 34  [150 mg 12 hr tablet, Take 150 mg by mouth 2 (...
# 35                                             [None]
# 36                  [2,000 unit CAP capsule, Take by]
# 37  [0.25 mg tablet, ibuprofen (ADVIL) 200 mg tabl...
# 38  [875 mg tablet, amoxicillin-clavulanate (AUGME...
# 39                                                 []
#
#                                        current_method  \
# 0                                              [None]
# 1   [sleep., daily., pain, day., days, tpn/tf/npo,...
# 2   [needed., route., tablet, pain, needed., hours...
# 3   [daily, patch, vomiting), given., breakfast, d...
# 4   [cream, daily, treatment, stop., None, sola, N...
# 5                                              [None]
# 6   [ec tablet, tablet, patch, tablet, gel, capsul...
# 7                [None, None, day, daily, time, None]
# 8   [needed., needed., diarrhea., day., snack., (n...
# 9   [diarrhea, None, daily., None, None, hours., (...
# 10          [pain, pain, meals, daily, nausea, daily]
# 11  [sch, prn, continuous, tid, oral, (am), bedtim...
# 12  [prn, prn, daily, prn, scheduled, days., meals...
# 13  [scheduled, scheduled, prn, scheduled, schedul...
# 14  [pain., None, directed, None, needed., None, d...
# 15  [pain., daily., daily., daily., bedtime., mout...
# 16                                             [None]
# 17  [inhaler, tabsr24h, None, tablet, cream, table...
# 18  [ec tablet, tablet, capsule, capsule, tablet, ...
# 19                                [days, sores, None]
# 20                                         [solution]
# 21                                             [None]
# 22                                           [tablet]
# 23                                           [breath]
# 24                                             [None]
# 25                                         [solution]
# 26                                          [needed.]
# 27                                         [bedtime.]
# 28                                           [mouth.]
# 29                                          [tablet.]
# 30                                           [meals.]
# 31                                           [tablet]
# 32                                           [daily.]
# 33                                           [sleep.]
# 34                                           [sleep.]
# 35                                             [None]
# 36                                           [mouth.]
# 37                                           [mouth.]
# 38                                           [tablet]
# 39                                                 []
#
#                                             past_drug  \
# 0                         [[Gemcitabine], [Abraxane]]
# 1            [[FOLFIRINOX], [Gemcitabine + Abraxane]]
# 2   [[FOLFIRINOX], [FOLFOX], [Gemcitabine plus nab...
# 3          [[FOLFIRINOX], [gemcitabine and Abraxane]]
# 4                            [[FOLFIRINOX], [FOLFOX]]
# 5                             [[modified FOLFIRINOX]]
# 6                        [[gemcitabine and Abraxane]]
# 7   [[FOLFOX chemotherapy (1 cycle], [FOLFIRINOX (...
# 8   [[FOLFIRINOX x], [], [Single-agent liposomal i...
# 9   [[FOLFIRINOX], [], [nab-paclitaxel + CORT12513...
# 10  [[omeprazole (for H. pylori treatment in Janua...
# 11  [[mFOLFIRINOX, 12 cycles], [gemcitabine and na...
# 12  [[vori], [FOLFIRINOX], [Gemcitabine + Capecita...
# 13                           [[oxycodone], [Tylenol]]
# 14                                                 []
# 15                                           [[none]]
# 16                                           [[none]]
# 17                       [[gemcitabine and Abraxane]]
# 18                       [[gemcitabine and Abraxane]]
# 19  [[metronidazole], [rifaximin], [probiotics], [...
# 20                           [[doxycycline, MONODOX]]
# 21                                 [[tamoxifen from]]
# 22                                                 []
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27                                                 []
# 28  [[polymyxin b-trimethoprim , iohexol, OMNIPAQUE]]
# 29                                                 []
# 30                                                 []
# 31                                      [[LORazepam]]
# 32  [[acetaminophen , docusate sodium , HYDROcodon...
# 33                                                 []
# 34                                                 []
# 35                                                 []
# 36                                                 []
# 37                                                 []
# 38                           [[tamoxifen, letrozole]]
# 39                                                 []
#
#                                           past_dosage  \
# 0                                        [None, None]
# 1                                        [None, None]
# 2   [None, None, None, 5-FU/LV plus nanoliposomal ...
# 3                                        [None, None]
# 4                                        [None, None]
# 5                                              [None]
# 6                                              [None]
# 7             [None, 08/07/19 -, 09/19/20, currently]
# 8   [12, 5FU & liposomal irinotecan x 12, None, No...
# 9   [None, 5FU & liposomal, None, None, None, None...
# 10                                             [None]
# 11                                 [None, None, None]
# 12                           [None, None, None, None]
# 13                                       [None, None]
# 14                                                 []
# 15                                             [None]
# 16                                             [None]
# 17                                             [None]
# 18                                             [None]
# 19                           [None, None, None, None]
# 20  [100 mg capsule, furosemide (LASIX) 40 mg tabl...
# 21                                          [1994 to]
# 22                                                 []
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27                                                 []
# 28                    [350 mg iodine/mL solution 150]
# 29                                                 []
# 30                                                 []
# 31                                             [None]
# 32                                             [None]
# 33                                                 []
# 34                                                 []
# 35                                                 []
# 36                                                 []
# 37                                                 []
# 38                                             [None]
# 39                                                 []
#
#                                           past_method  \
# 0                                        [None, None]
# 1                                        [None, None]
# 2                        [None, None, None, onivyde)]
# 3                                        [None, None]
# 4                                        [None, None]
# 5                                              [None]
# 6                                              [None]
# 7                    [06/15/19), 01/09/20), ongoing)]
# 8                  [cycles, cycles, None, None, None]
# 9   [None, irinotecan, None, None, None, None, Non...
# 10                                            [2021)]
# 11                                 [None, None, None]
# 12                           [None, None, None, None]
# 13                                       [None, None]
# 14                                                 []
# 15                                             [None]
# 16                                             [None]
# 17                                             [None]
# 18                                             [None]
# 19                           [None, None, None, None]
# 20                                               [mg]
# 21                                             [1996]
# 22                                                 []
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27                                                 []
# 28                                               [ml]
# 29                                                 []
# 30                                                 []
# 31                                             [None]
# 32                                             [None]
# 33                                                 []
# 34                                                 []
# 35                                                 []
# 36                                                 []
# 37                                                 []
# 38                                             [None]
# 39                                                 []
#
#                                 current_symptoms_list  \
# 0   [Intermittent abdominal discomfort, usually at...
# 1   [Intermittent fevers for 4-5 days following tr...
# 2   [Tolerating POs adequately since stent placeme...
# 3   [She does complain of brain fog which she attr...
# 4                [Continues to have some oral thrush]
# 5   [continued abdominal discomfort particularly o...
# 6   [She has no cancer pain but takes oxycodone fo...
# 7   [She denies any pain at present (currently on ...
# 8   [Worsening neuropathy., Improved abd pain., Tr...
# 9   [Feels ‘almost normal, Notes constant saltines...
# 10  [early satiety, nausea post prandial, loss of ...
# 11  [(+) weight loss, (+) bloating, (+) bilirubinu...
# 12  [Fevers episodically around 12/20/21 for a few...
# 13  [Appetite has been sluggish in the past few we...
# 14    [HgBA1C running >12, No pain. Wounds improved.]
# 15  [Her energy level is low and her appetite is l...
# 16  [Patient has felt very well., He is exercising...
# 17  [She is very fatigued and sleeps about 12 hour...
# 18  [Patient reports increased fatigue over the pa...
# 19  [Appetite fair, some early satiety and postpra...
# 20  [dyspnea, no pain at the site of her breast su...
# 21  [lack of energy and pain in her right hand, di...
# 22  [Patient with early stage breast cancer here t...
# 23      [tenderness at biopsy site and around axilla]
# 24  [mild joint stiffness, in particular in her kn...
# 25  [No bone pain or any other systemic concerns, ...
# 26  [Worsening GERD, nausea, fatigue for 3 days af...
# 27  [Feeling well since surgery, healing well, sli...
# 28  [Left breast mass growing rapidly, some discol...
# 29  [Found mass in her right breast while on vacat...
# 30  [Left breast still somewhat sore post-surgery,...
# 31              [Feeling well, no new symptoms noted]
# 32  [No new symptoms noted, patient here for treat...
# 33         [2 cm R breast mass 8 cm from the nipple.]
# 34  [Right lateral neck lump increasing in size, s...
# 35  [Right breast aching that is gradually increas...
# 36  [Mild left breast pain status post lumpectomy ...
# 37       [Left breast lump palpated in December 2017]
# 38  [Minimal joint aches, mild hot flashes and ins...
# 39  [Felt a lump in the right breast, two episodes...
#
#                                    past_symptoms_list  \
# 0   [Several months of vague abdominal discomfort,...
# 1   [Abdominal discomfort and biliary ductal obstr...
# 2   [Progressive anorexia and fatigue, Mild thromb...
# 3   [She does complain of brain fog which she attr...
# 4     [Presented with abdominal pain and weight loss]
# 5   [abdominal discomfort, bloating and eventually...
# 6   [symptoms of small bowel obstruction in early ...
# 7   [Painless jaundice (May 2019), Persistent mid-...
# 8   [Peripheral neuropathy - improved off of treat...
# 9   [Peripheral neuropathy, Diarrhea with every PO...
# 10  [abdominal pain x1mo, 35lb weight loss, emesis...
# 11  [weight loss (8 lbs over past month), decline ...
# 12  [acute symptomatic anemia, fever with leukocyt...
# 13  [2 months of intermittent epigastric and left ...
# 14  [03/19/17 he presented to ***** with 3 weeks o...
# 15  [November 2018: Presented to her primary care ...
# 16  [October 2017: abd pain. Seen in ED sent home....
# 17  [Severe adverse events including metabolic abn...
# 18  [Presented with abdominal pain and weight loss...
# 19  [intermittent mid/LUQ abdominal discomfort, bl...
# 20  [painful mass in her right breast, firm mobile...
# 21  [neuropathy of the right hand associated with ...
# 22                  [felt a mass in her right breast]
# 23  [chronic back and shoulder pain x 2 years, chr...
# 24    [Felt lump in her left breast in February 2017]
# 25                           [None explicitly stated]
# 26                           [None explicitly stated]
# 27  [Left breast mass, numbness of L axilla and L ...
# 28  [Palpated a mass in her left breast while brea...
# 29                           [None explicitly stated]
# 30                           [None explicitly stated]
# 31  [Felt a mass in her right breast in late January]
# 32  [Felt a mass in her right breast while on vaca...
# 33  [Self-palpated right breast mass in December 2...
# 34                           [None explicitly stated]
# 35  [Left breast had an area of increased density,...
# 36  [Left breast mass measuring 2cm after feeling ...
# 37                           [None explicitly stated]
# 38  [Left breast mass, history of postoperative na...
# 39                           [None explicitly stated]
#
#                               chronic_conditions_list  \
# 0   [Hypertension, voluntarily stopped his antihyp...
# 1   [COPD (chronic obstructive pulmonary disease) ...
# 2                      [Metastatic pancreatic cancer]
# 3         [Metastatic adenocarcinoma of the pancreas]
# 4   [Stage IV pancreatic adenocarcinoma, Biopsy-pr...
# 5   [Borderline resectable/locally advanced adenoc...
# 6   [Chronic opioid use, arthritis, chronic back p...
# 7   [Hypertension, Hyperlipidemia, Adenomatous pol...
# 8   [Asthma, Breast cancer (HCC), Difficult intuba...
# 9   [Diabetes with A1C 10, Locally advanced pancre...
# 10  [Borderline hypertension, Diabetes (CMS code) ...
# 11  [Pancreatic adenocarcinoma, Diabetes, Hyperten...
# 12  [Pancreatic adenocarcinoma, Prostate cancer, C...
# 13  [HTN, Dyslipidemia, Pre-diabetes, Lumbar steno...
# 14  [Arthritis, History of continuous positive air...
# 15  [Pancreatic adenocarcinoma, Orthostatic hypote...
# 16          [Locally advanced pMMR pancreatic cancer]
# 17  [Hypertension, History of hypothyroidism, Asth...
# 18  [Locally advanced and unresectable adenocarcin...
# 19  [Anxiety, Environmental allergies, metastatic ...
# 20  [Cardiac pacemaker in situ, Cataract, CHF (con...
# 21  [osteoarthritis in the left hand, trace emphys...
# 22  [Abnormal liver enzymes 2012, Hyperbilirubinem...
# 23  [Cataract, Elevated CA-125, GERD (gastroesopha...
# 24      [Breast cancer, Diabetes 08/09/2017, Obesity]
# 25                 [Breast cancer, Diabetes mellitus]
# 26  [Lynch syndrome, Colon cancer (HCC), Metastati...
# 27  [Arthritis, Breast cancer (left side), Catarac...
# 28  [Stage III HR+/HER2- IDC of the left breast, H...
# 29  [Breast cancer, right breast, Closed left ankl...
# 30  [Migraine, Chronic low back pain, Right-sided ...
# 31  [Breast cancer, Fibrocystic breast disease, Li...
# 32                    [Breast cancer, Hypothyroidism]
# 33  [Bipolar 2 disorder, Insomnia, Breast Cancer R...
# 34  [Back pain, Breast cancer, Depression, Hyperte...
# 35  [Hypertension (for 30 years), Hysterectomy and...
# 36                       [Breast cancer, left breast]
# 37                                     [ATM mutation]
# 38  [ER+/PR-/HER2- left breast cancer, Endometrios...
# 39                              [Breast cancer (HCC)]
#
#                                   family_history_list
# 0   [There is no cancer among his first-degree rel...
# 1   [Father Pancreatic cancer, Maternal Uncle Panc...
# 2   [Comprehensive past medical, family, and socia...
# 3                                              [none]
# 4   [Past medical, social, and family history were...
# 5                                              [none]
# 6   [The only cancer in her family is in maternal ...
# 7   [Paternal grandmother with esophageal cancer, ...
# 8   [Stomach cancer Mother  71, Colon cancer Siste...
# 9   [No new updates, reviewed and unchanged from p...
# 10  [Breast cancer (Mother), Prostate cancer (Fath...
# 11           [No updates from prior visits, per note]
# 12  [Hearing loss (Mother), Heart disease (Mother)...
# 13  [Reviewed; no hereditary pattern of cancer not...
# 14                                             [none]
# 15  [Past medical, social, and family history: Unc...
# 16                                             [none]
# 17  [Her father had prostate cancer., She has 3 pa...
# 18  [She has 4 siblings. One sister was diagnosed ...
# 19  [Ovarian cancer – Mother, Lung cancer – Matern...
# 20  [Stroke (Mother), Uterine cancer (Mother) age ...
# 21  [one maternal aunt with breast cancer at the a...
# 22  [Breast cancer in her sister, Cancer (age of o...
# 23  [Cancer Mother 35 - breast cancer, Hypertensio...
# 24            [Breast cancer Maternal Grandmother 58]
# 25  [Family history unknown: Yes, no h/o malignanc...
# 26  [Leukemia Mother - as a child, in remission, O...
# 27  [Paternal grandmother passed away from breast ...
# 28  [Lymphoma Father, No family history of breast ...
# 29  [Lung cancer - Father (Age 68), Melanoma - Mat...
# 30  [Hypertension - Mother, Arthritis - Mother, De...
# 31  [Breast cancer - Mother (early 50s, had unilat...
# 32                           [Breast cancer - Cousin]
# 33  [Alzheimer's disease - Paternal Grandfather, A...
# 34  [Cerebral aneurysm - Father, Melanoma - Negati...
# 35  [Mother had Parkinson's disease, does not know...
# 36  [Breast cancer - Paternal Grandmother (Age 35)...
# 37  [Breast cancer - Mother, Breast cancer - Other...
# 38  [Mother had Parkinson's disease, does not know...
# 39  [Colon cancer - Father (diagnosed in late 40s,...
#
# [40 rows x 27 columns]

# %%
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np

# ---------------------------
# 1. Create the 'group' column based on 'patient note'
# ---------------------------
def get_group(note):
    """Determine the group based on patient note.
       If note starts with 'pdac' (case-insensitive) => 'pdac';
       if starts with 'bc' => 'BC'; else 'unknown'."""
    if pd.isnull(note):
        return "unknown"
    note_str = str(note).strip().lower()
    if note_str.startswith("pdac"):
        return "pdac"
    elif note_str.startswith("bc"):
        return "BC"
    else:
        return "unknown"

# (Assuming the column name is exactly 'patient note')
combined_df['group'] = combined_df['Patient Note'].apply(get_group)

# ---------------------------
# 2. Graph Age and Gender Distributions
# ---------------------------

# Graph 2A: Age distribution by group (using a histogram for each group)
plt.figure(figsize=(8, 6))
groups = combined_df['group'].unique()
for grp in groups:
    subset = combined_df[combined_df['group'] == grp]
    plt.hist(subset['Age'].dropna(), bins=20, alpha=0.5, label=grp)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution by Group')
plt.legend()
plt.tight_layout()
plt.show()

# Graph 2B: Gender distribution by group (bar plot)
# Create a pivot table: counts of gender per group
gender_counts = combined_df.groupby('group')['Gender'].value_counts().unstack(fill_value=0)
gender_counts.plot(kind='bar', figsize=(8, 6))
plt.xlabel('Group')
plt.ylabel('Count')
plt.title('Gender Distribution by Group')
plt.tight_layout()
plt.show()

# ---------------------------
# 3. Drug Counts and Distributions
# ---------------------------

import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np

# Helper function to recursively flatten a nested list
def flatten_drug_list(nested_list):
    flat_list = []
    for element in nested_list:
        if isinstance(element, list):
            flat_list.extend(flatten_drug_list(element))
        else:
            flat_list.append(element)
    return flat_list

# Updated combine_drugs function to ensure flattening if necessary
def combine_drugs(row):
    drugs = []
    if 'current_drug' in row and isinstance(row['current_drug'], list):
        drugs += row['current_drug']
    if 'past_drug' in row and isinstance(row['past_drug'], list):
        drugs += row['past_drug']
    # Flatten the result so that it's a flat list of strings
    return flatten_drug_list(drugs)

# Assuming your DataFrame is called combined_df and already has columns 'current_drug' and 'past_drug'
combined_df['all_drugs'] = combined_df.apply(combine_drugs, axis=1)

# Count drugs by group using the flattened list
drug_counts_by_group = {}
for grp in combined_df['group'].unique():
    grp_drugs_series = combined_df[combined_df['group'] == grp]['all_drugs']
    flat_list = []
    for drugs in grp_drugs_series:
        # Flatten each cell's drugs and filter out entries that are "none"
        flat_list.extend([d for d in flatten_drug_list(drugs)
                          if isinstance(d, str) and d.lower() != 'none'])
    counts = Counter(flat_list)
    drug_counts_by_group[grp] = counts

# For example, plot the top 10 drugs for each group as a bar chart:
for grp, counts in drug_counts_by_group.items():
    top_drugs = counts.most_common(10)
    if not top_drugs:
        continue
    drugs, count_values = zip(*top_drugs)
    plt.figure(figsize=(8, 6))
    plt.bar(drugs, count_values)
    plt.xticks(rotation=45, ha='right')
    plt.xlabel('Drug')
    plt.ylabel('Count')
    plt.title(f'Top 10 Drugs in Group {grp.upper()}')
    plt.tight_layout()
    plt.show()

# Overall drug counts (regardless of group)
all_drugs_flat = [drug for sublist in combined_df['all_drugs'] for drug in sublist if drug.lower() != 'none']
overall_drug_counts = Counter(all_drugs_flat)
top_10_drugs = [drug for drug, cnt in overall_drug_counts.most_common(10)]

# For each of the top 10 drugs, plot a scatter of age vs. group with points colored by gender.
# (Here we use distinct markers or colors for gender.)
colors = {'male': 'blue', 'female': 'red', 'unknown': 'gray'}
for drug in top_10_drugs:
    # Filter rows where the drug is present
    mask = combined_df['all_drugs'].apply(lambda drugs: drug in drugs)
    sub_df = combined_df[mask]
    if sub_df.empty:
        continue
    plt.figure(figsize=(8, 6))
    for grp in sub_df['group'].unique():
        grp_df = sub_df[sub_df['group'] == grp]
        # Scatter plot: age on x-axis; using group as y value (jittered for visualization)
        y_vals = np.full(shape=len(grp_df), fill_value=0)  # use jitter instead of literal group text
        jitter = np.random.uniform(-0.1, 0.1, size=len(grp_df))
        y_vals = y_vals + jitter
        plt.scatter(grp_df['Age'], y_vals,
                    c=[colors.get(g, 'gray') for g in grp_df['Gender']],
                    label=f"{grp} - {drug}", alpha=0.7)
    plt.xlabel('Age')
    plt.ylabel('Patients (jittered)')
    plt.title(f'Age Distribution for Patients Taking {drug}')
    plt.legend()
    plt.tight_layout()
    plt.show()

# ---------------------------
# 4. Symptoms and Chronic Conditions Counts
# ---------------------------

# A helper function to flatten list columns and count items
def flatten_and_count(col_name):
    items = [item for sublist in combined_df[col_name] if isinstance(sublist, list) for item in sublist]
    return Counter(items)

# Current symptoms counts
current_symptom_counts = flatten_and_count('current_symptoms_list')
top_10_symptoms = [symptom for symptom, cnt in current_symptom_counts.most_common(10)]

plt.figure(figsize=(8, 6))
symptom_counts_values = [current_symptom_counts[symptom] for symptom in top_10_symptoms]
plt.bar(top_10_symptoms, symptom_counts_values)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Symptom')
plt.ylabel('Count')
plt.title('Top 10 Current Symptoms')
plt.tight_layout()
plt.show()

# Chronic conditions counts
chronic_counts = flatten_and_count('chronic_conditions_list')
top_10_chronic = [cond for cond, cnt in chronic_counts.most_common(10)]

plt.figure(figsize=(8, 6))
chronic_counts_values = [chronic_counts[cond] for cond in top_10_chronic]
plt.bar(top_10_chronic, chronic_counts_values)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Chronic Condition')
plt.ylabel('Count')
plt.title('Top 10 Chronic Conditions')
plt.tight_layout()
plt.show()

# ---------------------------
# Optional: Distributions for Symptoms vs. Age/Gender
# ---------------------------
# For example, for each of the top symptoms, you could create a scatter plot of age colored by gender.
for symptom in top_10_symptoms:
    mask = combined_df['current_symptoms_list'].apply(lambda symptoms: symptom in symptoms)
    sub_df = combined_df[mask]
    if sub_df.empty:
        continue
    plt.figure(figsize=(8, 6))
    for grp in sub_df['group'].unique():
        grp_df = sub_df[sub_df['group'] == grp]
        y_vals = np.full(len(grp_df), 0)
        jitter = np.random.uniform(-0.1, 0.1, size=len(grp_df))
        y_vals = y_vals + jitter
        plt.scatter(grp_df['Age'], y_vals,
                    c=[colors.get(g, 'gray') for g in grp_df['Gender']],
                    label=f"{grp} - {symptom}", alpha=0.7)
    plt.xlabel('Age')
    plt.ylabel('Patients (jittered)')
    plt.title(f'Age Distribution for Patients with Symptom: {symptom}')
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# /var/folders/kw/st1ymrwj7q923cvxxbj099fh0000gn/T/ipykernel_4526/2594763336.py:162: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# %pip install google-generativeai
# Out:
# Collecting google-generativeai
#   Downloading google_generativeai-0.8.4-py3-none-any.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Collecting google-ai-generativelanguage==0.6.15 (from google-generativeai)
#   Downloading google_ai_generativelanguage-0.6.15-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 994.6 kB/s eta 0:00:00:0100:01
# Collecting google-api-core (from google-generativeai)
#   Downloading google_api_core-2.24.2-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 789.5 kB/s eta 0:00:00a 0:00:01
# Collecting google-api-python-client (from google-generativeai)
#   Downloading google_api_python_client-2.165.0-py2.py3-none-any.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 715.8 kB/s eta 0:00:0000:0100:01
# Collecting google-auth>=2.15.0 (from google-generativeai)
#   Downloading google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.8/210.8 kB 949.4 kB/s eta 0:00:00a 0:00:01
# Collecting protobuf (from google-generativeai)
#   Downloading protobuf-6.30.1-cp39-abi3-macosx_10_9_universal2.whl (417 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.6/417.6 kB 714.6 kB/s eta 0:00:00a 0:00:01
# Collecting pydantic (from google-generativeai)
#   Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.7/431.7 kB 504.1 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tqdm in ./venv/lib/python3.11/site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in ./venv/lib/python3.11/site-packages (from google-generativeai) (4.13.0)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-ai-generativelanguage==0.6.15->google-generativeai)
#   Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 705.5 kB/s eta 0:00:00:--:--
# Collecting protobuf (from google-generativeai)
#   Downloading protobuf-5.29.4-cp38-abi3-macosx_10_9_universal2.whl (417 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.8/417.8 kB 683.2 kB/s eta 0:00:00a 0:00:01
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=2.15.0->google-generativeai)
#   Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=2.15.0->google-generativeai)
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 787.8 kB/s eta 0:00:00a 0:00:01
# Collecting rsa<5,>=3.1.4 (from google-auth>=2.15.0->google-generativeai)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core->google-generativeai)
#   Downloading googleapis_common_protos-1.69.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.2/293.2 kB 674.2 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in ./venv/lib/python3.11/site-packages (from google-api-core->google-generativeai) (2.32.3)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client->google-generativeai)
#   Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client->google-generativeai)
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client->google-generativeai)
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting annotated-types>=0.6.0 (from pydantic->google-generativeai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.27.2 (from pydantic->google-generativeai)
#   Downloading pydantic_core-2.27.2-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 623.6 kB/s eta 0:00:0000:0100:01
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core->google-generativeai)
#   Downloading grpcio-1.71.0-cp311-cp311-macosx_10_14_universal2.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 556.8 kB/s eta 0:00:0000:0100:01
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core->google-generativeai)
#   Downloading grpcio_status-1.71.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in ./venv/lib/python3.11/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.3)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai)
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 683.2 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.1.31)
# Installing collected packages: uritemplate, pydantic-core, pyasn1, protobuf, httplib2, grpcio, cachetools, annotated-types, rsa, pydantic, pyasn1-modules, proto-plus, googleapis-common-protos, grpcio-status, google-auth, google-auth-httplib2, google-api-core, google-api-python-client, google-ai-generativelanguage, google-generativeai
# Successfully installed annotated-types-0.7.0 cachetools-5.5.2 google-ai-generativelanguage-0.6.15 google-api-core-2.24.2 google-api-python-client-2.165.0 google-auth-2.38.0 google-auth-httplib2-0.2.0 google-generativeai-0.8.4 googleapis-common-protos-1.69.2 grpcio-1.71.0 grpcio-status-1.71.0 httplib2-0.22.0 proto-plus-1.26.1 protobuf-5.29.4 pyasn1-0.6.1 pyasn1-modules-0.4.1 pydantic-2.10.6 pydantic-core-2.27.2 rsa-4.9 uritemplate-4.1.1
#
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import json
import requests
import time

# Expected fields to extract
#EXPECTED_FIELDS = [
#    "Current Medications", "Past Medications", "Patient Current Age",
#    "Current Symptoms", "Past Symptoms", "Chronic Conditions",
#    "Family History", "Reason for Visit", "Primary Diagnosis",
#    "Procedure Names", "Information Relevant to Primary Diagnosis",
#    "Age", "Gender"
#]

EXPECTED_FIELDS = [
    "Drug Name", "Drug Dosage", "Drug Route of Administration", "Drug Strength", "Drug Form", "Frequency of Drug Intake", "Duration of Drug Intake",
    "Age", "Gender"
]

def extract_fields_from_note(note, api_key= ""):
    """
    Calls the Gemini API and returns extracted fields or False-filled dict on error.
    """
    api_url = f"https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent?key={api_key}"

    prompt = f"""
    Extract the following information from the patient note. If information is not present, return "Not mentioned":
    
    Patient Note:
    {note}
    
   - Extract and format as a JSON object with these fields:
   - Drug Name
   - Drug Dosage 
   - Drug Route of Administration
   - Drug Strength 
   - Drug Form
   - Frequency of Drug Intake 
   - Duration of Drug Intake
   - Age
   - Gender


    Return ONLY the JSON object, with no additional text before or after.
    """

    payload = {
        "contents": [{"parts": [{"text": prompt}]}],
        "generationConfig": {
            "temperature": 0.2,
            "maxOutputTokens": 3000
        }
    }

    headers = {"Content-Type": "application/json"}

    try:
        response = requests.post(api_url, json=payload, headers=headers)
        if response.status_code == 200:
            content = response.json()['candidates'][0]['content']['parts'][0]['text']
            json_start = content.find('{')
            json_end = content.rfind('}') + 1
            if json_start >= 0 and json_end > json_start:
                json_str = content[json_start:json_end]
                data = json.loads(json_str)
                return {field: data.get(field, "Not mentioned") for field in EXPECTED_FIELDS}
            else:
                return {field: False for field in EXPECTED_FIELDS}
        else:
            print(f"API error at status {response.status_code}: {response.text}")
            return {field: False for field in EXPECTED_FIELDS}
    except Exception as e:
        print(f"Exception during API call: {e}")
        return {field: False for field in EXPECTED_FIELDS}


def process_dataframe_clean(df, api_key, note_column="Entire Patient Note"):
    """
    Processes the dataframe and ensures 41 rows output: 1 header + 40 patient notes.
    Fills in all fields even on error with False values.
    """
    processed_data = []

    for idx in range(40):  # Force exactly 40 rows
        if idx >= len(df):
            processed_data.append({field: False for field in EXPECTED_FIELDS})
            continue

        note = df.iloc[idx].get(note_column, "")
        if pd.isna(note) or note.strip() == "":
            print(f"Skipping empty note at index {idx}")
            processed_data.append({field: False for field in EXPECTED_FIELDS})
            continue

        print(f"Processing note {idx+1}/40...")
        extracted_fields = extract_fields_from_note(note, api_key)
        processed_data.append(extracted_fields)
        time.sleep(0.5)

    # Create final DataFrame
    final_df = pd.DataFrame(processed_data, columns=EXPECTED_FIELDS)
    final_df.index.name = "Patient Index"
    return final_df


# Example usage:
final_df = process_dataframe_clean(combined_df, api_key="")
final_df.to_csv("cleaned_extracted_medical_info_all_drug_categories_RG.csv")
# Out:
# Processing note 1/40...
# Processing note 2/40...
# Processing note 3/40...
# Processing note 4/40...
# Processing note 5/40...
# Processing note 6/40...
# Processing note 7/40...
# Processing note 8/40...
# Processing note 9/40...
# Processing note 10/40...
# Processing note 11/40...
# Processing note 12/40...
# Processing note 13/40...
# Processing note 14/40...
# Processing note 15/40...
# Processing note 16/40...
# Processing note 17/40...
# Processing note 18/40...
# Processing note 19/40...
# Processing note 20/40...
# Processing note 21/40...
# Processing note 22/40...
# Processing note 23/40...
# Processing note 24/40...
# Processing note 25/40...
# Processing note 26/40...
# Processing note 27/40...
# Processing note 28/40...
# Processing note 29/40...
# Processing note 30/40...
# Processing note 31/40...
# Processing note 32/40...
# Processing note 33/40...
# Processing note 34/40...
# Processing note 35/40...
# Processing note 36/40...
# Processing note 37/40...
# Processing note 38/40...
# Processing note 39/40...
# Processing note 40/40...

# %%
##Remove duplicates from med7 files:
import json
from collections import Counter

def replace_nested_with_mode(json_file_path, json_file_name):
    with open(json_file_path, 'r') as f:
        data = json.load(f)
    
    for entry in data:
        for key, value in entry.items():
            if isinstance(value, list) and value:
                normalized_values = [v.lower() for v in value]
                counts = Counter(normalized_values)
                most_common = counts.most_common()
                
                entry[key] = most_common[0][0]  
    
    with open('modified_' + json_file_name, 'w') as f:
        json.dump(data, f, indent=2)
    
    return data

json_file_name = "medications_note_pdac1.json"  
json_file_path = "med7/medications_note_pdac2.json"
processed_data = replace_nested_with_mode(json_file_path, json_file_name)

# %%
#modify all json files so no duplicates
for i in range(0, 40):
    if i < 20:
        json_file_name = "medications_note_pdac" + str(i) + ".json"
    else:
        json_file_name = "medications_note_BC" + str(i) + ".json"
    
    json_file_path = "med7/" + json_file_name
    replace_nested_with_mode(json_file_path=json_file_path, json_file_name=json_file_name)

# %%
#Take modified json file and convert to dataframe format we like
def json_to_single_row_dataframe(json_file):
    with open(json_file, 'r') as f:
        data = json.load(f)
    
    columns = [
        "Drug Name", "Drug Dosage", "Drug Route of Administration", "Drug Strength", 
        "Drug Form", "Frequency of Drug Intake", "Duration of Drug Intake"
    ]
    
    json_keys = ["DRUG", "DOSAGE", "ROUTE", "STRENGTH", "FORM", "FREQUENCY", "DURATION"]
    
    n = len(data)
    processed_data = {
        col: [entry.get(key, "Not mentioned") for entry in data]
        for col, key in zip(columns, json_keys)
    }
    
    df = pd.DataFrame([processed_data])
    return df

json_file = "modified_med7/modified_medications_note_pdac0.json" 
df = json_to_single_row_dataframe(json_file)
display(df)
# Out:
#                                            Drug Name  \
# 0  [gemcitabine, Abraxane, antibiotics, oxycodone...
#
#                                          Drug Dosage  \
# 0  [Not mentioned, Not mentioned, Not mentioned, ...
#
#                         Drug Route of Administration  \
# 0  [Not mentioned, iv, Not mentioned, Not mention...
#
#                                        Drug Strength  \
# 0  [Not mentioned, Not mentioned, Not mentioned, ...
#
#                                            Drug Form  \
# 0  [Not mentioned, Not mentioned, Not mentioned, ...
#
#                             Frequency of Drug Intake  \
# 0  [Not mentioned, Not mentioned, Not mentioned, ...
#
#                              Duration of Drug Intake
# 0  [Not mentioned, Not mentioned, Not mentioned, ...

# %%
#convert all modified json files into one df
def concat_all_json_dfs():
    final_df = pd.DataFrame()
    for i in range(0, 40):
        if i < 20:
            json_file = "modified_med7/modified_medications_note_pdac" + str(i) + ".json"
        else:
            json_file = "modified_med7/modified_medications_note_BC" + str(i) + ".json"
        new_row = json_to_single_row_dataframe(json_file)
        final_df= pd.concat([final_df, new_row], ignore_index=True)
    return final_df

med7_df = concat_all_json_dfs()
med7_df.to_csv("Med7_Extracted_Results_RG.csv")
display(med7_df)
# Out:
#                                             Drug Name  \
# 0   [gemcitabine, Abraxane, antibiotics, oxycodone...
# 1   [Cipro, FOLFIRINOX, FOLFIRINOX, FOLFIRINOX, Ge...
# 2   [FOLFIRINOX, chemotherapy, FOLFOX, 5-FU, oxali...
# 3   [FOLFIRINOX, gemcitabine, Abraxane, chemothera...
# 4   [FOLFIRINOX, Irinotecan, FOLFOX, FOLFIRINOX, I...
# 5   [FOLFIRINOX, CONTRAST, Omnipaque, CONTRAST, co...
# 6   [chemotherapy, gemcitabine, Abraxane, oxycodon...
# 7   [Not mentioned, FOLFOX chemotherapy, irinoteca...
# 8   [FOLFIRINOX, FOLFIRINOX, 5FU, irinotecan, 5FU,...
# 9   [FOLFIRINOX, FOLFIRINOX, 5FU, oxaliplatin, iri...
# 10  [omeprazole, mFOLFIRINOX, metformin, acetamino...
# 11  [gemcitabine, nab-paclitaxel, mFOLFIRINOX, mFO...
# 12  [vori, iron, FOLFIRINOX, Vanco, FOLFIRINOX, PR...
# 13  [oxycodone, Tylenol, oxycodone, amLODIPine, NO...
# 14  [FOLFIRINOX, FOLFIRINOX, acetaminophen, TYLENO...
# 15  [IVF, IVF, Gemcitabine, chlorhexidine, chlorhe...
# 16  [chemotherapy, chemotherapy, FOLFIRINOX, Irino...
# 17  [gemcitabine, Abraxane, gemcitabine, capecitab...
# 18  [pain medications, gemcitabine, Abraxane, FOLF...
# 19  [metronidazole, rifaximin, probiotics, Tylenol...
# 20  [Lasix, OCP, acetaminophen, TYLENOL, aspirin, ...
# 21  [tamoxifen, CoQ10, oral contraceptives, hormon...
# 22  [oral contraceptives, hormone replacement ther...
# 23  [TYLENOL, alendronate, FOSAMAX, ascorbate calc...
# 24  [chemotherapy, chemotherapy, OCP, chemotherapy...
# 25  [ergocalciferol, vitamin D2, ERGOCALCIFEROL, m...
# 26  [Not mentioned, paclitaxel, pembrolizumab, pem...
# 27  [PPI, oral contraceptives, acetaminophen, TYLE...
# 28  [ddAC, leuprolide, exemestane, leuprolide, tam...
# 29  [Sulfa (Sulfonamide Antibiotics), CETRORELIX, ...
# 30  [Penicillins, amLODIPine, NORVASC, NEURONTIN, ...
# 31  [Clomid, chemotherapy, simvastatin, ZOCOR, LOR...
# 32  [chemotherapy, cholecalciferol, vitamin D3, VI...
# 33  [lamictal, Aripiprazole, Lurasidone, ascorbic ...
# 34  [OCP, buPROPion, cetirizine, ZYRTEC, docusate ...
# 35  [black cohosh, Hydrochlorothiazide, potassium,...
# 36  [Penicillins, cholecalciferol, vitamin D3, VIT...
# 37  [Sulfa, Sulfonamide Antibiotics), ibuprofen, A...
# 38  [tamoxifen, letrozole, exemestane, letrozole, ...
# 39  [chemotherapy, anthracycline, taxane, docetaxe...
#
#                                           Drug Dosage  \
# 0   [Not mentioned, Not mentioned, Not mentioned, ...
# 1   [Not mentioned, Not mentioned, Not mentioned, ...
# 2   [Not mentioned, Not mentioned, Not mentioned, ...
# 3   [Not mentioned, Not mentioned, Not mentioned, ...
# 4   [Not mentioned, Not mentioned, Not mentioned, ...
# 5   [Not mentioned, Not mentioned, Not mentioned, ...
# 6   [Not mentioned, Not mentioned, Not mentioned, ...
# 7   [Not mentioned, Not mentioned, Not mentioned, ...
# 8   [Not mentioned, Not mentioned, Not mentioned, ...
# 9   [Not mentioned, Not mentioned, Not mentioned, ...
# 10  [Not mentioned, Not mentioned, Not mentioned, ...
# 11  [Not mentioned, Not mentioned, Not mentioned, ...
# 12  [Not mentioned, Not mentioned, Not mentioned, ...
# 13  [Not mentioned, Not mentioned, Not mentioned, ...
# 14  [Not mentioned, Not mentioned, Not mentioned, ...
# 15  [Not mentioned, Not mentioned, Not mentioned, ...
# 16  [Not mentioned, Not mentioned, Not mentioned, ...
# 17  [Not mentioned, Not mentioned, Not mentioned, ...
# 18  [Not mentioned, Not mentioned, Not mentioned, ...
# 19  [Not mentioned, Not mentioned, Not mentioned, ...
# 20  [Not mentioned, Not mentioned, Not mentioned, ...
# 21  [Not mentioned, Not mentioned, Not mentioned, ...
# 22  [Not mentioned, Not mentioned, Not mentioned, ...
# 23  [1, Not mentioned, 1, Not mentioned, Not menti...
# 24  [Not mentioned, Not mentioned, Not mentioned, ...
# 25  [Not mentioned, Not mentioned, Not mentioned, ...
# 26  [Not mentioned, Not mentioned, Not mentioned, ...
# 27  [Not mentioned, Not mentioned, Not mentioned, ...
# 28  [Not mentioned, Not mentioned, Not mentioned, ...
# 29  [Not mentioned, Not mentioned, Not mentioned, ...
# 30  [Not mentioned, Not mentioned, 1 \n , 1, 1, No...
# 31  [Not mentioned, Not mentioned, Not mentioned, ...
# 32  [Not mentioned, Not mentioned, Not mentioned, ...
# 33  [Not mentioned, Not mentioned, Not mentioned, ...
# 34  [Not mentioned, Not mentioned, Not mentioned, ...
# 35  [Not mentioned, Not mentioned, Not mentioned, ...
# 36  [Not mentioned, Not mentioned, Not mentioned, ...
# 37  [Not mentioned, Not mentioned, Not mentioned, ...
# 38  [Not mentioned, Not mentioned, Not mentioned, ...
# 39  [Not mentioned, Not mentioned, Not mentioned, ...
#
#                          Drug Route of Administration  \
# 0   [Not mentioned, iv, Not mentioned, Not mention...
# 1   [Not mentioned, Not mentioned, Not mentioned, ...
# 2   [Not mentioned, Not mentioned, Not mentioned, ...
# 3   [Not mentioned, Not mentioned, Not mentioned, ...
# 4   [Not mentioned, Not mentioned, Not mentioned, ...
# 5   [Not mentioned, Not mentioned, Not mentioned, ...
# 6   [Not mentioned, Not mentioned, Not mentioned, ...
# 7   [Not mentioned, Not mentioned, Not mentioned, ...
# 8   [Not mentioned, Not mentioned, Not mentioned, ...
# 9   [Not mentioned, Not mentioned, Not mentioned, ...
# 10  [Not mentioned, Not mentioned, Not mentioned, ...
# 11  [Not mentioned, Not mentioned, Not mentioned, ...
# 12  [Not mentioned, Not mentioned, Not mentioned, ...
# 13  [Not mentioned, Not mentioned, Not mentioned, ...
# 14  [Not mentioned, Not mentioned, Not mentioned, ...
# 15  [Not mentioned, Not mentioned, Not mentioned, ...
# 16  [Not mentioned, Not mentioned, Not mentioned, ...
# 17  [Not mentioned, Not mentioned, Not mentioned, ...
# 18  [Not mentioned, Not mentioned, Not mentioned, ...
# 19  [Not mentioned, Not mentioned, Not mentioned, ...
# 20  [Not mentioned, Not mentioned, Not mentioned, ...
# 21  [Not mentioned, Not mentioned, Not mentioned, ...
# 22  [Not mentioned, Not mentioned, Not mentioned, ...
# 23  [by mouth, Not mentioned, BY MOUTH, by mouth, ...
# 24  [Not mentioned, Not mentioned, Not mentioned, ...
# 25  [Not mentioned, Not mentioned, Not mentioned, ...
# 26  [Not mentioned, Not mentioned, Not mentioned, ...
# 27  [Not mentioned, Not mentioned, Not mentioned, ...
# 28  [Not mentioned, Not mentioned, Not mentioned, ...
# 29  [Not mentioned, under the skin, Not mentioned,...
# 30  [Not mentioned, Not mentioned, by mouth, by mo...
# 31  [Not mentioned, Not mentioned, Not mentioned, ...
# 32  [Not mentioned, Not mentioned, Not mentioned, ...
# 33  [Not mentioned, Not mentioned, Not mentioned, ...
# 34  [Not mentioned, by mouth, Not mentioned, by mo...
# 35  [Not mentioned, Not mentioned, Not mentioned, ...
# 36  [Not mentioned, Not mentioned, Not mentioned, ...
# 37  [Not mentioned, Not mentioned, Not mentioned, ...
# 38  [Not mentioned, Not mentioned, Not mentioned, ...
# 39  [Not mentioned, Not mentioned, Not mentioned, ...
#
#                                         Drug Strength  \
# 0   [Not mentioned, Not mentioned, Not mentioned, ...
# 1   [Not mentioned, Not mentioned, Not mentioned, ...
# 2   [Not mentioned, Not mentioned, Not mentioned, ...
# 3   [Not mentioned, Not mentioned, Not mentioned, ...
# 4   [Not mentioned, Not mentioned, Not mentioned, ...
# 5   [Not mentioned, Not mentioned, 350, Not mentio...
# 6   [Not mentioned, Not mentioned, Not mentioned, ...
# 7   [Not mentioned, Not mentioned, Not mentioned, ...
# 8   [Not mentioned, Not mentioned, Not mentioned, ...
# 9   [Not mentioned, Not mentioned, 2400mg/m2, 85 m...
# 10  [Not mentioned, Not mentioned, Not mentioned, ...
# 11  [Not mentioned, Not mentioned, Not mentioned, ...
# 12  [Not mentioned, Not mentioned, Not mentioned, ...
# 13  [Not mentioned, Not mentioned, Not mentioned, ...
# 14  [Not mentioned, Not mentioned, Not mentioned, ...
# 15  [Not mentioned, Not mentioned, Not mentioned, ...
# 16  [Not mentioned, Not mentioned, Not mentioned, ...
# 17  [Not mentioned, Not mentioned, Not mentioned, ...
# 18  [Not mentioned, Not mentioned, Not mentioned, ...
# 19  [Not mentioned, Not mentioned, Not mentioned, ...
# 20  [Not mentioned, Not mentioned, Not mentioned, ...
# 21  [Not mentioned, Not mentioned, Not mentioned, ...
# 22  [Not mentioned, Not mentioned, Not mentioned, ...
# 23  [325 mg, Not mentioned, 70 mg, Not mentioned, ...
# 24  [Not mentioned, Not mentioned, Not mentioned, ...
# 25  [Not mentioned, Not mentioned, 50,000 unit, No...
# 26  [Not mentioned, Not mentioned, Not mentioned, ...
# 27  [Not mentioned, Not mentioned, Not mentioned, ...
# 28  [Not mentioned, Not mentioned, Not mentioned, ...
# 29  [Not mentioned, Not mentioned, Not mentioned, ...
# 30  [Not mentioned, Not mentioned, 5 mg, 300 mg, 5...
# 31  [Not mentioned, Not mentioned, Not mentioned, ...
# 32  [Not mentioned, Not mentioned, Not mentioned, ...
# 33  [Not mentioned, Not mentioned, Not mentioned, ...
# 34  [Not mentioned, 150 mg, Not mentioned, 10 mg, ...
# 35  [Not mentioned, Not mentioned, Not mentioned, ...
# 36  [Not mentioned, Not mentioned, Not mentioned, ...
# 37  [Not mentioned, 0.25 mg, Not mentioned, 200 mg...
# 38  [Not mentioned, Not mentioned, Not mentioned, ...
# 39  [Not mentioned, Not mentioned, Not mentioned, ...
#
#                                             Drug Form  \
# 0   [Not mentioned, Not mentioned, Not mentioned, ...
# 1   [Not mentioned, Not mentioned, Not mentioned, ...
# 2   [Not mentioned, Not mentioned, Not mentioned, ...
# 3   [Not mentioned, Not mentioned, Not mentioned, ...
# 4   [Not mentioned, Not mentioned, Not mentioned, ...
# 5   [Not mentioned, Not mentioned, Not mentioned, ...
# 6   [Not mentioned, Not mentioned, Not mentioned, ...
# 7   [Not mentioned, Not mentioned, Not mentioned, ...
# 8   [Not mentioned, Not mentioned, Not mentioned, ...
# 9   [Not mentioned, Not mentioned, Not mentioned, ...
# 10  [Not mentioned, Not mentioned, Not mentioned, ...
# 11  [Not mentioned, Not mentioned, Not mentioned, ...
# 12  [Not mentioned, Not mentioned, Not mentioned, ...
# 13  [Not mentioned, Not mentioned, Not mentioned, ...
# 14  [Not mentioned, Not mentioned, Not mentioned, ...
# 15  [Not mentioned, Not mentioned, Not mentioned, ...
# 16  [Not mentioned, Not mentioned, Not mentioned, ...
# 17  [Not mentioned, Not mentioned, Not mentioned, ...
# 18  [Not mentioned, Not mentioned, Not mentioned, ...
# 19  [Not mentioned, Not mentioned, Not mentioned, ...
# 20  [Not mentioned, Not mentioned, Not mentioned, ...
# 21  [Not mentioned, Not mentioned, Not mentioned, ...
# 22  [Not mentioned, Not mentioned, Not mentioned, ...
# 23  [tablet, Not mentioned, tablet, Not mentioned,...
# 24  [Not mentioned, Not mentioned, Not mentioned, ...
# 25  [Not mentioned, Not mentioned, capsule, Not me...
# 26  [Not mentioned, Not mentioned, Not mentioned, ...
# 27  [Not mentioned, Not mentioned, Not mentioned, ...
# 28  [Not mentioned, Not mentioned, Not mentioned, ...
# 29  [Not mentioned, Not mentioned, Not mentioned, ...
# 30  [Not mentioned, Not mentioned, tablet, capsule...
# 31  [Not mentioned, Not mentioned, Not mentioned, ...
# 32  [Not mentioned, Not mentioned, Not mentioned, ...
# 33  [Not mentioned, Not mentioned, Not mentioned, ...
# 34  [Not mentioned, 12 hr, Not mentioned, tablet, ...
# 35  [Not mentioned, Not mentioned, Not mentioned, ...
# 36  [Not mentioned, Not mentioned, Not mentioned, ...
# 37  [Not mentioned, tablet, Not mentioned, tablet,...
# 38  [Not mentioned, Not mentioned, Not mentioned, ...
# 39  [Not mentioned, Not mentioned, Not mentioned, ...
#
#                              Frequency of Drug Intake  \
# 0   [Not mentioned, Not mentioned, Not mentioned, ...
# 1   [Not mentioned, Not mentioned, Not mentioned, ...
# 2   [Not mentioned, Not mentioned, Not mentioned, ...
# 3   [Not mentioned, Not mentioned, Not mentioned, ...
# 4   [Not mentioned, Not mentioned, Not mentioned, ...
# 5   [Not mentioned, Not mentioned, Not mentioned, ...
# 6   [Not mentioned, Not mentioned, alternate week,...
# 7   [Not mentioned, Not mentioned, Not mentioned, ...
# 8   [Not mentioned, Not mentioned, Not mentioned, ...
# 9   [Not mentioned, Not mentioned, Not mentioned, ...
# 10  [Not mentioned, Not mentioned, Not mentioned, ...
# 11  [Not mentioned, Not mentioned, Not mentioned, ...
# 12  [Not mentioned, Not mentioned, Not mentioned, ...
# 13  [Not mentioned, Not mentioned, Not mentioned, ...
# 14  [Not mentioned, Not mentioned, Not mentioned, ...
# 15  [Not mentioned, Not mentioned, Not mentioned, ...
# 16  [Not mentioned, Not mentioned, Not mentioned, ...
# 17  [Not mentioned, Not mentioned, Not mentioned, ...
# 18  [Not mentioned, Not mentioned, Not mentioned, ...
# 19  [Not mentioned, Not mentioned, Not mentioned, ...
# 20  [Not mentioned, Not mentioned, Not mentioned, ...
# 21  [Not mentioned, Not mentioned, Not mentioned, ...
# 22  [Not mentioned, Not mentioned, Not mentioned, ...
# 23  [every 6 (six) hours as needed, Not mentioned,...
# 24  [Not mentioned, Not mentioned, Not mentioned, ...
# 25  [Not mentioned, Not mentioned, Not mentioned, ...
# 26  [nab, Not mentioned, Not mentioned, Not mentio...
# 27  [Not mentioned, Not mentioned, Not mentioned, ...
# 28  [Not mentioned, Not mentioned, Not mentioned, ...
# 29  [Not mentioned, Not mentioned, Not mentioned, ...
# 30  [Not mentioned, Not mentioned, Daily, 3 (three...
# 31  [Not mentioned, Not mentioned, Not mentioned, ...
# 32  [Not mentioned, Not mentioned, Not mentioned, ...
# 33  [Not mentioned, Not mentioned, Not mentioned, ...
# 34  [Not mentioned, 2 (two) times daily, Not menti...
# 35  [Not mentioned, Not mentioned, Not mentioned, ...
# 36  [Not mentioned, Not mentioned, Not mentioned, ...
# 37  [Not mentioned, Not mentioned, Not mentioned, ...
# 38  [Not mentioned, Not mentioned, Not mentioned, ...
# 39  [Not mentioned, Not mentioned, Not mentioned, ...
#
#                               Duration of Drug Intake
# 0   [Not mentioned, Not mentioned, Not mentioned, ...
# 1   [Not mentioned, Not mentioned, Not mentioned, ...
# 2   [Not mentioned, Not mentioned, Not mentioned, ...
# 3   [Not mentioned, Not mentioned, 28 day cycles, ...
# 4   [Not mentioned, Not mentioned, Not mentioned, ...
# 5   [Not mentioned, Not mentioned, Not mentioned, ...
# 6   [Not mentioned, Not mentioned, Not mentioned, ...
# 7   [1 cycle, Not mentioned, Not mentioned, 11 cyc...
# 8   [12 cycles, Not mentioned, Not mentioned, 12 c...
# 9   [Not mentioned, Not mentioned, over 48 hours, ...
# 10  [Not mentioned, Not mentioned, Not mentioned, ...
# 11  [Not mentioned, Not mentioned, Not mentioned, ...
# 12  [Not mentioned, Not mentioned, Not mentioned, ...
# 13  [Not mentioned, Not mentioned, Not mentioned, ...
# 14  [Not mentioned, Not mentioned, Not mentioned, ...
# 15  [Not mentioned, Not mentioned, Not mentioned, ...
# 16  [Not mentioned, Not mentioned, Not mentioned, ...
# 17  [Not mentioned, Not mentioned, Not mentioned, ...
# 18  [Not mentioned, Not mentioned, Not mentioned, ...
# 19  [Not mentioned, Not mentioned, Not mentioned, ...
# 20  [Not mentioned, Not mentioned, Not mentioned, ...
# 21  [Not mentioned, Not mentioned, for six years, ...
# 22  [Not mentioned, Not mentioned, Not mentioned, ...
# 23  [Not mentioned, Not mentioned, Not mentioned, ...
# 24  [Not mentioned, Not mentioned, Not mentioned, ...
# 25  [Not mentioned, Not mentioned, Not mentioned, ...
# 26  [Not mentioned, Not mentioned, Not mentioned, ...
# 27  [Not mentioned, for 6 months, Not mentioned, N...
# 28  [Not mentioned, Not mentioned, Not mentioned, ...
# 29  [Not mentioned, Not mentioned, Not mentioned, ...
# 30  [Not mentioned, Not mentioned, Not mentioned, ...
# 31  [Not mentioned, Not mentioned, Not mentioned, ...
# 32  [Not mentioned, Not mentioned, Not mentioned, ...
# 33  [Not mentioned, Not mentioned, Not mentioned, ...
# 34  [for 4 years, Not mentioned, Not mentioned, No...
# 35  [Not mentioned, Not mentioned, Not mentioned, ...
# 36  [Not mentioned, Not mentioned, Not mentioned, ...
# 37  [Not mentioned, Not mentioned, Not mentioned, ...
# 38  [Not mentioned, Not mentioned, Not mentioned, ...
# 39  [Not mentioned, Not mentioned, for 4 cycles, N...

# %%
##Similarity metric that could be used to compare two lists:
from itertools import product
from scipy.optimize import linear_sum_assignment
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.spatial.distance import cosine

def list_similarity(list1, list2, similarity_func):
    """Computes similarity between two lists of different lengths, accounting for 'Not mentioned'."""
    
    # Count 'Not mentioned' occurrences
    not_mentioned_count_1 = list1.count("Not mentioned")
    not_mentioned_count_2 = list2.count("Not mentioned")
    
    # Consider proportion of 'Not mentioned' values as similarity factor
    not_mentioned_sim = 1 - abs(not_mentioned_count_1 / len(list1) - not_mentioned_count_2 / len(list2))
    
    # Compute pairwise similarity for all real (non-'Not mentioned') values
    valid_pairs = [(i, j) for i, val1 in enumerate(list1) for j, val2 in enumerate(list2)]
    similarity_matrix = np.zeros((len(list1), len(list2)))

    for i, j in valid_pairs:
        if list1[i] == "Not mentioned" or list2[j] == "Not mentioned":
            similarity_matrix[i, j] = 0  # Explicit penalty for mismatch
        else:
            similarity_matrix[i, j] = similarity_func(list1[i], list2[j])  # Use similarity metric
    
    # Use Hungarian algorithm to find best matches
    row_ind, col_ind = linear_sum_assignment(-similarity_matrix)  # Maximize similarity
    matched_sim = sum(similarity_matrix[row_ind, col_ind]) / max(len(list1), len(list2))
    
    # Final similarity score (combining content matching and 'Not mentioned' alignment)
    final_score = (matched_sim + not_mentioned_sim) / 2
    return final_score

jaccard_sim = lambda a, b: len(set(a.split()) & set(b.split())) / len(set(a.split()) | set(b.split()))

def cosine_similarity(str1, str2):
    """Computes cosine similarity between two text strings using TF-IDF."""
    vectorizer = TfidfVectorizer().fit([str1, str2])
    vecs = vectorizer.transform([str1, str2]).toarray()
    return 1 - cosine(vecs[0], vecs[1])  # Cosine similarity (1 - distance)

def ratio_similarity(num1, num2):
    """Computes ratio-based similarity for numerical values."""
    try:
        num1, num2 = float(num1), float(num2)
        return min(num1, num2) / max(num1, num2) if max(num1, num2) != 0 else 0
    except ValueError:
        return 0  # Handle cases where non-numeric values are passed
    
med7_df = med7_df.map(lambda x: x if isinstance(x, list) else [x]) #ensure all elements in df are type list
final_df = final_df.map(lambda x: x if isinstance(x, list) else [x])

    
similarity_means = []
for c in range(7):
    sim_metric = []
    if c == 1 or c == 3:
        sim_func = ratio_similarity
    else:
        sim_func = jaccard_sim
    for r in range(40):
        list1 = med7_df.iloc[r, c]
        list2 = final_df.iloc[r, c] #going down rows and storing metric at each one
        sim_metric.append(list_similarity(list1, list2, sim_func))
    similarity_means.append(sum(sim_metric)/len(sim_metric))

similarity_means = np.array(similarity_means)
print(similarity_means)
# Out:
# [0.61511927 0.22762223 0.27316892 0.26738388 0.31324186 0.33600427
#  0.32849362]

# %%
##Plot bar chart for similarities
# Create a color list where indices 1 and 3 have a different color
import matplotlib.pyplot as plt
import seaborn as sns
values = similarity_means
colors = ['tab:blue' if i not in [1, 3] else 'tab:orange' for i in range(len(values))]

# Create a corresponding labels list for the legend
labels = ['Jaccard similarity' if i not in [1, 3] else 'Ratio similarity' for i in range(len(values))]

columns = ['DRUG', 'DOSAGE', 'ROUTE', 'STRENGTH', 'FORM', 'FREQUENCY', 'DURATION']

# Create the bar plot
plt.figure(figsize=(8, 6))
bars = plt.bar(range(len(values)), values, color=colors)

# Add legend
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles=[bars[0], bars[1]], labels=['Jaccard similarity', 'Ratio similarity'], title="Similarity Metric")

# Customize the plot aesthetics
plt.title('Comparison Between Contextual Drug NER for Med7 and Gemini', fontsize=16)
plt.xlabel('Index', fontsize=12)
plt.ylabel('Similarity Value', fontsize=12)
plt.xticks(range(len(values)), labels=columns)
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import requests
import json

def test_gemini_api():
    api_key = ""  # Replace with your actual key
    api_url = f"https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent?key={api_key}"
    
    payload = {
        "contents": [{
            "parts": [{"text": "Explain how AI works"}]
        }]
    }
    
    headers = {
        "Content-Type": "application/json"
    }
    
    response = requests.post(api_url, json=payload, headers=headers)
    print(f"Status code: {response.status_code}")
    print(json.dumps(response.json(), indent=2))

    print(api_url)
    return response

# Run the test
test_gemini_api()
# Out:
# Status code: 403
# {
#   "error": {
#     "code": 403,
#     "message": "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.",
#     "status": "PERMISSION_DENIED"
#   }
# }
# https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent?key=
# <Response [403]>

# %%
import torch
from transformers import AutoTokenizer, AutoModelForMaskedLM
import pandas as pd

# Load ClinicalBERT
model_name = "emilyalsentzer/Bio_ClinicalBERT"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForMaskedLM.from_pretrained(model_name)
model.eval()

EXPECTED_FIELDS = [
    "Current Medications", "Past Medications", "Patient Current Age",
    "Current Symptoms", "Past Symptoms", "Chronic Conditions",
    "Family History", "Reason for Visit", "Primary Diagnosis",
    "Procedure Names", "Information Relevant to Primary Diagnosis",
    "Age", "Gender"
]

def chunk_text(text, max_tokens=512, stride=256):
    tokens = tokenizer.tokenize(text)
    chunks = []
    start = 0
    while start < len(tokens):
        chunk_tokens = tokens[start:start+max_tokens]
        chunk = tokenizer.convert_tokens_to_string(chunk_tokens)
        chunks.append(chunk)
        start += stride
    return chunks

def extract_field_from_chunk(chunk, field):
    prompt = f"{chunk}\n\nThe patient's {field.lower()} is [MASK]."
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=512)
    mask_idx = torch.where(inputs.input_ids == tokenizer.mask_token_id)[1]

    if mask_idx.numel() == 0:
        return None

    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        mask_logits = logits[0, mask_idx, :]
        predicted_token_id = torch.argmax(mask_logits, dim=-1)
        predicted_token = tokenizer.decode(predicted_token_id).strip()
        return predicted_token

def extract_fields_from_note_chunked(note):
    try:
        chunks = chunk_text(note)
        extracted = {}

        for field in EXPECTED_FIELDS:
            for chunk in chunks:
                result = extract_field_from_chunk(chunk, field)
                if result and result.lower() != '[mask]':
                    extracted[field] = result
                    break  # take first valid result
            if field not in extracted:
                extracted[field] = "Not mentioned"
                
        return extracted
    except Exception as e:
        print(f"Extraction error: {e}")
        return {field: False for field in EXPECTED_FIELDS}

def process_dataframe_clinicalbert_chunked(df, note_column="Entire Patient Note"):
    processed_data = []

    for idx in range(40):  # Ensure exactly 40 notes
        if idx >= len(df):
            processed_data.append({field: False for field in EXPECTED_FIELDS})
            continue

        note = df.iloc[idx].get(note_column, "")
        if pd.isna(note) or note.strip() == "":
            print(f"Skipping empty note at index {idx}")
            processed_data.append({field: False for field in EXPECTED_FIELDS})
            continue

        print(f"Processing note {idx+1}/40...")
        extracted = extract_fields_from_note_chunked(note)
        processed_data.append(extracted)

    final_df = pd.DataFrame(processed_data, columns=EXPECTED_FIELDS)
    final_df.index.name = "Patient Index"
    return final_df

final_df = process_dataframe_clinicalbert_chunked(combined_df)
final_df.to_csv("clinicalbert_chunked_output.csv", index=False)
# Out:
# Processing note 1/40...
# Processing note 2/40...
# Processing note 3/40...
# Processing note 4/40...
# Processing note 5/40...
# Processing note 6/40...
# Processing note 7/40...
# Processing note 8/40...
# Processing note 9/40...
# Processing note 10/40...
# Processing note 11/40...
# Processing note 12/40...
# Processing note 13/40...
# Processing note 14/40...
# Processing note 15/40...
# Processing note 16/40...
# Processing note 17/40...
# Processing note 18/40...
# Processing note 19/40...
# Processing note 20/40...
# Processing note 21/40...
# Processing note 22/40...
# Processing note 23/40...
# Processing note 24/40...
# Processing note 25/40...
# Processing note 26/40...
# Processing note 27/40...
# Processing note 28/40...
# Processing note 29/40...
# Processing note 30/40...
# Processing note 31/40...
# Processing note 32/40...
# Processing note 33/40...
# Processing note 34/40...
# Processing note 35/40...
# Processing note 36/40...
# Processing note 37/40...
# Processing note 38/40...
# Processing note 39/40...
# Processing note 40/40...

# %%
import requests
import json
import pandas as pd

HF_API_URL = "https://api-inference.huggingface.co/models/meta-llama/Meta-Llama-3-8B-Instruct"
HF_TOKEN = ""  # get it from https://huggingface.co/settings/tokens

EXPECTED_FIELDS = [
    "Current Medications", "Past Medications", "Patient Current Age",
    "Current Symptoms", "Past Symptoms", "Chronic Conditions",
    "Family History", "Reason for Visit", "Primary Diagnosis",
    "Procedure Names", "Information Relevant to Primary Diagnosis",
    "Age", "Gender"
]

headers = {
    "Authorization": f"Bearer {HF_TOKEN}",
    "Content-Type": "application/json"
}

def build_prompt(note):
    return (
        f"Patient Note:\n{note}\n\n"
        f"Extract the following fields as a JSON object: {', '.join(EXPECTED_FIELDS)}. "
        f"If a field is missing, return 'Not mentioned'. Return only a JSON object."
    )

def call_llama3(note):
    payload = {
        "inputs": build_prompt(note),
        "parameters": {
            "temperature": 0.2,
            "max_new_tokens": 3000,
            "return_full_text": False
        }
    }
    try:
        response = requests.post(HF_API_URL, headers=headers, json=payload)
        result = response.json()
        if isinstance(result, list) and "generated_text" in result[0]:
            content = result[0]["generated_text"]
            json_start = content.find("{")
            json_end = content.rfind("}") + 1
            json_str = content[json_start:json_end]
            return json.loads(json_str)
        else:
            print(f"Error: Unexpected response format: {result}")
            return {field: False for field in EXPECTED_FIELDS}
    except Exception as e:
        print(f"LLaMA API error: {e}")
        return {field: False for field in EXPECTED_FIELDS}

def process_notes_llama(df, note_column="Entire Patient Note"):
    results = []
    for idx in range(40):
        if idx >= len(df):
            results.append({field: False for field in EXPECTED_FIELDS})
            continue
        note = df.iloc[idx].get(note_column, "")
        if pd.isna(note) or note.strip() == "":
            results.append({field: False for field in EXPECTED_FIELDS})
            continue
        print(f"Processing note {idx+1}/40...")
        result = call_llama3(note)
        results.append(result)
    return pd.DataFrame(results)

result_df = process_notes_llama(combined_df, note_column="Entire Patient Note")
result_df.to_csv("llama3_extracted_info.csv", index=False)
# Out:
# Processing note 1/40...
# Processing note 2/40...
# Processing note 3/40...
# Processing note 4/40...
# Processing note 5/40...
# Processing note 6/40...
# Processing note 7/40...
# Processing note 8/40...
# Processing note 9/40...
# Processing note 10/40...
# Processing note 11/40...
# Processing note 12/40...
# Error: Unexpected response format: {'error': 'Input validation error: `inputs` tokens + `max_new_tokens` must be <= 8192. Given: 7336 `inputs` tokens and 1024 `max_new_tokens`', 'error_type': 'validation'}
# Processing note 13/40...
# LLaMA API error: Expecting value: line 1 column 1 (char 0)
# Processing note 14/40...
# Processing note 15/40...
# Processing note 16/40...
# Processing note 17/40...
# Processing note 18/40...
# LLaMA API error: Expecting ',' delimiter: line 116 column 6 (char 3131)
# Processing note 19/40...
# Processing note 20/40...
# Processing note 21/40...
# Processing note 22/40...
# Processing note 23/40...
# Processing note 24/40...
# Processing note 25/40...
# Processing note 26/40...
# Processing note 27/40...
# Processing note 28/40...
# Processing note 29/40...
# Processing note 30/40...
# Processing note 31/40...
# Processing note 32/40...
# Processing note 33/40...
# Processing note 34/40...
# Processing note 35/40...
# Processing note 36/40...
# Processing note 37/40...
# Processing note 38/40...
# Processing note 39/40...
# Processing note 40/40...

# %%
##Clean up Llama3 data frame
unclean_df = pd.read_csv("llama3_extracted_info.csv")
unclean_df
# Out:
#                                   Current Medications  \
# 0                                      ['See intake']
# 1   ['ALPRAZolam (XANAX) 0.25 mg tablet', 'atorvas...
# 2   ['acetaminophen (TYLENOL ORAL) Take 200 mg by ...
# 3   ['buPROPion (WELLBUTRIN SR) 100 mg 12 hr table...
# 4   ['butenafine (LOTRIMIN ULTRA) 1 % cream', 'cho...
# 5                                 modified FOLFIRINOX
# 6   ['bisacodyL (DULCOLAX) 5 mg EC tablet', 'chole...
# 7   ['acetaminophen (TYLENOL PO) take by mouth eve...
# 8   ['albuterol 90 mcg/actuation metered dose inha...
# 9   [{'Medication': 'diphenoxylate-atropine (LOMOT...
# 10  ['acetaminophen (TYLENOL) 500 mg tablet', 'ibu...
# 11                                              False
# 12                                              False
# 13  ['amLODIPine (NORVASC) 5 mg, Oral, Daily Sched...
# 14  ['acetaminophen (TYLENOL) 500 mg tablet', 'alp...
# 15  [{'Medication': 'acetaminophen (TYLENOL EXTRA ...
# 16                                         FOLFIRINOX
# 17                                              False
# 18  ['aspirin 81 mg EC tablet', 'atorvastatin (LIP...
# 19  ['oxyCODONE-acetaminophen (Percocet) 5-325 mg ...
# 20  ['acetaminophen (TYLENOL) 500 mg tablet', 'amL...
# 21                                      Not mentioned
# 22  [{'Medication': 'clotrimazole-betamethasone (L...
# 23  ['acetaminophen (TYLENOL) 325 mg tablet', 'ale...
# 24                                      Not mentioned
# 25  ['ergocalciferol, vitamin D2, (ERGOCALCIFEROL)...
# 26  ['albuterol 90 mcg/actuation metered dose inha...
# 27  ['acetaminophen (TYLENOL) 325 mg tablet', 'ace...
# 28  ['gabapentin (NEURONTIN) 300 mg capsule', 'hyd...
# 29  ['CETRORELIX ACETATE (CETROTIDE SUBCUT)', 'MEN...
# 30  [{'Medication': 'amLODIPine (NORVASC)', 'Sig':...
# 31  ['simvastatin (ZOCOR) 20 mg tablet', 'LORazepa...
# 32  ['cholecalciferol, vitamin D3, (VITAMIN D3 ORA...
# 33  ['ascorbic acid, vitamin C, 500 mg TABSR', 'B-...
# 34  ['buPROPion (WELLBUTRIN SR) 150 mg 12 hr table...
# 35     ['Hydrochlorothiazide, potassium and Exforge']
# 36                    ['cholecalciferol, vitamin D3']
# 37  ['ALPRAZolam (XANAX) 0.25 mg tablet', 'ibuprof...
# 38  ['exemestane (AROMASIN) 25 mg tablet', 'HYDROc...
# 39                                      Not mentioned
#
#                                      Past Medications Patient Current Age  \
# 0                                       Not mentioned                  47
# 1                                       Not mentioned                  71
# 2                                       Not mentioned                  74
# 3                                       Not mentioned                  64
# 4                            ['palonosetron (Aloxi)']                  53
# 5                                       Not mentioned                  63
# 6                                       Not mentioned                  68
# 7                       ['erythromycin causing rash']                  69
# 8                                       Not mentioned                  71
# 9                                       Not mentioned                  73
# 10                                     ['omeprazole']                  52
# 11                                              False               False
# 12                                              False               False
# 13                                  ['Not mentioned']                  69
# 14  ['APPENDECTOMY', 'ERCP', 'IR PORT PLACEMENT', ...                  64
# 15                                      Not mentioned                  86
# 16                                      Not mentioned                  58
# 17                                              False               False
# 18                                      Not mentioned                  69
# 19                                      Not mentioned                  51
# 20  ['doxycycline (MONODOX) 100 mg capsule', 'furo...                  81
# 21                                          tamoxifen                  73
# 22                                      Not mentioned                  60
# 23                                      Not mentioned                  71
# 24                                      Not mentioned                  55
# 25                                      Not mentioned                  53
# 26                                      Not mentioned                  44
# 27  ['APPENDECTOMY', 'BREAST LUMPECTOMY', 'HAMMER ...                  70
# 28  ['polymyxin b-trimethoprim (POLYTRIM) ophthalm...                  31
# 29                ['Sulfa (Sulfonamide Antibiotics)']                  32
# 30                                      Not mentioned                  51
# 31                                  ['OCP', 'Clomid']                  67
# 32                                      Not mentioned                  36
# 33                                     ['Lurasidone']                  34
# 34                                      Not mentioned                  33
# 35                                  ['Not mentioned']                  59
# 36                                      Not mentioned                  58
# 37            ['Depo-Provera', 'oral contraceptives']                  32
# 38  ['amoxicillin (AMOXIL) 875 mg tablet', 'amoxic...                  49
# 39                                      Not mentioned                  44
#
#                                      Current Symptoms  \
# 0   ['abdominal discomfort', 'pain', 'numbness and...
# 1   ['fevers for 4-5 days following treatment', 'n...
# 2   ['Occasional bilateral abdominal pain', 'Gener...
# 3   ['brain fog', 'numbness and tingling in her fi...
# 4   ['oral thrush', 'abdominal pain/cramping', 'we...
# 5   abdominal discomfort, bloating, jaundice, pleu...
# 6   no cancer pain but take oxycodone for chronic ...
# 7                   mild fatigue and transient nausea
# 8   ['Worsening neuropathy', 'Improved abdominal p...
# 9   ['Constant saltiness in mouth which limits her...
# 10  ['early satiety', 'nausea post prandial', 'los...
# 11                                              False
# 12                                              False
# 13  ['epigastric and left sided abdominal pain', '...
# 14  ascites, numbness on the tip of his tongue, he...
# 15  ['Low energy level', 'Low appetite', 'Weight l...
# 16  Abdominal pain, intermittent upper abdominal pain
# 17                                              False
# 18  ['increase fatigue', 'increase emesis, nausea,...
# 19  ['abdominal discomfort', 'bloating', 'gassines...
# 20             ['dyspnea', 'fatigue', 'constipation']
# 21  lack of energy, pain in right hand, discomfort...
# 22                                      Not mentioned
# 23  ['tenderness at biopsy site and around axilla'...
# 24     mld joint stiffness, particularly in her knees
# 25        No bone pain or any other systemic concerns
# 26  ['Worsening GERD', 'Nausea', 'Fatigue', 'Right...
# 27  ['Slight more arm stiffness on her left arm bu...
# 28  ['irregular menstrual periods', 'joint pain', ...
# 29                                  ['mild bloating']
# 30  ['Hot flashes', 'Night sweats', 'Chronic low b...
# 31                                      Not mentioned
# 32                                      Not mentioned
# 33                            ['Insomnia', 'Anxiety']
# 34  ['swollen lymph nodes', 'pain', 'difficulty sw...
# 35  ['Right breast aching that is gradually increa...
# 36                          ['mild left breast pain']
# 37    ['Nervousness or Anxiety', 'Sleep disturbance']
# 38  ['minimal joint aches', 'mild hot flashes and ...
# 39  Bilateral breast cancer, nipple discharge, no ...
#
#                                         Past Symptoms  \
# 0                                 ['gross hematuria']
# 1                                       Not mentioned
# 2                                       Not mentioned
# 3                                       Not mentioned
# 4                              ['hyperbilirubinemia']
# 5            abdominal discomfort, bloating, jaundice
# 6                                       Not mentioned
# 7                                   painless jaundice
# 8    ['Nausea 11/14/2016', 'Obstructive sleep apnea']
# 9                                       Not mentioned
# 10                             ['constipated before']
# 11                                              False
# 12                                              False
# 13                                  ['Not mentioned']
# 14  painless jaundice, acholic stools, transaminit...
# 15                                      Not mentioned
# 16  Abd pain, no abnormalities in the stomach or d...
# 17                                              False
# 18                                      Not mentioned
# 19  ['intermittent mid/LUQ abdominal discomfort, b...
# 20  ['stroke', 'uterine cancer', 'blindness', 'amb...
# 21  neuropathy of the right hand associated with a...
# 22                                      Not mentioned
# 23                                      Not mentioned
# 24                                      Not mentioned
# 25                                      Not mentioned
# 26                                      Not mentioned
# 27  ['PONV (postoperative nausea and vomiting) wit...
# 28                           ['nausea and body pain']
# 29  ['Viral meningitis', 'Closed left ankle fractu...
# 30                                      Not mentioned
# 31                                      Not mentioned
# 32                                      Not mentioned
# 33                             ['Bipolar 2 disorder']
# 34                                      Not mentioned
# 35                                  ['Not mentioned']
# 36                                      Not mentioned
# 37                                      Not mentioned
# 38  ['neck pain', 'numbness and tingling in left a...
# 39                                      Not mentioned
#
#                                    Chronic Conditions  \
# 0                                    ['hypertension']
# 1   ['COPD (chronic obstructive pulmonary disease)...
# 2                                       Not mentioned
# 3                  ['adenocarcinoma of the pancreas']
# 4                                ['Gilbert syndrome']
# 5                                       Not mentioned
# 6   Chronic opioid use, arthritis, chronic back pa...
# 7                  ['hypertension', 'hyperlipidemia']
# 8   ['Lupus', 'Asthma', 'Breast cancer (HCC)', 'Ob...
# 9                                       Not mentioned
# 10            ['borderline hypertension', 'diabetes']
# 11                                              False
# 12                                              False
# 13  ['HTN', 'Dyslipidemia', 'Pre-diabetes', 'Lumba...
# 14  Type II diabetes mellitus, hyperlipidemia, art...
# 15                      ['Pancreatic adenocarcinoma']
# 16         Locally advanced pancreatic adenocarcinoma
# 17                                              False
# 18                                       ['diabetes']
# 19                                      Not mentioned
# 20  ['CHF (congestive heart failure)', 'CKD (chron...
# 21  osteoporosis, osteopenia, benign thyroid nodul...
# 22               ['HTN', 'GERD', 'Plantar fasciitis']
# 23  ['GERD (gastroesophageal reflux disease)', 'Ki...
# 24                                  Diabetes, Obesity
# 25                                  Diabetes mellitus
# 26  ['Lynch syndrome', 'Colon cancer', 'Endometria...
# 27  ['Arthritis', 'Breast cancer', 'Cataract', 'GE...
# 28   ['HTN (hypertension)', 'Hyperemesis gravidarum']
# 29                                  ['Breast cancer']
# 30   ['High blood pressure', 'Chronic low back pain']
# 31  ['Fibrocystic breast disease', 'Lipoma', 'Mela...
# 32                                     Hypothyroidism
# 33                             ['Bipolar 2 disorder']
# 34          ['Hypertension', 'Obesity', 'Depression']
# 35                                   ['Hypertension']
# 36                                      Not mentioned
# 37                                      Not mentioned
# 38                 ['Breast cancer', 'Endometriosis']
# 39                                        Hepatitis B
#
#                                        Family History  \
# 0   ['maternal grandmother had colorectal cancer',...
# 1   ['Father: Pancreatic cancer', 'Maternal Uncle:...
# 2                                       Not mentioned
# 3                                       Not mentioned
# 4                                       Not mentioned
# 5                                       Not mentioned
# 6   The only cancer in her family is in maternal a...
# 7   ['Paternal grandmother with esophageal cancer'...
# 8   ['Stomach cancer Mother', 'Colon cancer Sister...
# 9                                       Not mentioned
# 10  ['breast cancer', 'prostate cancer', 'stomach ...
# 11                                              False
# 12                                              False
# 13                                  ['Not mentioned']
# 14                                      Not mentioned
# 15                                      Not mentioned
# 16                                      Not mentioned
# 17                                              False
# 18  ['sister diagnosed with pancreatic cancer at a...
# 19  ['Ovarian cancer (mother)', 'Lung cancer (mate...
# 20  ['stroke (mother)', 'uterine cancer (mother)',...
# 21  maternal aunt with breast cancer at age 70, tw...
# 22  ['Breast cancer in her sister', 'Cancer (age o...
# 23  {'Cancer': ['Mother: breast cancer', 'Sister: ...
# 24           Breast cancer (maternal grandmother, 58)
# 25                                  No h/o malignancy
# 26  ['Leukemia (mother)', 'Colon cancer (maternal ...
# 27  ['Paternal grandmother passed away from breast...
# 28    ['Lymphoma (father)', 'Breast cancer (neg Hx)']
# 29  ['Lung cancer (father)', 'Melanoma (maternal g...
# 30  {'Hypertension': 'Father', 'Arthritis': 'Mothe...
# 31  {'Breast cancer': ['Mother', 'Paternal Great A...
# 32                             Breast cancer (cousin)
# 33  ["Alzheimer's disease", 'Breast cancer', 'Hype...
# 34  ['Cerebral aneurysm (father)', 'Melanoma (neg ...
# 35                 ["Mother had Parkinson's disease"]
# 36  ['Breast cancer (Paternal Grandmother, 35; Pat...
# 37  ['Breast cancer Mother', 'Breast cancer Other'...
# 38                                      Not mentioned
# 39  Father with colon cancer, liver diagnosed age ...
#
#                                      Reason for Visit  \
# 0                                     Follow-up visit
# 1   Follow-up of his diagnosis of Adenocarcinoma o...
# 2           Follow-up of metastatic pancreatic cancer
# 3                                     Follow-up visit
# 4   follow-up of his diagnosis of adenocarcinoma o...
# 5                                           follow-up
# 6                                      restaging scan
# 7   consultation for recurrent metastatic pancreat...
# 8                                           Follow-up
# 9                                     Follow-up visit
# 10  second opinion and consideration of clinical t...
# 11                                              False
# 12                                              False
# 13  new patient at the UCSF Comprehensive Cancer C...
# 14           evaluation of resected pancreatic cancer
# 15             Follow-up of pancreatic adenocarcinoma
# 16                                    Follow-up visit
# 17                                              False
# 18                                    Follow-up visit
# 19         Consultation for pancreatic adenocarcinoma
# 20  Establish care and discuss treatment options f...
# 21  discussion of potential treatment options for ...
# 22  Patient with early stage breast cancer here to...
# 23                New patient visit for breast cancer
# 24    To discuss treatment options and establish care
# 25         To discuss systemic therapy and management
# 26             Follow-up for metastatic breast cancer
# 27                         To establish Oncology care
# 28  to discuss treatment options and to establish ...
# 29                      Newly diagnosed breast cancer
# 30  Discussion of potential adjuvant anti-hormonal...
# 31       Establish care and discuss treatment options
# 32  Planning of subsequent steps of treatment and ...
# 33                      Newly diagnosed breast cancer
# 34       Recent diagnosis of metastatic breast cancer
# 35                      Newly diagnosed breast cancer
# 36  To discuss treatment options for newly diagnos...
# 37  Discussion of treatment options for recently d...
# 38                                    Follow-up visit
# 39  Return visit to the breast cancer center for h...
#
#                                     Primary Diagnosis  \
# 0     Locally advanced adenocarcinoma of the pancreas
# 1                      Adenocarcinoma of the pancreas
# 2   Metastatic Pancreatic Ductal Adenocarcinoma (P...
# 3           Metastatic adenocarcinoma of the pancreas
# 4                      adenocarcinoma of the pancreas
# 5                      adenocarcinoma of the pancreas
# 6             Adenocarcinoma the tail of the pancreas
# 7                metastatic pancreatic adenocarcinoma
# 8                        Metastatic pancreatic cancer
# 9                  Locally advanced pancreatic cancer
# 10                                  pancreatic cancer
# 11                                              False
# 12                                              False
# 13               metastatic pancreatic adenocarcinoma
# 14            Pancreatic ductal adenocarcinoma (PDAC)
# 15                          Pancreatic adenocarcinoma
# 16         Locally advanced pancreatic adenocarcinoma
# 17                                              False
# 18           Localized adenocarcinoma of the pancreas
# 19                          Pancreatic adenocarcinoma
# 20             Invasive ductal carcinoma, SBR grade 3
# 21  locally recurrent, unresectable, hormone-recep...
# 22  Invasive spindle cell metaplastic carcinoma br...
# 23   HR low, HER2 negative cancer of the right breast
# 24                          Early stage breast cancer
# 25                    HR-negative HER2+ breast cancer
# 26                           Metastatic breast cancer
# 27                   Stage IIA pT2(m)N1a L breast IDC
# 28                   HR+/HER2- IDC of the left breast
# 29                        Breast cancer, right breast
# 30                    Ductal carcinoma in situ (DCIS)
# 31                          Early stage breast cancer
# 32            Invasive ductal carcinoma (ER+ / HER2-)
# 33  Invasive Ductal Carcinoma (IDC) of the right b...
# 34                           Metastatic breast cancer
# 35                         Invasive lobular carcinoma
# 36                         Breast cancer, left breast
# 37               Left IDC (Invasive Ductal Carcinoma)
# 38  ER+/PR-/HER2- left breast cancer, mammaprint l...
# 39                            Bilateral breast cancer
#
#                                       Procedure Names  \
# 0   ['ERCP with an EUS', 'placement of plastic ste...
# 1           ['IR PORT PLACEMENT', 'PANCREAS SURGERY']
# 2   ['CT ABDOMEN/PELVIS WITH CONTRAST', 'CT CHEST ...
# 3   ['ERCP', 'CT Abdomen/Pelvis with Contrast', 'C...
# 4   ['EUS directed FNA', 'biopsy of abdominal wall...
# 5   laparoscopy, pylorus-preserving pancreatectomy...
# 6   ['CT Abdomen/Pelvis with and without contrast'...
# 7   ['Whipple resection', 'ERCP', 'EUS-guided FNA'...
# 8   ['ENDO ADULT EGD WITH PEG/TUBE PLACEMENT', 'IR...
# 9   ['EUS', 'CT AP Pancreatic Protocol', 'CT chest...
# 10        ['CT AP', 'EGD/EUS', 'FNA/FNB', 'CT Chest']
# 11                                              False
# 12                                              False
# 13                                    ['ERCP', 'EUS']
# 14  ['Pancreaticoduodenectomy', 'Distal pancreatec...
# 15  ['ERCP', 'PET/CT', 'CT abdomen/pelvis', 'CT ch...
# 16  Endoscopic ultrasound guided biopsy, CT scan, ...
# 17                                              False
# 18                  ['CT scan', 'EUS', 'FNA', 'ERCP']
# 19  ['EGD', 'Colonoscopy', 'Abdominal U/S', 'Abdom...
# 20  ['right breast simple mastectomy', 'sentinel l...
# 21  fine-needle aspiration, core biopsy, PET/CT sc...
# 22  ['CHOLECYSTECTOMY, LAPAROSCOPIC', 'Common bile...
# 23  ['PET CT Limited Whole Body', 'Right Breast Di...
# 24  AXILLARY LYMPH NODE DISSECTION, MASTECTOMY, PA...
# 25  MRI Pelvis, MRI neck, PET CT, Breast MRI, Core...
# 26                                      Not mentioned
# 27  ['Bilateral mastectomies', 'Left axillary lymp...
# 28  ['Bilateral breast skin-sparing mastectomy + l...
# 29  ['Ultrasound guided core biopsy', 'Fine needle...
# 30  ['Lumpectomy', 'Stereotactic core needle biopsy']
# 31  ['Excisional Biopsy of Breast', 'KNEE ARTHROSC...
# 32  ['Ultrasound guided fine needle aspiration bio...
# 33  ['Blepharoplasty', 'Breast biopsy', 'Fat trans...
# 34  ['US-guided fine needle aspiration', 'Diagnost...
# 35  ['Core biopsy', 'MRI', 'PET/CT scan', 'Ultraso...
# 36  ['MRI-guided core biopsy', 'Left breast ultras...
# 37  ['US-guided core biopsy', 'FNA of a left axill...
# 38    ['NAHT', 'Bilateral mastectomies', 'DEXA scan']
# 39            Ultrasound, CT, bilateral breast cancer
#
#             Information Relevant to Primary Diagnosis            Age  \
# 0   ['biliary obstruction', 'pancreatic mass', 'po...             47
# 1   SPINK1 carrier, variant of unknown significanc...             71
# 2   ['Multicystic, ill-defined mass measures 4.7 x...             74
# 3   ['extent of disease uncertain', 'new liver les...             64
# 4   ['oligo metastatic disease in the abdominal wa...             53
# 5   CT scan, PET/CT, EUS, FNA, laparoscopy, surgic...             63
# 6   The mass in the tail of the pancreas was PET a...             68
# 7   Patient has a known germline ATM mutation and ...             69
# 8   BRCA variant of unknown significance in the se...             71
# 9   ['Stable pancreatic mass with vessel encasemen...             73
# 10  ['pancreatic cystic lesion', 'lymphadenopathy'...  Not mentioned
# 11                                              False          False
# 12                                              False          False
# 13  ['malignant biliary obstruction', 'pancreatic ...             69
# 14  Positive margins, high risk for recurrence, ri...             64
# 15  Ill-defined pancreatic mass is no longer seen,...             86
# 16  Patient had an endoscopic ultrasound guided bi...             58
# 17                                              False          False
# 18  ['mass in the uncinate process and involvement...             69
# 19  Multiple hypodense lesions throughout the live...             51
# 20  ['ER negative', 'PR negative', 'HER2 positive'...             81
# 21  initially treated with surgery and interstitia...             73
# 22  Multifocal, locally advanced, ER Negative, PR ...             60
# 23  Hypermetabolic (FDG avid) right lateral breast...             71
# 24  Bilateral breast cancer, clinically and genomi...             55
# 25  Multiple right breast masses, enlarged level 1...             53
# 26        Metastatic breast cancer to liver and nodes             44
# 27  ['ER+/PR+/HER- with FISH ratio 1.1, high-risk ...             70
# 28  ['locally advanced, unresectable recurrence (p...             31
# 29  ['Grade 2 IDC, ER >95%, PR 25%, HER2 neg by IH...             32
# 30                     Biopsy proven left breast DCIS             51
# 31  Patient has a clinical stage II HR+/HER2- IDC ...             67
# 32  Patient has axillary lymph node involvement, a...             36
# 33  ['ER+/PR+ and HER2 equivocal IDC of the right ...             34
# 34  Metastatic adenocarcinoma, consistent with bre...             33
# 35  ['ER positive with 96% of the cells staining, ...             59
# 36  ['Pathology report shows infiltrating ductal c...             58
# 37  ['ER positive (>95%)', 'PR positive (<5%)', 'H...             32
# 38  s/p bilateral mastectomies, s/p adjuvant tamox...             49
# 39  Bilateral breast cancer, ER+ HER2 positive, Ki...             44
#
#            Gender
# 0            Male
# 1            Male
# 2            Male
# 3          Female
# 4            Male
# 5          Female
# 6   Not mentioned
# 7          Female
# 8          Female
# 9          Female
# 10  Not mentioned
# 11          False
# 12          False
# 13  Not mentioned
# 14           Male
# 15         Female
# 16           Male
# 17          False
# 18         Female
# 19           Male
# 20         Female
# 21         Female
# 22         Female
# 23         Female
# 24         Female
# 25         Female
# 26         Female
# 27         Female
# 28         Female
# 29         Female
# 30         Female
# 31         Female
# 32         Female
# 33         Female
# 34         Female
# 35         Female
# 36         Female
# 37         Female
# 38         Female
# 39         Female

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud
import lda  # The LDA library

# If you haven't downloaded NLTK stopwords/punkt yet, do so:
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/smallina/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /Users/smallina/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
pdac_df = combined_df.iloc[0:20].copy()
bc_df   = combined_df.iloc[20:40].copy()

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [t for t in tokens if t not in stop_words and len(t) > 1]
    return " ".join(tokens)

pdac_df["clean_note"] = pdac_df["Entire Patient Note"].astype(str).apply(clean_text)
bc_df["clean_note"]   = bc_df["Entire Patient Note"].astype(str).apply(clean_text)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/smallina/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/smallina/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def build_cooccurrence_matrix(texts, terms):
    # Map each term to an index
    term_index = {t: i for i, t in enumerate(terms)}
    size = len(terms)
    matrix = np.zeros((size, size), dtype=int)

    for doc in texts:
        doc_tokens = set(doc.split())  # unique tokens in doc
        doc_terms = [t for t in doc_tokens if t in term_index]
        # For each pair of terms, increment co-occurrence
        for i in range(len(doc_terms)):
            for j in range(i+1, len(doc_terms)):
                idx1 = term_index[doc_terms[i]]
                idx2 = term_index[doc_terms[j]]
                matrix[idx1, idx2] += 1
                matrix[idx2, idx1] += 1
    return matrix

target_terms = ["chemotherapy","radiation","pain","metastasis",
                "nausea","immunotherapy","diabetes","hypertension"]

# PDAC co-occurrence
pdac_co_mat = build_cooccurrence_matrix(pdac_df["clean_note"], target_terms)

plt.figure(figsize=(6,5))
plt.imshow(pdac_co_mat, cmap="Blues", interpolation="nearest")
plt.xticks(range(len(target_terms)), target_terms, rotation=45)
plt.yticks(range(len(target_terms)), target_terms)
plt.colorbar()
plt.title("PDAC Co-occurrence Heatmap")
plt.tight_layout()
plt.show()

# BC co-occurrence
bc_co_mat = build_cooccurrence_matrix(bc_df["clean_note"], target_terms)

plt.figure(figsize=(6,5))
plt.imshow(bc_co_mat, cmap="Reds", interpolation="nearest")
plt.xticks(range(len(target_terms)), target_terms, rotation=45)
plt.yticks(range(len(target_terms)), target_terms)
plt.colorbar()
plt.title("BC Co-occurrence Heatmap")
plt.tight_layout()
plt.show()

# %%
from collections import Counter
import math

def compute_tfidf(docs, top_n=10):
    """
    Return top_n terms by TF-IDF across the corpus.
    """
    # 1) Count term frequencies (TF)
    doc_counts = []
    for doc in docs:
        c = Counter(doc.split())
        doc_counts.append(c)

    # 2) Compute document frequency (DF)
    df_counts = Counter()
    total_docs = len(docs)
    for c in doc_counts:
        for term in c.keys():
            df_counts[term] += 1

    # 3) Compute TF-IDF for each term
    tfidf_scores = {}
    for doc_idx, c in enumerate(doc_counts):
        for term, freq in c.items():
            tf = freq  # raw count
            df = df_counts[term]
            idf = math.log((total_docs + 1) / (df + 1)) + 1
            score = tf * idf
            tfidf_scores[term] = tfidf_scores.get(term, 0) + score

    # Sort by overall TF-IDF
    sorted_terms = sorted(tfidf_scores.items(), key=lambda x: x[1], reverse=True)
    return sorted_terms[:top_n]

print("Top TF-IDF PDAC:")
print(compute_tfidf(pdac_df["clean_note"], top_n=10))
print("---")
print("Top TF-IDF BC:")
print(compute_tfidf(bc_df["clean_note"], top_n=10))
# Out:
# Top TF-IDF PDAC:
# [('mg', 316.23728627266877), ('tablet', 215.8261771276973), ('take', 210.767782298094), ('pancreatic', 209.0), ('ct', 203.0), ('patient', 180.0), ('cancer', 172.0), ('mouth', 163.52672764507292), ('history', 156.0), ('mass', 143.68425249121225)]
# ---
# Top TF-IDF BC:
# [('breast', 607.0), ('right', 353.0), ('cm', 322.0), ('left', 294.0), ('mg', 248.0270745193101), ('tablet', 232.76386993350644), ('mass', 210.8068229980559), ('history', 204.0), ('cancer', 197.0), ('patient', 193.0)]

# %%
from collections import defaultdict

def make_term_matrix(docs, vocab=None):
    """
    Build a doc-term matrix (list of lists) + vocabulary list from cleaned docs.
    This is a minimal approach, no SciPy or scikit-learn.
    """
    if vocab is None:
        vocab_set = set()
        for doc in docs:
            vocab_set.update(doc.split())
        vocab = sorted(list(vocab_set))

    vocab_index = {word: i for i, word in enumerate(vocab)}
    dt_matrix = np.zeros((len(docs), len(vocab)), dtype=int)

    for doc_i, doc in enumerate(docs):
        for token in doc.split():
            if token in vocab_index:
                dt_matrix[doc_i, vocab_index[token]] += 1
    return dt_matrix, vocab

# Build doc-term matrix for PDAC
pdac_docs = pdac_df["clean_note"].tolist()
pdac_dtm, pdac_vocab = make_term_matrix(pdac_docs)

# Train LDA model
model = lda.LDA(n_topics=3, n_iter=500, random_state=42)
model.fit(pdac_dtm)

# Print top words per topic
topic_word = model.topic_word_  # shape: [n_topics, n_vocab]
n_top_words = 8
for i, topic_dist in enumerate(topic_word):
    top_word_ids = np.argsort(topic_dist)[::-1][:n_top_words]
    topic_words = [pdac_vocab[w_id] for w_id in top_word_ids]
    print(f"Topic {i}: {' '.join(topic_words)}")

# If you also want doc-topic distribution
doc_topic = model.doc_topic_
for i in range(len(pdac_docs)):
    print(f"Doc {i} (PDAC) -> Topic: {doc_topic[i].argmax()}")
# Out:
# INFO:lda:n_documents: 20
# INFO:lda:vocab_size: 4029
# INFO:lda:n_words: 25072
# INFO:lda:n_topics: 3
# INFO:lda:n_iter: 500
# INFO:lda:<0> log likelihood: -239104
# INFO:lda:<10> log likelihood: -209103
# INFO:lda:<20> log likelihood: -205042
# INFO:lda:<30> log likelihood: -203330
# INFO:lda:<40> log likelihood: -202390
# INFO:lda:<50> log likelihood: -202132
# INFO:lda:<60> log likelihood: -202132
# INFO:lda:<70> log likelihood: -201843
# INFO:lda:<80> log likelihood: -201493
# INFO:lda:<90> log likelihood: -201474
# INFO:lda:<100> log likelihood: -201240
# INFO:lda:<110> log likelihood: -201259
# INFO:lda:<120> log likelihood: -201139
# INFO:lda:<130> log likelihood: -201185
# INFO:lda:<140> log likelihood: -200825
# INFO:lda:<150> log likelihood: -200757
# INFO:lda:<160> log likelihood: -200731
# INFO:lda:<170> log likelihood: -200690
# INFO:lda:<180> log likelihood: -200462
# INFO:lda:<190> log likelihood: -200527
# INFO:lda:<200> log likelihood: -200458
# INFO:lda:<210> log likelihood: -200329
# INFO:lda:<220> log likelihood: -200365
# INFO:lda:<230> log likelihood: -200349
# INFO:lda:<240> log likelihood: -200302
# INFO:lda:<250> log likelihood: -200572
# INFO:lda:<260> log likelihood: -200475
# INFO:lda:<270> log likelihood: -200365
# INFO:lda:<280> log likelihood: -200466
# INFO:lda:<290> log likelihood: -200372
# INFO:lda:<300> log likelihood: -200281
# INFO:lda:<310> log likelihood: -200310
# INFO:lda:<320> log likelihood: -200456
# INFO:lda:<330> log likelihood: -199950
# INFO:lda:<340> log likelihood: -200152
# INFO:lda:<350> log likelihood: -200596
# INFO:lda:<360> log likelihood: -200374
# INFO:lda:<370> log likelihood: -200312
# INFO:lda:<380> log likelihood: -200473
# INFO:lda:<390> log likelihood: -200288
# INFO:lda:<400> log likelihood: -200334
# INFO:lda:<410> log likelihood: -200452
# INFO:lda:<420> log likelihood: -200579
# INFO:lda:<430> log likelihood: -200361
# INFO:lda:<440> log likelihood: -200287
# INFO:lda:<450> log likelihood: -200564
# INFO:lda:<460> log likelihood: -200358
# INFO:lda:<470> log likelihood: -200695
# INFO:lda:<480> log likelihood: -200718
# INFO:lda:<490> log likelihood: -200458
# INFO:lda:<499> log likelihood: -200543
# Topic 0: pancreatic cm normal cancer treatment lymph tumor metastatic
# Topic 1: ct mass count plasma dose value chest result
# Topic 2: mg tablet take mouth patient history daily negative
# Doc 0 (PDAC) -> Topic: 1
# Doc 1 (PDAC) -> Topic: 2
# Doc 2 (PDAC) -> Topic: 0
# Doc 3 (PDAC) -> Topic: 1
# Doc 4 (PDAC) -> Topic: 2
# Doc 5 (PDAC) -> Topic: 1
# Doc 6 (PDAC) -> Topic: 1
# Doc 7 (PDAC) -> Topic: 0
# Doc 8 (PDAC) -> Topic: 2
# Doc 9 (PDAC) -> Topic: 2
# Doc 10 (PDAC) -> Topic: 0
# Doc 11 (PDAC) -> Topic: 1
# Doc 12 (PDAC) -> Topic: 1
# Doc 13 (PDAC) -> Topic: 0
# Doc 14 (PDAC) -> Topic: 2
# Doc 15 (PDAC) -> Topic: 1
# Doc 16 (PDAC) -> Topic: 2
# Doc 17 (PDAC) -> Topic: 2
# Doc 18 (PDAC) -> Topic: 2
# Doc 19 (PDAC) -> Topic: 0

# %%
def top_ngrams(docs, n=2, top=10):
    counter = Counter()
    for doc in docs:
        tokens = doc.split()
        for i in range(len(tokens) - n + 1):
            ngram = tuple(tokens[i:i+n])
            counter[ngram] += 1
    return counter.most_common(top)

pdac_bigrams = top_ngrams(pdac_df["clean_note"], n=2, top=10)
print("PDAC Top 10 Bigrams:")
print(pdac_bigrams)

bc_bigrams = top_ngrams(bc_df["clean_note"], n=2, top=10)
print("BC Top 10 Bigrams:")
print(bc_bigrams)

def plot_ngram_counts(ngram_counts, title):
    ngrams, counts = zip(*ngram_counts)
    ngrams = [" ".join(ng) for ng in ngrams]
    plt.figure(figsize=(8,4))
    plt.barh(ngrams, counts, color="skyblue")
    plt.gca().invert_yaxis()
    plt.title(title)
    plt.show()

plot_ngram_counts(pdac_bigrams, "PDAC Top 10 Bigrams")
plot_ngram_counts(bc_bigrams, "BC Top 10 Bigrams")
# Out:
# PDAC Top 10 Bigrams:
# [(('tablet', 'take'), 91), (('serum', 'plasma'), 85), (('mg', 'tablet'), 77), (('ref', 'range'), 58), (('value', 'ref'), 55), (('result', 'value'), 53), (('pancreatic', 'cancer'), 52), (('take', 'mg'), 51), (('mg', 'mouth'), 50), (('count', 'xel'), 49)]
# BC Top 10 Bigrams:
# [(('right', 'breast'), 160), (('left', 'breast'), 152), (('breast', 'cancer'), 136), (('lymph', 'node'), 83), (('tablet', 'take'), 72), (('mg', 'tablet'), 64), (('right', 'axillary'), 59), (('axillary', 'lymph'), 55), (('lymph', 'nodes'), 54), (('social', 'history'), 51)]

# %%
def plot_wordcloud(text, title):
    wc = WordCloud(background_color="white", max_words=100).generate(text)
    plt.figure(figsize=(8,6))
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(title)
    plt.show()

# PDAC
pdac_text = " ".join(pdac_df["clean_note"].tolist())
plot_wordcloud(pdac_text, "PDAC Word Cloud")

# BC
bc_text = " ".join(bc_df["clean_note"].tolist())
plot_wordcloud(bc_text, "BC Word Cloud")
